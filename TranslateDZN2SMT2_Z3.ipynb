# %% [markdown]
# # Translate `dzn` to `smt2` for z3

# %% [markdown]
# ### Check Versions of Tools

# %%
import subprocess

output = subprocess.check_output("../optimathsat/bin/optimathsat -version", shell=True, universal_newlines=True)
output
# Out:
# 'MathSAT5 version 1.6.4 (d39a648d6bb7) (Feb 25 2020 14:02:07, gmp 6.1.2, gcc 9.2.1, 64-bit)\n'

# %%
output = subprocess.check_output("../minizinc/build/minizinc --version", shell=True, universal_newlines=True)
output
# Out:
# 'MiniZinc to FlatZinc converter, version 2.3.2\nCopyright (C) 2014-2020 Monash University, NICTA, Data61\n'

# %%
output = subprocess.check_output("../z3/build/z3 --version", shell=True, universal_newlines=True)
output
# Out:
# 'Z3 version 4.8.8 - 64 bit\n'

# %% [markdown]
# First generate the FlatZinc files using the MiniZinc tool. Make sure that a `smt2` folder is located inside `./minizinc/share/minizinc/`. Else, to enable OptiMathSAT's support for global constraints download the [smt2.tar.gz](http://optimathsat.disi.unitn.it/data/smt2.tar.gz) package and unpack it there using
#
# ```zsh
# tar xf smt2.tar.gz $MINIZINC_PATH/share/minizinc/
# ```
#
# If next output shows a list of `.mzn` files, then this dependency is satified.

# %%
output = subprocess.check_output("ls -la ../minizinc/share/minizinc/smt2/", shell=True, universal_newlines=True)
print(output)
# Out:
# total 292
# drwxr-xr-x  2 kw kw 4096 Jan 15  2018 .
# drwxr-xr-x 11 kw kw 4096 Apr 28 15:52 ..
# -rw-r--r--  1 kw kw  328 Nov 13  2017 alldifferent_except_0.mzn
# -rw-r--r--  1 kw kw  382 Nov 13  2017 all_different_int.mzn
# -rw-r--r--  1 kw kw  396 Nov 13  2017 all_different_set.mzn
# -rw-r--r--  1 kw kw  270 Nov 13  2017 all_disjoint.mzn
# -rw-r--r--  1 kw kw  150 Nov 14  2017 all_equal_int.mzn
# -rw-r--r--  1 kw kw  164 Nov 13  2017 all_equal_set.mzn
# -rw-r--r--  1 kw kw  351 Nov 13  2017 among.mzn
# -rw-r--r--  1 kw kw  305 Nov  8  2017 arg_max_float.mzn
# -rw-r--r--  1 kw kw  291 Nov  8  2017 arg_max_int.mzn
# -rw-r--r--  1 kw kw  306 Nov  8  2017 arg_min_float.mzn
# -rw-r--r--  1 kw kw  291 Nov  8  2017 arg_min_int.mzn
# -rw-r--r--  1 kw kw  480 Nov 13  2017 at_least_int.mzn
# -rw-r--r--  1 kw kw  506 Nov 14  2017 at_least_set.mzn
# -rw-r--r--  1 kw kw  340 Nov 13  2017 at_most1.mzn
# -rw-r--r--  1 kw kw  474 Nov 13  2017 at_most_int.mzn
# -rw-r--r--  1 kw kw  502 Nov 13  2017 at_most_set.mzn
# -rw-r--r--  1 kw kw 1162 Nov  8  2017 bin_packing_capa.mzn
# -rw-r--r--  1 kw kw 1044 Nov  8  2017 bin_packing_load.mzn
# -rw-r--r--  1 kw kw  883 Nov 14  2017 bin_packing.mzn
# -rw-r--r--  1 kw kw  765 Nov 14  2017 comparison_rel_array.mzn
# -rw-r--r--  1 kw kw  350 Nov 13  2017 count_eq.mzn
# -rw-r--r--  1 kw kw  382 Nov 13  2017 count_geq.mzn
# -rw-r--r--  1 kw kw  375 Nov 13  2017 count_gt.mzn
# -rw-r--r--  1 kw kw  379 Nov 13  2017 count_leq.mzn
# -rw-r--r--  1 kw kw  371 Nov 13  2017 count_lt.mzn
# -rw-r--r--  1 kw kw  371 Nov 13  2017 count_neq.mzn
# -rw-r--r--  1 kw kw  398 Nov 13  2017 decreasing_bool.mzn
# -rw-r--r--  1 kw kw  404 Nov 13  2017 decreasing_float.mzn
# -rw-r--r--  1 kw kw  393 Nov 13  2017 decreasing_int.mzn
# -rw-r--r--  1 kw kw  408 Nov 14  2017 decreasing_set.mzn
# -rw-r--r--  1 kw kw 1589 Nov 13  2017 diffn_k.mzn
# -rw-r--r--  1 kw kw  853 Nov 14  2017 diffn.mzn
# -rw-r--r--  1 kw kw 1731 Nov 13  2017 diffn_nonstrict_k.mzn
# -rw-r--r--  1 kw kw  919 Nov 14  2017 diffn_nonstrict.mzn
# -rw-r--r--  1 kw kw  276 Nov 14  2017 disjoint.mzn
# -rw-r--r--  1 kw kw  836 Nov  8  2017 disjunctive.mzn
# -rw-r--r--  1 kw kw  748 Nov  8  2017 disjunctive_strict.mzn
# -rw-r--r--  1 kw kw  696 Nov 14  2017 distribute.mzn
# -rw-r--r--  1 kw kw  474 Nov 13  2017 exactly_int.mzn
# -rw-r--r--  1 kw kw  502 Nov 13  2017 exactly_set.mzn
# -rw-r--r--  1 kw kw  851 Nov 14  2017 global_cardinality_closed.mzn
# -rw-r--r--  1 kw kw  396 Nov  8  2017 global_cardinality_fn.mzn
# -rw-r--r--  1 kw kw  914 Nov 13  2017 global_cardinality_low_up_closed.mzn
# -rw-r--r--  1 kw kw  795 Nov 13  2017 global_cardinality_low_up.mzn
# -rw-r--r--  1 kw kw  717 Nov 14  2017 global_cardinality.mzn
# -rw-r--r--  1 kw kw  398 Nov 13  2017 increasing_bool.mzn
# -rw-r--r--  1 kw kw  403 Nov 13  2017 increasing_float.mzn
# -rw-r--r--  1 kw kw  394 Nov 13  2017 increasing_int.mzn
# -rw-r--r--  1 kw kw  408 Nov 13  2017 increasing_set.mzn
# -rw-r--r--  1 kw kw  728 Nov 14  2017 int_set_channel.mzn
# -rw-r--r--  1 kw kw  582 Nov  8  2017 inverse.mzn
# -rw-r--r--  1 kw kw  827 Nov  8  2017 inverse_set.mzn
# -rw-r--r--  1 kw kw  708 Nov 14  2017 link_set_to_booleans.mzn
# -rw-r--r--  1 kw kw  375 Nov 11  2017 maximum_float.mzn
# -rw-r--r--  1 kw kw  367 Nov 11  2017 maximum_int.mzn
# -rw-r--r--  1 kw kw  422 Nov 13  2017 member_bool.mzn
# -rw-r--r--  1 kw kw  431 Nov 13  2017 member_float.mzn
# -rw-r--r--  1 kw kw  414 Nov 13  2017 member_int.mzn
# -rw-r--r--  1 kw kw  442 Nov 13  2017 member_set.mzn
# -rw-r--r--  1 kw kw  372 Nov 11  2017 minimum_float.mzn
# -rw-r--r--  1 kw kw  367 Nov 11  2017 minimum_int.mzn
# -rw-r--r--  1 kw kw  283 Nov 13  2017 nvalue.mzn
# -rw-r--r--  1 kw kw  712 Nov 14  2017 range.mzn
# -rw-r--r--  1 kw kw 1751 Nov 13  2017 redefinitions-2.0.2.mzn
# -rw-r--r--  1 kw kw 1434 Nov 13  2017 redefinitions-2.0.mzn
# -rw-r--r--  1 kw kw  678 Nov 15  2017 redefinitions-2.1.mzn
# -rw-r--r--  1 kw kw  571 Nov 14  2017 roots.mzn
# -rw-r--r--  1 kw kw  764 Nov  8  2017 sum_pred.mzn
# -rw-r--r--  1 kw kw  445 Nov 15  2017 symmetric_all_different.mzn
# -rw-r--r--  1 kw kw  280 Nov 15  2017 value_precede_int.mzn
# -rw-r--r--  1 kw kw  294 Nov 15  2017 value_precede_set.mzn

# %% [markdown]
# ## Transform `dzn` to `fzn` Using a `mzn` Model

# %% [markdown]
# Then transform the desired `.dzn` file to `.fzn` using a `Mz.mzn` MiniZinc model.

# %% [markdown]
# First list all `dzn` files contained in the `dzn_path` that should get processed.

# %%
import os

dzn_files = []
dzn_path = 'dzn-files/'

for filename in os.listdir(dzn_path):
    if filename.endswith(".dzn"):
        dzn_files.append(filename)
len(dzn_files)
# Out:
# 278

# %% [markdown]
# #### Model $Mz_1$

# %%
import sys

fzn_path = 'fzn-files/smt2/Mz1-noAbs/'
minizinc_base_cmd = '../minizinc/build/minizinc \
    -Werror \
    --compile --solver org.minizinc.mzn-fzn \
    --search-dir /home/kw/minizinc/share/minizinc/smt2/ \
    mzn-model/Mz1-noAbs.mzn '
translate_count = 0
for dzn in dzn_files:
    translate_count += 1
    minizinc_transform_cmd = minizinc_base_cmd + dzn_path + dzn \
        + ' --output-to-file ' + fzn_path + dzn.replace('.', '-') + '.fzn'
    print(f'''\r({translate_count}/{len(dzn_files)}) Translating {dzn_path + dzn} to {fzn_path + dzn.replace('.', '-')}.fzn''', end='')
    sys.stdout.flush()
    subprocess.check_output(minizinc_transform_cmd, shell=True, 
                                     universal_newlines=True)
# Out:
# (278/278) Translating dzn-files/R066.dzn to fzn-files/z3/Mz1-noAbs/R066-dzn.fzn

# %% [markdown]
# #### Model $Mz_2$

# %%
import sys

fzn_path = 'fzn-files/smt2/Mz2-noAbs/'
minizinc_base_cmd = '../minizinc/build/minizinc \
    -Werror \
    --compile --solver org.minizinc.mzn-fzn \
    --search-dir /home/kw/minizinc/share/minizinc/smt2/ \
    mzn-model/Mz2-noAbs.mzn '
translate_count = 0
for dzn in dzn_files:
    translate_count += 1
    minizinc_transform_cmd = minizinc_base_cmd + dzn_path + dzn \
        + ' --output-to-file ' + fzn_path + dzn.replace('.', '-') + '.fzn'
    print(f'''\r({translate_count}/{len(dzn_files)}) Translating {dzn_path + dzn} to {fzn_path + dzn.replace('.', '-')}.fzn''', end='')
    sys.stdout.flush()
    subprocess.check_output(minizinc_transform_cmd, shell=True, 
                                     universal_newlines=True)
# Out:
# (278/278) Translating dzn-files/R066.dzn to fzn-files/z3/Mz2-noAbs/R066-dzn.fzn

# %% [markdown]
# ## Translate `fzn` to `smt2`

# %% [markdown]
# The generated `.fzn` file can be used to generate a `.smt2` file using the `fzn2smt2.py` script from this [project](https://github.com/PatrickTrentin88/fzn2omt).

# %% [markdown]
# #### $Mz_1$

# %%
import os

fzn_files = []
fzn_path = 'fzn-files/smt2/Mz1-noAbs/'

for filename in os.listdir(fzn_path):
    if filename.endswith(".fzn"):
        fzn_files.append(filename)
len(fzn_files)
# Out:
# 278

# %%
smt2_path = 'smt2-files/z3/Mz1-noAbs/'
fzn2smt2_base_cmd = '../fzn2omt/fzn2smt2.py --solver z3 --smt2 '
translate_count = 0
for fzn in fzn_files:
    translate_count += 1
    fzn2smt2_transform_cmd = fzn2smt2_base_cmd + smt2_path \
    + fzn.replace('.', '-') + '.smt2 ' + fzn_path + fzn
    print(f'''\r({translate_count}/{len(fzn_files)}) Translating {fzn_path + fzn} to {smt2_path + fzn.replace('.', '-')}.smt2''', end='')
    sys.stdout.flush()
    my_env = os.environ.copy()
    my_env['PATH'] = "/home/kw/optimathsat/bin/:" + my_env['PATH']
    subprocess.check_output(fzn2smt2_transform_cmd, shell=True, env=my_env,
                                     universal_newlines=True)
# Out:
# (278/278) Translating fzn-files/z3/Mz1-noAbs/A063-dzn.fzn to smt2-files/z3/Mz1-noAbs/A063-dzn-fzn.smt2

# %% [markdown]
# #### $Mz_2$

# %%
import os

fzn_files = []
fzn_path = 'fzn-files/smt2/Mz2-noAbs/'

for filename in os.listdir(fzn_path):
    if filename.endswith(".fzn"):
        fzn_files.append(filename)
len(fzn_files)
# Out:
# 278

# %%
smt2_path = 'smt2-files/z3/Mz2-noAbs/'
fzn2smt2_base_cmd = '../fzn2omt/fzn2smt2.py --solver z3 --smt2 '
translate_count = 0
for fzn in fzn_files:
    translate_count += 1
    fzn2smt2_transform_cmd = fzn2smt2_base_cmd + smt2_path \
    + fzn.replace('.', '-') + '.smt2 ' + fzn_path + fzn
    print(f'''\r({translate_count}/{len(fzn_files)}) Translating {fzn_path + fzn} to {smt2_path + fzn.replace('.', '-')}.smt2''', end='')
    sys.stdout.flush()
    my_env = os.environ.copy()
    my_env['PATH'] = "/home/kw/optimathsat/bin/:" + my_env['PATH']
    subprocess.check_output(fzn2smt2_transform_cmd, shell=True, env=my_env,
                                     universal_newlines=True)
# Out:
# (278/278) Translating fzn-files/z3/Mz2-noAbs/A063-dzn.fzn to smt2-files/z3/Mz2-noAbs/A063-dzn-fzn.smt2

# %% [markdown]
# ### Adjust `smt2` Files According to 7.5 in Paper
#
# - Add lower and upper bounds for the decision variable `pfc`
# - Add number of cavities as comments for later solution extraction (workaround)

# %%
import os
import re

def adjust_smt2_file(smt2_path: str, file: str, write_path: str):

    with open(smt2_path+'/'+file, 'r+') as myfile:
        data = "".join(line for line in myfile)

    filename = os.path.splitext(file)[0]
    print(filename)

    newFile = open(os.path.join(write_path, filename +'_v3.smt2'),"w+")
    newFile.write(data)
    newFile.close()

    openFile = open(os.path.join(write_path, filename +'_v3.smt2'))
    data = openFile.readlines()
    additionalLines = data[-5:]
    data = data[:-5]
    openFile.close()

    newFile = open(os.path.join(write_path, filename +'_v3.smt2'),"w+")
    newFile.writelines([item for item in data])
    newFile.close()

    with open(os.path.join(write_path, filename +'_v3.smt2'),"r") as myfile:
        data = "".join(line for line in myfile)
    newFile = open(os.path.join(write_path, filename +'_v3.smt2'),"w+")
    matches = re.findall(r'\(define-fun .\d\d \(\) Int (\d+)\)', data)
    try:
        cavity_count = int(matches[0])
        print(f'''cavity_count: {cavity_count}''')
        newFile.write(f''';; k={cavity_count}\n''')
        newFile.write(f''';; Extract pfc from\n''')
        for i in range(0,cavity_count):
            newFile.write(f''';; X_INTRODUCED_{str(i)}_\n''')
        newFile.write(data)
        for i in range(1,cavity_count+1):
            lb = f'''(define-fun lbound{str(i)} () Bool (> X_INTRODUCED_{str(i-1)}_ 0))\n'''
            ub = f'''(define-fun ubound{str(i)} () Bool (<= X_INTRODUCED_{str(i-1)}_ {str(cavity_count)}))\n'''
            assertLb = f'''(assert lbound{str(i)})\n'''
            assertUb = f'''(assert ubound{str(i)})\n'''

            newFile.write(lb)
            newFile.write(ub)
            newFile.write(assertLb)
            newFile.write(assertUb)
    except:
        print(f'''Check {filename} for completeness - data missing?''')

    newFile.writelines([item for item in additionalLines])
    newFile.close()

# %% [markdown]
# #### $Mz_1$

# %%
smt2_path = 'smt2-files/z3/Mz1-noAbs'

for file in os.listdir(smt2_path):
    if file.endswith(".smt2"):
        adjust_smt2_file(smt2_path=smt2_path, file=file, write_path=f'''{smt2_path}/v3''')
# Out:
# A062-dzn-fzn
# cavity_count: 160
# A040-dzn-fzn
# cavity_count: 40
# R077-dzn-fzn
# cavity_count: 48
# A010-dzn-fzn
# cavity_count: 12
# A024-dzn-fzn
# cavity_count: 86
# R205-dzn-fzn
# cavity_count: 36
# R074-dzn-fzn
# cavity_count: 20
# R062-dzn-fzn
# cavity_count: 44
# A003-dzn-fzn
# cavity_count: 24
# A035-dzn-fzn
# cavity_count: 78
# R156-dzn-fzn
# cavity_count: 78
# A047-dzn-fzn
# cavity_count: 148
# A030-dzn-fzn
# cavity_count: 10
# R172-dzn-fzn
# cavity_count: 22
# R130-dzn-fzn
# cavity_count: 64
# R054-dzn-fzn
# cavity_count: 45
# R143-dzn-fzn
# cavity_count: 20
# R003-dzn-fzn
# cavity_count: 36
# R030-dzn-fzn
# cavity_count: 26
# R022-dzn-fzn
# cavity_count: 26
# R041-dzn-fzn
# cavity_count: 10
# A002-dzn-fzn
# cavity_count: 24
# R025-dzn-fzn
# cavity_count: 32
# R135-dzn-fzn
# cavity_count: 24
# R142-dzn-fzn
# cavity_count: 20
# R087-dzn-fzn
# cavity_count: 60
# R132-dzn-fzn
# cavity_count: 56
# R059-dzn-fzn
# cavity_count: 36
# A071-dzn-fzn
# cavity_count: 192
# R146-dzn-fzn
# cavity_count: 24
# R082-dzn-fzn
# cavity_count: 12
# R099-dzn-fzn
# cavity_count: 34
# R131-dzn-fzn
# cavity_count: 64
# A066-dzn-fzn
# cavity_count: 170
# R110-dzn-fzn
# cavity_count: 18
# R115-dzn-fzn
# cavity_count: 30
# R171-dzn-fzn
# cavity_count: 65
# R120-dzn-fzn
# cavity_count: 32
# R175-dzn-fzn
# cavity_count: 84
# R111-dzn-fzn
# cavity_count: 24
# A048-dzn-fzn
# cavity_count: 68
# R186-dzn-fzn
# cavity_count: 69
# R137-dzn-fzn
# cavity_count: 56
# R145-dzn-fzn
# cavity_count: 24
# R148-dzn-fzn
# cavity_count: 16
# A037-dzn-fzn
# cavity_count: 86
# R184-dzn-fzn
# cavity_count: 70
# R068-dzn-fzn
# cavity_count: 54
# R091-dzn-fzn
# cavity_count: 58
# R191-dzn-fzn
# cavity_count: 69
# A059-dzn-fzn
# cavity_count: 70
# R196-dzn-fzn
# cavity_count: 110
# A026-dzn-fzn
# cavity_count: 12
# A052-dzn-fzn
# cavity_count: 70
# R123-dzn-fzn
# cavity_count: 20
# R129-dzn-fzn
# cavity_count: 44
# A061-dzn-fzn
# cavity_count: 130
# R165-dzn-fzn
# cavity_count: 3
# R128-dzn-fzn
# cavity_count: 40
# R122-dzn-fzn
# cavity_count: 20
# R090-dzn-fzn
# cavity_count: 58
# R083-dzn-fzn
# cavity_count: 24
# A017-dzn-fzn
# cavity_count: 80
# A042-dzn-fzn
# cavity_count: 76
# R180-dzn-fzn
# cavity_count: 70
# R112-dzn-fzn
# cavity_count: 36
# R190-dzn-fzn
# cavity_count: 100
# R126-dzn-fzn
# cavity_count: 40
# R034-dzn-fzn
# cavity_count: 6
# R103-dzn-fzn
# cavity_count: 16
# R046-dzn-fzn
# cavity_count: 52
# A013-dzn-fzn
# cavity_count: 4
# R067-dzn-fzn
# cavity_count: 54
# R019-dzn-fzn
# cavity_count: 64
# R127-dzn-fzn
# cavity_count: 40
# R203-dzn-fzn
# cavity_count: 6
# R141-dzn-fzn
# cavity_count: 34
# A007-dzn-fzn
# cavity_count: 6
# A034-dzn-fzn
# cavity_count: 76
# R038-dzn-fzn
# cavity_count: 40
# R039-dzn-fzn
# cavity_count: 40
# R096-dzn-fzn
# cavity_count: 40
# A063-dzn-fzn
# cavity_count: 162
# R050-dzn-fzn
# cavity_count: 45
# A046-dzn-fzn
# cavity_count: 80
# R060-dzn-fzn
# cavity_count: 54
# R072-dzn-fzn
# cavity_count: 12
# R166-dzn-fzn
# cavity_count: 65
# A023-dzn-fzn
# cavity_count: 86
# A043-dzn-fzn
# cavity_count: 78
# R204-dzn-fzn
# cavity_count: 46
# A055-dzn-fzn
# cavity_count: 6
# R076-dzn-fzn
# cavity_count: 8
# R170-dzn-fzn
# cavity_count: 3
# A049-dzn-fzn
# cavity_count: 70
# A027-dzn-fzn
# cavity_count: 12
# R182-dzn-fzn
# cavity_count: 70
# R164-dzn-fzn
# cavity_count: 67
# R119-dzn-fzn
# cavity_count: 38
# R138-dzn-fzn
# cavity_count: 20
# R167-dzn-fzn
# cavity_count: 26
# R047-dzn-fzn
# cavity_count: 40
# A065-dzn-fzn
# cavity_count: 166
# A036-dzn-fzn
# cavity_count: 80
# R069-dzn-fzn
# cavity_count: 42
# R056-dzn-fzn
# cavity_count: 26
# R173-dzn-fzn
# cavity_count: 26
# R065-dzn-fzn
# cavity_count: 48
# A069-dzn-fzn
# cavity_count: 186
# R158-dzn-fzn
# cavity_count: 80
# R150-dzn-fzn
# cavity_count: 30
# R183-dzn-fzn
# cavity_count: 70
# R032-dzn-fzn
# cavity_count: 40
# R109-dzn-fzn
# cavity_count: 26
# R147-dzn-fzn
# cavity_count: 16
# R007-dzn-fzn
# cavity_count: 46
# R053-dzn-fzn
# cavity_count: 52
# R140-dzn-fzn
# cavity_count: 70
# A064-dzn-fzn
# cavity_count: 162
# R036-dzn-fzn
# cavity_count: 40
# R001-dzn-fzn
# Check R001-dzn-fzn for completeness - data missing?
# R136-dzn-fzn
# cavity_count: 16
# A051-dzn-fzn
# cavity_count: 70
# R011-dzn-fzn
# cavity_count: 44
# R194-dzn-fzn
# cavity_count: 112
# R014-dzn-fzn
# cavity_count: 20
# A008-dzn-fzn
# cavity_count: 6
# R095-dzn-fzn
# cavity_count: 68
# R098-dzn-fzn
# cavity_count: 64
# R006-dzn-fzn
# cavity_count: 30
# R100-dzn-fzn
# cavity_count: 46
# R084-dzn-fzn
# cavity_count: 24
# R189-dzn-fzn
# cavity_count: 100
# R121-dzn-fzn
# cavity_count: 20
# R042-dzn-fzn
# cavity_count: 52
# R043-dzn-fzn
# cavity_count: 10
# R174-dzn-fzn
# cavity_count: 26
# R155-dzn-fzn
# cavity_count: 75
# R179-dzn-fzn
# cavity_count: 70
# R031-dzn-fzn
# cavity_count: 40
# A070-dzn-fzn
# cavity_count: 190
# A072-dzn-fzn
# cavity_count: 198
# A033-dzn-fzn
# cavity_count: 80
# A060-dzn-fzn
# cavity_count: 100
# A020-dzn-fzn
# cavity_count: 80
# A015-dzn-fzn
# cavity_count: 8
# R195-dzn-fzn
# cavity_count: 110
# R159-dzn-fzn
# cavity_count: 80
# R124-dzn-fzn
# cavity_count: 14
# R008-dzn-fzn
# cavity_count: 18
# R177-dzn-fzn
# cavity_count: 70
# R081-dzn-fzn
# cavity_count: 34
# R028-dzn-fzn
# cavity_count: 26
# A073-dzn-fzn
# cavity_count: 198
# A018-dzn-fzn
# cavity_count: 80
# R185-dzn-fzn
# cavity_count: 70
# A056-dzn-fzn
# cavity_count: 18
# R157-dzn-fzn
# cavity_count: 78
# R104-dzn-fzn
# cavity_count: 16
# R058-dzn-fzn
# cavity_count: 48
# R105-dzn-fzn
# cavity_count: 18
# R018-dzn-fzn
# cavity_count: 58
# R197-dzn-fzn
# cavity_count: 49
# R154-dzn-fzn
# cavity_count: 76
# A021-dzn-fzn
# cavity_count: 80
# R134-dzn-fzn
# cavity_count: 56
# R102-dzn-fzn
# cavity_count: 16
# A012-dzn-fzn
# cavity_count: 2
# R149-dzn-fzn
# cavity_count: 24
# R168-dzn-fzn
# cavity_count: 56
# A032-dzn-fzn
# cavity_count: 40
# A014-dzn-fzn
# cavity_count: 16
# R023-dzn-fzn
# cavity_count: 26
# R085-dzn-fzn
# cavity_count: 16
# R160-dzn-fzn
# cavity_count: 80
# A028-dzn-fzn
# cavity_count: 40
# R021-dzn-fzn
# cavity_count: 26
# R075-dzn-fzn
# cavity_count: 10
# A053-dzn-fzn
# cavity_count: 12
# A031-dzn-fzn
# cavity_count: 18
# A019-dzn-fzn
# cavity_count: 80
# R017-dzn-fzn
# cavity_count: 66
# A009-dzn-fzn
# cavity_count: 8
# R073-dzn-fzn
# cavity_count: 16
# R024-dzn-fzn
# cavity_count: 26
# A057-dzn-fzn
# cavity_count: 20
# R163-dzn-fzn
# cavity_count: 56
# R101-dzn-fzn
# cavity_count: 16
# R113-dzn-fzn
# cavity_count: 36
# R063-dzn-fzn
# cavity_count: 26
# R029-dzn-fzn
# cavity_count: 26
# A038-dzn-fzn
# cavity_count: 20
# R116-dzn-fzn
# cavity_count: 32
# R161-dzn-fzn
# cavity_count: 80
# R106-dzn-fzn
# cavity_count: 26
# R078-dzn-fzn
# cavity_count: 30
# R020-dzn-fzn
# cavity_count: 68
# R202-dzn-fzn
# cavity_count: 24
# R004-dzn-fzn
# cavity_count: 36
# R033-dzn-fzn
# cavity_count: 6
# R040-dzn-fzn
# cavity_count: 40
# A041-dzn-fzn
# cavity_count: 50
# R144-dzn-fzn
# cavity_count: 56
# A068-dzn-fzn
# cavity_count: 180
# R114-dzn-fzn
# cavity_count: 30
# A058-dzn-fzn
# cavity_count: 40
# A045-dzn-fzn
# cavity_count: 72
# A016-dzn-fzn
# cavity_count: 80
# R002-dzn-fzn
# Check R002-dzn-fzn for completeness - data missing?
# R201-dzn-fzn
# cavity_count: 24
# R066-dzn-fzn
# cavity_count: 36
# R162-dzn-fzn
# cavity_count: 80
# R152-dzn-fzn
# cavity_count: 16
# R057-dzn-fzn
# cavity_count: 54
# R181-dzn-fzn
# cavity_count: 78
# R187-dzn-fzn
# cavity_count: 69
# R198-dzn-fzn
# cavity_count: 50
# A050-dzn-fzn
# cavity_count: 70
# R027-dzn-fzn
# cavity_count: 26
# R051-dzn-fzn
# cavity_count: 45
# A025-dzn-fzn
# cavity_count: 20
# A022-dzn-fzn
# cavity_count: 80
# R093-dzn-fzn
# cavity_count: 58
# R117-dzn-fzn
# cavity_count: 32
# R052-dzn-fzn
# cavity_count: 52
# R010-dzn-fzn
# cavity_count: 70
# R193-dzn-fzn
# cavity_count: 104
# R061-dzn-fzn
# cavity_count: 42
# R049-dzn-fzn
# cavity_count: 45
# R064-dzn-fzn
# cavity_count: 54
# A044-dzn-fzn
# cavity_count: 80
# R151-dzn-fzn
# cavity_count: 16
# R169-dzn-fzn
# cavity_count: 67
# R200-dzn-fzn
# cavity_count: 48
# R088-dzn-fzn
# cavity_count: 60
# R035-dzn-fzn
# cavity_count: 12
# R108-dzn-fzn
# cavity_count: 12
# R092-dzn-fzn
# cavity_count: 58
# R094-dzn-fzn
# cavity_count: 68
# A004-dzn-fzn
# cavity_count: 4
# R176-dzn-fzn
# cavity_count: 70
# R153-dzn-fzn
# cavity_count: 75
# R055-dzn-fzn
# cavity_count: 45
# R178-dzn-fzn
# cavity_count: 70
# R016-dzn-fzn
# cavity_count: 60
# A001-dzn-fzn
# cavity_count: 20
# R139-dzn-fzn
# cavity_count: 18
# R070-dzn-fzn
# cavity_count: 42
# A067-dzn-fzn
# cavity_count: 180
# R086-dzn-fzn
# cavity_count: 60
# R125-dzn-fzn
# cavity_count: 20
# R079-dzn-fzn
# cavity_count: 48
# R013-dzn-fzn
# cavity_count: 34
# R005-dzn-fzn
# cavity_count: 36
# R037-dzn-fzn
# cavity_count: 12
# A006-dzn-fzn
# cavity_count: 6
# R097-dzn-fzn
# cavity_count: 60
# R080-dzn-fzn
# cavity_count: 28
# R012-dzn-fzn
# cavity_count: 70
# R009-dzn-fzn
# cavity_count: 38
# R133-dzn-fzn
# cavity_count: 56
# R045-dzn-fzn
# cavity_count: 52
# A011-dzn-fzn
# cavity_count: 16
# R199-dzn-fzn
# cavity_count: 46
# R071-dzn-fzn
# cavity_count: 6
# R015-dzn-fzn
# cavity_count: 20
# R107-dzn-fzn
# cavity_count: 26
# R118-dzn-fzn
# cavity_count: 32
# R188-dzn-fzn
# cavity_count: 69
# A039-dzn-fzn
# cavity_count: 20
# A029-dzn-fzn
# cavity_count: 40
# R026-dzn-fzn
# cavity_count: 10
# A005-dzn-fzn
# cavity_count: 4
# R089-dzn-fzn
# cavity_count: 60
# R048-dzn-fzn
# cavity_count: 45
# R044-dzn-fzn
# cavity_count: 52
# A054-dzn-fzn
# cavity_count: 2
# R192-dzn-fzn
# cavity_count: 104

# %% [markdown]
# #### $Mz_2$

# %%
smt2_path = 'smt2-files/z3/Mz2-noAbs'

for file in os.listdir(smt2_path):
    if file.endswith(".smt2"):
        adjust_smt2_file(smt2_path=smt2_path, file=file, write_path=f'''{smt2_path}/v3''')
# Out:
# A062-dzn-fzn
# nbChambers: 160
# A040-dzn-fzn
# nbChambers: 40
# R077-dzn-fzn
# nbChambers: 48
# A010-dzn-fzn
# nbChambers: 12
# A024-dzn-fzn
# nbChambers: 86
# R205-dzn-fzn
# nbChambers: 36
# R074-dzn-fzn
# nbChambers: 20
# R062-dzn-fzn
# nbChambers: 44
# A003-dzn-fzn
# nbChambers: 24
# A035-dzn-fzn
# nbChambers: 78
# R156-dzn-fzn
# nbChambers: 78
# A047-dzn-fzn
# nbChambers: 148
# A030-dzn-fzn
# nbChambers: 10
# R172-dzn-fzn
# nbChambers: 22
# R130-dzn-fzn
# nbChambers: 64
# R054-dzn-fzn
# nbChambers: 45
# R143-dzn-fzn
# nbChambers: 20
# R003-dzn-fzn
# nbChambers: 36
# R030-dzn-fzn
# nbChambers: 26
# R022-dzn-fzn
# nbChambers: 26
# R041-dzn-fzn
# nbChambers: 10
# A002-dzn-fzn
# nbChambers: 24
# R025-dzn-fzn
# nbChambers: 32
# R135-dzn-fzn
# nbChambers: 24
# R142-dzn-fzn
# nbChambers: 20
# R087-dzn-fzn
# nbChambers: 60
# R132-dzn-fzn
# nbChambers: 56
# R059-dzn-fzn
# nbChambers: 36
# A071-dzn-fzn
# nbChambers: 192
# R146-dzn-fzn
# nbChambers: 24
# R082-dzn-fzn
# nbChambers: 12
# R099-dzn-fzn
# nbChambers: 34
# R131-dzn-fzn
# nbChambers: 64
# A066-dzn-fzn
# nbChambers: 170
# R110-dzn-fzn
# nbChambers: 18
# R115-dzn-fzn
# nbChambers: 30
# R171-dzn-fzn
# nbChambers: 65
# R120-dzn-fzn
# nbChambers: 32
# R175-dzn-fzn
# nbChambers: 84
# R111-dzn-fzn
# nbChambers: 24
# A048-dzn-fzn
# nbChambers: 68
# R186-dzn-fzn
# nbChambers: 69
# R137-dzn-fzn
# nbChambers: 56
# R145-dzn-fzn
# nbChambers: 24
# R148-dzn-fzn
# nbChambers: 16
# A037-dzn-fzn
# nbChambers: 86
# R184-dzn-fzn
# nbChambers: 70
# R068-dzn-fzn
# nbChambers: 54
# R091-dzn-fzn
# nbChambers: 58
# R191-dzn-fzn
# nbChambers: 69
# A059-dzn-fzn
# nbChambers: 70
# R196-dzn-fzn
# nbChambers: 110
# A026-dzn-fzn
# nbChambers: 12
# A052-dzn-fzn
# nbChambers: 70
# R123-dzn-fzn
# nbChambers: 20
# R129-dzn-fzn
# nbChambers: 44
# A061-dzn-fzn
# nbChambers: 130
# R165-dzn-fzn
# nbChambers: 3
# R128-dzn-fzn
# nbChambers: 40
# R122-dzn-fzn
# nbChambers: 20
# R090-dzn-fzn
# nbChambers: 58
# R083-dzn-fzn
# nbChambers: 24
# A017-dzn-fzn
# nbChambers: 80
# A042-dzn-fzn
# nbChambers: 76
# R180-dzn-fzn
# nbChambers: 70
# R112-dzn-fzn
# nbChambers: 36
# R190-dzn-fzn
# nbChambers: 100
# R126-dzn-fzn
# nbChambers: 40
# R034-dzn-fzn
# nbChambers: 6
# R103-dzn-fzn
# nbChambers: 16
# R046-dzn-fzn
# nbChambers: 52
# A013-dzn-fzn
# nbChambers: 4
# R067-dzn-fzn
# nbChambers: 54
# R019-dzn-fzn
# nbChambers: 64
# R127-dzn-fzn
# nbChambers: 40
# R203-dzn-fzn
# nbChambers: 6
# R141-dzn-fzn
# nbChambers: 34
# A007-dzn-fzn
# nbChambers: 6
# A034-dzn-fzn
# nbChambers: 76
# R038-dzn-fzn
# nbChambers: 40
# R039-dzn-fzn
# nbChambers: 40
# R096-dzn-fzn
# nbChambers: 40
# A063-dzn-fzn
# nbChambers: 162
# R050-dzn-fzn
# nbChambers: 45
# A046-dzn-fzn
# nbChambers: 80
# R060-dzn-fzn
# nbChambers: 54
# R072-dzn-fzn
# nbChambers: 12
# R166-dzn-fzn
# nbChambers: 65
# A023-dzn-fzn
# nbChambers: 86
# A043-dzn-fzn
# nbChambers: 78
# R204-dzn-fzn
# nbChambers: 46
# A055-dzn-fzn
# nbChambers: 6
# R076-dzn-fzn
# nbChambers: 8
# R170-dzn-fzn
# nbChambers: 3
# A049-dzn-fzn
# nbChambers: 70
# A027-dzn-fzn
# nbChambers: 12
# R182-dzn-fzn
# nbChambers: 70
# R164-dzn-fzn
# nbChambers: 67
# R119-dzn-fzn
# nbChambers: 38
# R138-dzn-fzn
# nbChambers: 20
# R167-dzn-fzn
# nbChambers: 26
# R047-dzn-fzn
# nbChambers: 40
# A065-dzn-fzn
# nbChambers: 166
# A036-dzn-fzn
# nbChambers: 80
# R069-dzn-fzn
# nbChambers: 42
# R056-dzn-fzn
# nbChambers: 26
# R173-dzn-fzn
# nbChambers: 26
# R065-dzn-fzn
# nbChambers: 48
# A069-dzn-fzn
# nbChambers: 186
# R158-dzn-fzn
# nbChambers: 80
# R150-dzn-fzn
# nbChambers: 30
# R183-dzn-fzn
# nbChambers: 70
# R032-dzn-fzn
# nbChambers: 40
# R109-dzn-fzn
# nbChambers: 26
# R147-dzn-fzn
# nbChambers: 16
# R007-dzn-fzn
# nbChambers: 46
# R053-dzn-fzn
# nbChambers: 52
# R140-dzn-fzn
# nbChambers: 70
# A064-dzn-fzn
# nbChambers: 162
# R036-dzn-fzn
# nbChambers: 40
# R001-dzn-fzn
# Check R001-dzn-fzn for completeness - data missing?
# R136-dzn-fzn
# nbChambers: 16
# A051-dzn-fzn
# nbChambers: 70
# R011-dzn-fzn
# nbChambers: 44
# R194-dzn-fzn
# nbChambers: 112
# R014-dzn-fzn
# nbChambers: 20
# A008-dzn-fzn
# nbChambers: 6
# R095-dzn-fzn
# nbChambers: 68
# R098-dzn-fzn
# nbChambers: 64
# R006-dzn-fzn
# nbChambers: 30
# R100-dzn-fzn
# nbChambers: 46
# R084-dzn-fzn
# nbChambers: 24
# R189-dzn-fzn
# nbChambers: 100
# R121-dzn-fzn
# nbChambers: 20
# R042-dzn-fzn
# nbChambers: 52
# R043-dzn-fzn
# nbChambers: 10
# R174-dzn-fzn
# nbChambers: 26
# R155-dzn-fzn
# nbChambers: 75
# R179-dzn-fzn
# nbChambers: 70
# R031-dzn-fzn
# nbChambers: 40
# A070-dzn-fzn
# nbChambers: 190
# A072-dzn-fzn
# nbChambers: 198
# A033-dzn-fzn
# nbChambers: 80
# A060-dzn-fzn
# nbChambers: 100
# A020-dzn-fzn
# nbChambers: 80
# A015-dzn-fzn
# nbChambers: 8
# R195-dzn-fzn
# nbChambers: 110
# R159-dzn-fzn
# nbChambers: 80
# R124-dzn-fzn
# nbChambers: 14
# R008-dzn-fzn
# nbChambers: 18
# R177-dzn-fzn
# nbChambers: 70
# R081-dzn-fzn
# nbChambers: 34
# R028-dzn-fzn
# nbChambers: 26
# A073-dzn-fzn
# nbChambers: 198
# A018-dzn-fzn
# nbChambers: 80
# R185-dzn-fzn
# nbChambers: 70
# A056-dzn-fzn
# nbChambers: 18
# R157-dzn-fzn
# nbChambers: 78
# R104-dzn-fzn
# nbChambers: 16
# R058-dzn-fzn
# nbChambers: 48
# R105-dzn-fzn
# nbChambers: 18
# R018-dzn-fzn
# nbChambers: 58
# R197-dzn-fzn
# nbChambers: 49
# R154-dzn-fzn
# nbChambers: 76
# A021-dzn-fzn
# nbChambers: 80
# R134-dzn-fzn
# nbChambers: 56
# R102-dzn-fzn
# nbChambers: 16
# A012-dzn-fzn
# nbChambers: 2
# R149-dzn-fzn
# nbChambers: 24
# R168-dzn-fzn
# nbChambers: 56
# A032-dzn-fzn
# nbChambers: 40
# A014-dzn-fzn
# nbChambers: 16
# R023-dzn-fzn
# nbChambers: 26
# R085-dzn-fzn
# nbChambers: 16
# R160-dzn-fzn
# nbChambers: 80
# A028-dzn-fzn
# nbChambers: 40
# R021-dzn-fzn
# nbChambers: 26
# R075-dzn-fzn
# nbChambers: 10
# A053-dzn-fzn
# nbChambers: 12
# A031-dzn-fzn
# nbChambers: 18
# A019-dzn-fzn
# nbChambers: 80
# R017-dzn-fzn
# nbChambers: 66
# A009-dzn-fzn
# nbChambers: 8
# R073-dzn-fzn
# nbChambers: 16
# R024-dzn-fzn
# nbChambers: 26
# A057-dzn-fzn
# nbChambers: 20
# R163-dzn-fzn
# nbChambers: 56
# R101-dzn-fzn
# nbChambers: 16
# R113-dzn-fzn
# nbChambers: 36
# R063-dzn-fzn
# nbChambers: 26
# R029-dzn-fzn
# nbChambers: 26
# A038-dzn-fzn
# nbChambers: 20
# R116-dzn-fzn
# nbChambers: 32
# R161-dzn-fzn
# nbChambers: 80
# R106-dzn-fzn
# nbChambers: 26
# R078-dzn-fzn
# nbChambers: 30
# R020-dzn-fzn
# nbChambers: 68
# R202-dzn-fzn
# nbChambers: 24
# R004-dzn-fzn
# nbChambers: 36
# R033-dzn-fzn
# nbChambers: 6
# R040-dzn-fzn
# nbChambers: 40
# A041-dzn-fzn
# nbChambers: 50
# R144-dzn-fzn
# nbChambers: 56
# A068-dzn-fzn
# nbChambers: 180
# R114-dzn-fzn
# nbChambers: 30
# A058-dzn-fzn
# nbChambers: 40
# A045-dzn-fzn
# nbChambers: 72
# A016-dzn-fzn
# nbChambers: 80
# R002-dzn-fzn
# Check R002-dzn-fzn for completeness - data missing?
# R201-dzn-fzn
# nbChambers: 24
# R066-dzn-fzn
# nbChambers: 36
# R162-dzn-fzn
# nbChambers: 80
# R152-dzn-fzn
# nbChambers: 16
# R057-dzn-fzn
# nbChambers: 54
# R181-dzn-fzn
# nbChambers: 78
# R187-dzn-fzn
# nbChambers: 69
# R198-dzn-fzn
# nbChambers: 50
# A050-dzn-fzn
# nbChambers: 70
# R027-dzn-fzn
# nbChambers: 26
# R051-dzn-fzn
# nbChambers: 45
# A025-dzn-fzn
# nbChambers: 20
# A022-dzn-fzn
# nbChambers: 80
# R093-dzn-fzn
# nbChambers: 58
# R117-dzn-fzn
# nbChambers: 32
# R052-dzn-fzn
# nbChambers: 52
# R010-dzn-fzn
# nbChambers: 70
# R193-dzn-fzn
# nbChambers: 104
# R061-dzn-fzn
# nbChambers: 42
# R049-dzn-fzn
# nbChambers: 45
# R064-dzn-fzn
# nbChambers: 54
# A044-dzn-fzn
# nbChambers: 80
# R151-dzn-fzn
# nbChambers: 16
# R169-dzn-fzn
# nbChambers: 67
# R200-dzn-fzn
# nbChambers: 48
# R088-dzn-fzn
# nbChambers: 60
# R035-dzn-fzn
# nbChambers: 12
# R108-dzn-fzn
# nbChambers: 12
# R092-dzn-fzn
# nbChambers: 58
# R094-dzn-fzn
# nbChambers: 68
# A004-dzn-fzn
# nbChambers: 4
# R176-dzn-fzn
# nbChambers: 70
# R153-dzn-fzn
# nbChambers: 75
# R055-dzn-fzn
# nbChambers: 45
# R178-dzn-fzn
# nbChambers: 70
# R016-dzn-fzn
# nbChambers: 60
# A001-dzn-fzn
# nbChambers: 20
# R139-dzn-fzn
# nbChambers: 18
# R070-dzn-fzn
# nbChambers: 42
# A067-dzn-fzn
# nbChambers: 180
# R086-dzn-fzn
# nbChambers: 60
# R125-dzn-fzn
# nbChambers: 20
# R079-dzn-fzn
# nbChambers: 48
# R013-dzn-fzn
# nbChambers: 34
# R005-dzn-fzn
# nbChambers: 36
# R037-dzn-fzn
# nbChambers: 12
# A006-dzn-fzn
# nbChambers: 6
# R097-dzn-fzn
# nbChambers: 60
# R080-dzn-fzn
# nbChambers: 28
# R012-dzn-fzn
# nbChambers: 70
# R009-dzn-fzn
# nbChambers: 38
# R133-dzn-fzn
# nbChambers: 56
# R045-dzn-fzn
# nbChambers: 52
# A011-dzn-fzn
# nbChambers: 16
# R199-dzn-fzn
# nbChambers: 46
# R071-dzn-fzn
# nbChambers: 6
# R015-dzn-fzn
# nbChambers: 20
# R107-dzn-fzn
# nbChambers: 26
# R118-dzn-fzn
# nbChambers: 32
# R188-dzn-fzn
# nbChambers: 69
# A039-dzn-fzn
# nbChambers: 20
# A029-dzn-fzn
# nbChambers: 40
# R026-dzn-fzn
# nbChambers: 10
# A005-dzn-fzn
# nbChambers: 4
# R089-dzn-fzn
# nbChambers: 60
# R048-dzn-fzn
# nbChambers: 45
# R044-dzn-fzn
# nbChambers: 52
# A054-dzn-fzn
# nbChambers: 2
# R192-dzn-fzn
# nbChambers: 104

# %% [markdown]
# ## Test Generated `smt2` Files Using `z3`
#
# This shoud generate the `smt2` file without any error. If this was the case then the `z3` prover can be called on a file by running
#
#
# ```zsh
# z3 output/A001-dzn-smt2-fzn.smt2
# ```
#
# yielding something similar to
#
# ```zsh
# z3 output/A001-dzn-smt2-fzn.smt2
# sat
# (objectives
#  (obj 41881)
# )
# (model
#   (define-fun X_INTRODUCED_981_ () Bool
#     false)
#   (define-fun X_INTRODUCED_348_ () Bool
#     false)
#
#    .....
# ```

# %% [markdown]
# #### Tests with `smt2` from $Mz_1$

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz1-noAbs/v3/A004-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 88)
# )
# (model
#   (define-fun X_INTRODUCED_36_ () Int
#     0)
#   (define-fun X_INTRODUCED_56_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_5_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_61_ () Bool
#     false)
#   (define-fun X_INTRODUCED_39_ () Bool
#     true)
#   (define-fun X_INTRODUCED_31_ () Bool
#     false)
#   (define-fun X_INTRODUCED_12_ () Bool
#     false)
#   (define-fun X_INTRODUCED_27_ () Bool
#     false)
#   (define-fun X_INTRODUCED_59_ () Bool
#     false)
#   (define-fun X_INTRODUCED_34_ () Bool
#     false)
#   (define-fun X_INTRODUCED_44_ () Int
#     0)
#   (define-fun obj () Int
#     88)
#   (define-fun X_INTRODUCED_15_ () Bool
#     true)
#   (define-fun X_INTRODUCED_43_ () Bool
#     false)
#   (define-fun X_INTRODUCED_38_ () Int
#     0)
#   (define-fun M () Int
#     1)
#   (define-fun X_INTRODUCED_54_ () Int
#     3)
#   (define-fun X_INTRODUCED_49_ () Int
#     0)
#   (define-fun X_INTRODUCED_50_ () Int
#     0)
#   (define-fun X_INTRODUCED_46_ () Bool
#     false)
#   (define-fun X_INTRODUCED_16_ () Int
#     0)
#   (define-fun X_INTRODUCED_10_ () Bool
#     false)
#   (define-fun X_INTRODUCED_28_ () Int
#     0)
#   (define-fun X_INTRODUCED_29_ () Int
#     1)
#   (define-fun X_INTRODUCED_25_ () Bool
#     false)
#   (define-fun X_INTRODUCED_22_ () Bool
#     true)
#   (define-fun X_INTRODUCED_48_ () Bool
#     false)
#   (define-fun X_INTRODUCED_58_ () Int
#     3)
#   (define-fun X_INTRODUCED_0_ () Int
#     3)
#   (define-fun X_INTRODUCED_17_ () Int
#     1)
#   (define-fun X_INTRODUCED_40_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1_ () Int
#     4)
#   (define-fun X_INTRODUCED_11_ () Int
#     (- 3))
#   (define-fun X_INTRODUCED_45_ () Int
#     1)
#   (define-fun X_INTRODUCED_42_ () Bool
#     false)
#   (define-fun X_INTRODUCED_35_ () Bool
#     false)
#   (define-fun X_INTRODUCED_26_ () Bool
#     false)
#   (define-fun X_INTRODUCED_20_ () Bool
#     true)
#   (define-fun X_INTRODUCED_9_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Bool
#     false)
#   (define-fun X_INTRODUCED_14_ () Bool
#     true)
#   (define-fun X_INTRODUCED_62_ () Int
#     0)
#   (define-fun X_INTRODUCED_13_ () Int
#     3)
#   (define-fun X_INTRODUCED_8_ () Int
#     1)
#   (define-fun X_INTRODUCED_60_ () Int
#     0)
#   (define-fun X_INTRODUCED_47_ () Int
#     0)
#   (define-fun X_INTRODUCED_41_ () Int
#     1)
#   (define-fun X_INTRODUCED_32_ () Int
#     0)
#   (define-fun X_INTRODUCED_23_ () Int
#     1)
#   (define-fun S () Int
#     1)
#   (define-fun X_INTRODUCED_3_ () Int
#     1)
#   (define-fun X_INTRODUCED_2_ () Int
#     2)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz1-noAbs/v3/A012-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 0)
# )
# (model
#   (define-fun X_INTRODUCED_5_ () Bool
#     false)
#   (define-fun X_INTRODUCED_22_ () Bool
#     true)
#   (define-fun X_INTRODUCED_8_ () Bool
#     false)
#   (define-fun S () Int
#     0)
#   (define-fun X_INTRODUCED_0_ () Int
#     2)
#   (define-fun X_INTRODUCED_3_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_17_ () Int
#     1)
#   (define-fun X_INTRODUCED_7_ () Bool
#     false)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_6_ () Int
#     1)
#   (define-fun obj () Int
#     0)
#   (define-fun X_INTRODUCED_1_ () Int
#     1)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz1-noAbs/v3/R008-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 1)
# )
# (model
#   (define-fun X_INTRODUCED_188_ () Int
#     0)
#   (define-fun X_INTRODUCED_818_ () Bool
#     false)
#   (define-fun X_INTRODUCED_850_ () Int
#     0)
#   (define-fun X_INTRODUCED_348_ () Bool
#     false)
#   (define-fun X_INTRODUCED_790_ () Bool
#     false)
#   (define-fun X_INTRODUCED_925_ () Bool
#     false)
#   (define-fun X_INTRODUCED_369_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1010_ () Int
#     0)
#   (define-fun X_INTRODUCED_773_ () Bool
#     false)
#   (define-fun X_INTRODUCED_911_ () Int
#     0)
#   (define-fun X_INTRODUCED_985_ () Int
#     0)
#   (define-fun X_INTRODUCED_307_ () Bool
#     false)
#   (define-fun X_INTRODUCED_97_ () Bool
#     false)
#   (define-fun X_INTRODUCED_844_ () Int
#     0)
#   (define-fun X_INTRODUCED_419_ () Int
#     0)
#   (define-fun X_INTRODUCED_164_ () Bool
#     true)
#   (define-fun X_INTRODUCED_910_ () Bool
#     false)
#   (define-fun X_INTRODUCED_168_ () Bool
#     true)
#   (define-fun X_INTRODUCED_917_ () Int
#     0)
#   (define-fun X_INTRODUCED_64_ () Bool
#     false)
#   (define-fun X_INTRODUCED_883_ () Bool
#     false)
#   (define-fun X_INTRODUCED_219_ () Bool
#     true)
#   (define-fun X_INTRODUCED_739_ () Int
#     0)
#   (define-fun X_INTRODUCED_1007_ () Bool
#     false)
#   (define-fun X_INTRODUCED_155_ () Int
#     0)
#   (define-fun X_INTRODUCED_305_ () Int
#     0)
#   (define-fun X_INTRODUCED_967_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1031_ () Bool
#     false)
#   (define-fun X_INTRODUCED_642_ () Bool
#     false)
#   (define-fun X_INTRODUCED_687_ () Bool
#     false)
#   (define-fun X_INTRODUCED_284_ () Int
#     0)
#   (define-fun X_INTRODUCED_718_ () Int
#     0)
#   (define-fun X_INTRODUCED_543_ () Bool
#     false)
#   (define-fun X_INTRODUCED_982_ () Bool
#     false)
#   (define-fun X_INTRODUCED_48_ () Bool
#     false)
#   (define-fun X_INTRODUCED_465_ () Bool
#     false)
#   (define-fun X_INTRODUCED_995_ () Bool
#     false)
#   (define-fun X_INTRODUCED_766_ () Bool
#     false)
#   (define-fun X_INTRODUCED_247_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1041_ () Bool
#     true)
#   (define-fun X_INTRODUCED_490_ () Bool
#     false)
#   (define-fun X_INTRODUCED_620_ () Int
#     0)
#   (define-fun X_INTRODUCED_807_ () Int
#     0)
#   (define-fun X_INTRODUCED_685_ () Int
#     0)
#   (define-fun X_INTRODUCED_954_ () Bool
#     false)
#   (define-fun X_INTRODUCED_472_ () Bool
#     false)
#   (define-fun X_INTRODUCED_535_ () Bool
#     false)
#   (define-fun X_INTRODUCED_563_ () Int
#     0)
#   (define-fun X_INTRODUCED_194_ () Bool
#     true)
#   (define-fun X_INTRODUCED_601_ () Bool
#     false)
#   (define-fun X_INTRODUCED_436_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1016_ () Int
#     1)
#   (define-fun X_INTRODUCED_38_ () Bool
#     false)
#   (define-fun X_INTRODUCED_192_ () Int
#     0)
#   (define-fun X_INTRODUCED_229_ () Int
#     0)
#   (define-fun X_INTRODUCED_442_ () Bool
#     false)
#   (define-fun X_INTRODUCED_515_ () Int
#     0)
#   (define-fun X_INTRODUCED_958_ () Int
#     0)
#   (define-fun X_INTRODUCED_453_ () Bool
#     true)
#   (define-fun X_INTRODUCED_691_ () Int
#     0)
#   (define-fun X_INTRODUCED_317_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1025_ () Bool
#     false)
#   (define-fun X_INTRODUCED_157_ () Bool
#     false)
#   (define-fun X_INTRODUCED_313_ () Bool
#     true)
#   (define-fun X_INTRODUCED_58_ () Bool
#     false)
#   (define-fun X_INTRODUCED_635_ () Int
#     0)
#   (define-fun X_INTRODUCED_484_ () Bool
#     false)
#   (define-fun X_INTRODUCED_111_ () Bool
#     true)
#   (define-fun X_INTRODUCED_647_ () Int
#     0)
#   (define-fun X_INTRODUCED_852_ () Bool
#     false)
#   (define-fun X_INTRODUCED_697_ () Int
#     0)
#   (define-fun X_INTRODUCED_678_ () Bool
#     false)
#   (define-fun X_INTRODUCED_492_ () Int
#     0)
#   (define-fun X_INTRODUCED_259_ () Bool
#     true)
#   (define-fun X_INTRODUCED_990_ () Bool
#     false)
#   (define-fun X_INTRODUCED_552_ () Bool
#     false)
#   (define-fun X_INTRODUCED_788_ () Int
#     0)
#   (define-fun X_INTRODUCED_372_ () Bool
#     false)
#   (define-fun X_INTRODUCED_161_ () Bool
#     true)
#   (define-fun X_INTRODUCED_236_ () Bool
#     false)
#   (define-fun X_INTRODUCED_458_ () Int
#     0)
#   (define-fun X_INTRODUCED_34_ () Bool
#     false)
#   (define-fun X_INTRODUCED_546_ () Bool
#     false)
#   (define-fun X_INTRODUCED_439_ () Bool
#     false)
#   (define-fun X_INTRODUCED_149_ () Bool
#     false)
#   (define-fun X_INTRODUCED_586_ () Bool
#     true)
#   (define-fun X_INTRODUCED_216_ () Int
#     0)
#   (define-fun X_INTRODUCED_336_ () Int
#     0)
#   (define-fun X_INTRODUCED_641_ () Int
#     0)
#   (define-fun X_INTRODUCED_177_ () Bool
#     true)
#   (define-fun X_INTRODUCED_859_ () Bool
#     false)
#   (define-fun X_INTRODUCED_28_ () Bool
#     false)
#   (define-fun X_INTRODUCED_965_ () Bool
#     false)
#   (define-fun X_INTRODUCED_454_ () Bool
#     false)
#   (define-fun X_INTRODUCED_187_ () Bool
#     false)
#   (define-fun X_INTRODUCED_987_ () Int
#     0)
#   (define-fun X_INTRODUCED_389_ () Int
#     0)
#   (define-fun X_INTRODUCED_551_ () Int
#     0)
#   (define-fun X_INTRODUCED_758_ () Bool
#     false)
#   (define-fun X_INTRODUCED_833_ () Bool
#     false)
#   (define-fun X_INTRODUCED_198_ () Bool
#     false)
#   (define-fun X_INTRODUCED_137_ () Int
#     0)
#   (define-fun X_INTRODUCED_265_ () Int
#     0)
#   (define-fun X_INTRODUCED_184_ () Int
#     0)
#   (define-fun X_INTRODUCED_36_ () Bool
#     false)
#   (define-fun X_INTRODUCED_61_ () Bool
#     false)
#   (define-fun X_INTRODUCED_663_ () Int
#     0)
#   (define-fun X_INTRODUCED_360_ () Bool
#     true)
#   (define-fun X_INTRODUCED_362_ () Bool
#     false)
#   (define-fun X_INTRODUCED_978_ () Bool
#     false)
#   (define-fun X_INTRODUCED_789_ () Bool
#     false)
#   (define-fun X_INTRODUCED_456_ () Int
#     0)
#   (define-fun X_INTRODUCED_134_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1027_ () Bool
#     false)
#   (define-fun X_INTRODUCED_503_ () Bool
#     false)
#   (define-fun X_INTRODUCED_280_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1001_ () Bool
#     false)
#   (define-fun X_INTRODUCED_401_ () Bool
#     false)
#   (define-fun X_INTRODUCED_500_ () Bool
#     false)
#   (define-fun X_INTRODUCED_525_ () Bool
#     true)
#   (define-fun X_INTRODUCED_403_ () Bool
#     false)
#   (define-fun X_INTRODUCED_117_ () Int
#     0)
#   (define-fun X_INTRODUCED_315_ () Int
#     0)
#   (define-fun X_INTRODUCED_464_ () Int
#     0)
#   (define-fun X_INTRODUCED_603_ () Bool
#     true)
#   (define-fun X_INTRODUCED_244_ () Bool
#     false)
#   (define-fun X_INTRODUCED_498_ () Int
#     0)
#   (define-fun X_INTRODUCED_489_ () Int
#     0)
#   (define-fun X_INTRODUCED_548_ () Int
#     0)
#   (define-fun X_INTRODUCED_679_ () Int
#     0)
#   (define-fun X_INTRODUCED_203_ () Bool
#     false)
#   (define-fun X_INTRODUCED_299_ () Bool
#     false)
#   (define-fun X_INTRODUCED_945_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1032_ () Int
#     0)
#   (define-fun X_INTRODUCED_756_ () Int
#     0)
#   (define-fun X_INTRODUCED_250_ () Bool
#     false)
#   (define-fun X_INTRODUCED_839_ () Bool
#     false)
#   (define-fun X_INTRODUCED_695_ () Bool
#     false)
#   (define-fun X_INTRODUCED_353_ () Bool
#     true)
#   (define-fun X_INTRODUCED_375_ () Bool
#     true)
#   (define-fun X_INTRODUCED_114_ () Bool
#     true)
#   (define-fun X_INTRODUCED_897_ () Int
#     0)
#   (define-fun X_INTRODUCED_344_ () Int
#     0)
#   (define-fun X_INTRODUCED_312_ () Int
#     0)
#   (define-fun X_INTRODUCED_411_ () Int
#     0)
#   (define-fun X_INTRODUCED_840_ () Int
#     0)
#   (define-fun X_INTRODUCED_266_ () Bool
#     false)
#   (define-fun X_INTRODUCED_230_ () Bool
#     false)
#   (define-fun X_INTRODUCED_726_ () Bool
#     false)
#   (define-fun X_INTRODUCED_127_ () Bool
#     true)
#   (define-fun X_INTRODUCED_416_ () Bool
#     true)
#   (define-fun X_INTRODUCED_511_ () Bool
#     true)
#   (define-fun X_INTRODUCED_578_ () Bool
#     false)
#   (define-fun X_INTRODUCED_376_ () Bool
#     false)
#   (define-fun X_INTRODUCED_567_ () Bool
#     false)
#   (define-fun X_INTRODUCED_643_ () Bool
#     false)
#   (define-fun X_INTRODUCED_823_ () Int
#     0)
#   (define-fun X_INTRODUCED_441_ () Bool
#     true)
#   (define-fun X_INTRODUCED_470_ () Int
#     0)
#   (define-fun X_INTRODUCED_397_ () Int
#     0)
#   (define-fun X_INTRODUCED_228_ () Bool
#     false)
#   (define-fun X_INTRODUCED_445_ () Bool
#     true)
#   (define-fun X_INTRODUCED_598_ () Bool
#     false)
#   (define-fun X_INTRODUCED_993_ () Bool
#     false)
#   (define-fun X_INTRODUCED_644_ () Int
#     0)
#   (define-fun X_INTRODUCED_832_ () Int
#     0)
#   (define-fun X_INTRODUCED_811_ () Bool
#     true)
#   (define-fun X_INTRODUCED_400_ () Bool
#     false)
#   (define-fun X_INTRODUCED_616_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1046_ () Bool
#     false)
#   (define-fun X_INTRODUCED_656_ () Bool
#     false)
#   (define-fun X_INTRODUCED_434_ () Int
#     0)
#   (define-fun X_INTRODUCED_702_ () Bool
#     false)
#   (define-fun X_INTRODUCED_513_ () Int
#     0)
#   (define-fun X_INTRODUCED_286_ () Bool
#     false)
#   (define-fun X_INTRODUCED_688_ () Int
#     0)
#   (define-fun X_INTRODUCED_220_ () Bool
#     false)
#   (define-fun X_INTRODUCED_896_ () Bool
#     false)
#   (define-fun X_INTRODUCED_961_ () Bool
#     false)
#   (define-fun X_INTRODUCED_51_ () Bool
#     false)
#   (define-fun X_INTRODUCED_754_ () Bool
#     false)
#   (define-fun X_INTRODUCED_893_ () Bool
#     false)
#   (define-fun X_INTRODUCED_853_ () Int
#     0)
#   (define-fun X_INTRODUCED_1038_ () Int
#     10)
#   (define-fun X_INTRODUCED_103_ () Int
#     0)
#   (define-fun X_INTRODUCED_862_ () Int
#     0)
#   (define-fun X_INTRODUCED_256_ () Bool
#     false)
#   (define-fun X_INTRODUCED_287_ () Bool
#     true)
#   (define-fun X_INTRODUCED_494_ () Bool
#     false)
#   (define-fun X_INTRODUCED_741_ () Bool
#     false)
#   (define-fun X_INTRODUCED_162_ () Bool
#     false)
#   (define-fun X_INTRODUCED_931_ () Bool
#     false)
#   (define-fun X_INTRODUCED_588_ () Int
#     0)
#   (define-fun X_INTRODUCED_301_ () Int
#     0)
#   (define-fun X_INTRODUCED_638_ () Int
#     0)
#   (define-fun X_INTRODUCED_886_ () Int
#     0)
#   (define-fun X_INTRODUCED_320_ () Int
#     0)
#   (define-fun X_INTRODUCED_866_ () Int
#     0)
#   (define-fun X_INTRODUCED_258_ () Bool
#     false)
#   (define-fun X_INTRODUCED_715_ () Int
#     0)
#   (define-fun X_INTRODUCED_950_ () Int
#     0)
#   (define-fun X_INTRODUCED_996_ () Int
#     0)
#   (define-fun X_INTRODUCED_388_ () Bool
#     false)
#   (define-fun X_INTRODUCED_218_ () Bool
#     false)
#   (define-fun X_INTRODUCED_556_ () Bool
#     false)
#   (define-fun X_INTRODUCED_672_ () Int
#     0)
#   (define-fun X_INTRODUCED_96_ () Bool
#     true)
#   (define-fun X_INTRODUCED_909_ () Int
#     0)
#   (define-fun X_INTRODUCED_424_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1037_ () Int
#     6)
#   (define-fun X_INTRODUCED_880_ () Int
#     0)
#   (define-fun X_INTRODUCED_384_ () Bool
#     false)
#   (define-fun X_INTRODUCED_474_ () Bool
#     true)
#   (define-fun X_INTRODUCED_908_ () Bool
#     false)
#   (define-fun X_INTRODUCED_904_ () Bool
#     false)
#   (define-fun X_INTRODUCED_91_ () Int
#     0)
#   (define-fun X_INTRODUCED_750_ () Int
#     0)
#   (define-fun X_INTRODUCED_504_ () Int
#     0)
#   (define-fun X_INTRODUCED_226_ () Bool
#     false)
#   (define-fun X_INTRODUCED_193_ () Bool
#     false)
#   (define-fun X_INTRODUCED_468_ () Bool
#     true)
#   (define-fun X_INTRODUCED_812_ () Bool
#     false)
#   (define-fun X_INTRODUCED_770_ () Int
#     0)
#   (define-fun X_INTRODUCED_276_ () Bool
#     true)
#   (define-fun X_INTRODUCED_129_ () Int
#     0)
#   (define-fun X_INTRODUCED_653_ () Bool
#     false)
#   (define-fun X_INTRODUCED_414_ () Int
#     0)
#   (define-fun X_INTRODUCED_568_ () Int
#     0)
#   (define-fun X_INTRODUCED_364_ () Bool
#     true)
#   (define-fun X_INTRODUCED_159_ () Int
#     0)
#   (define-fun X_INTRODUCED_167_ () Int
#     0)
#   (define-fun X_INTRODUCED_782_ () Int
#     0)
#   (define-fun X_INTRODUCED_677_ () Bool
#     false)
#   (define-fun X_INTRODUCED_163_ () Int
#     0)
#   (define-fun X_INTRODUCED_418_ () Bool
#     false)
#   (define-fun X_INTRODUCED_608_ () Int
#     0)
#   (define-fun X_INTRODUCED_865_ () Bool
#     false)
#   (define-fun X_INTRODUCED_363_ () Int
#     0)
#   (define-fun X_INTRODUCED_1029_ () Bool
#     true)
#   (define-fun X_INTRODUCED_491_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1018_ () Int
#     1)
#   (define-fun X_INTRODUCED_141_ () Int
#     0)
#   (define-fun X_INTRODUCED_455_ () Bool
#     false)
#   (define-fun X_INTRODUCED_487_ () Bool
#     false)
#   (define-fun X_INTRODUCED_40_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_215_ () Bool
#     false)
#   (define-fun X_INTRODUCED_92_ () Bool
#     false)
#   (define-fun X_INTRODUCED_343_ () Bool
#     false)
#   (define-fun X_INTRODUCED_706_ () Int
#     0)
#   (define-fun X_INTRODUCED_800_ () Bool
#     false)
#   (define-fun X_INTRODUCED_339_ () Bool
#     false)
#   (define-fun X_INTRODUCED_124_ () Bool
#     false)
#   (define-fun X_INTRODUCED_581_ () Bool
#     false)
#   (define-fun X_INTRODUCED_539_ () Bool
#     true)
#   (define-fun X_INTRODUCED_234_ () Bool
#     false)
#   (define-fun X_INTRODUCED_842_ () Int
#     0)
#   (define-fun X_INTRODUCED_700_ () Int
#     0)
#   (define-fun X_INTRODUCED_876_ () Bool
#     false)
#   (define-fun X_INTRODUCED_181_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1047_ () Bool
#     true)
#   (define-fun X_INTRODUCED_224_ () Bool
#     false)
#   (define-fun X_INTRODUCED_675_ () Bool
#     false)
#   (define-fun X_INTRODUCED_576_ () Int
#     0)
#   (define-fun X_INTRODUCED_246_ () Bool
#     false)
#   (define-fun X_INTRODUCED_829_ () Int
#     0)
#   (define-fun X_INTRODUCED_65_ () Int
#     0)
#   (define-fun X_INTRODUCED_1049_ () Bool
#     true)
#   (define-fun X_INTRODUCED_202_ () Bool
#     false)
#   (define-fun X_INTRODUCED_796_ () Int
#     0)
#   (define-fun X_INTRODUCED_575_ () Bool
#     false)
#   (define-fun X_INTRODUCED_145_ () Bool
#     false)
#   (define-fun X_INTRODUCED_835_ () Int
#     0)
#   (define-fun X_INTRODUCED_599_ () Int
#     0)
#   (define-fun X_INTRODUCED_41_ () Bool
#     false)
#   (define-fun X_INTRODUCED_627_ () Bool
#     false)
#   (define-fun X_INTRODUCED_759_ () Int
#     0)
#   (define-fun X_INTRODUCED_2_ () Int
#     18)
#   (define-fun X_INTRODUCED_450_ () Bool
#     false)
#   (define-fun X_INTRODUCED_819_ () Int
#     0)
#   (define-fun X_INTRODUCED_222_ () Bool
#     false)
#   (define-fun X_INTRODUCED_476_ () Int
#     0)
#   (define-fun X_INTRODUCED_67_ () Int
#     0)
#   (define-fun X_INTRODUCED_310_ () Bool
#     false)
#   (define-fun X_INTRODUCED_70_ () Int
#     0)
#   (define-fun X_INTRODUCED_946_ () Int
#     0)
#   (define-fun X_INTRODUCED_412_ () Bool
#     false)
#   (define-fun X_INTRODUCED_5_ () Int
#     2)
#   (define-fun X_INTRODUCED_613_ () Bool
#     false)
#   (define-fun X_INTRODUCED_681_ () Bool
#     false)
#   (define-fun X_INTRODUCED_59_ () Bool
#     false)
#   (define-fun X_INTRODUCED_150_ () Bool
#     false)
#   (define-fun X_INTRODUCED_449_ () Bool
#     true)
#   (define-fun X_INTRODUCED_870_ () Bool
#     false)
#   (define-fun X_INTRODUCED_182_ () Bool
#     false)
#   (define-fun X_INTRODUCED_404_ () Bool
#     false)
#   (define-fun X_INTRODUCED_151_ () Int
#     0)
#   (define-fun X_INTRODUCED_43_ () Bool
#     false)
#   (define-fun X_INTRODUCED_591_ () Int
#     0)
#   (define-fun X_INTRODUCED_968_ () Int
#     0)
#   (define-fun X_INTRODUCED_156_ () Bool
#     true)
#   (define-fun X_INTRODUCED_724_ () Bool
#     false)
#   (define-fun X_INTRODUCED_84_ () Bool
#     true)
#   (define-fun X_INTRODUCED_303_ () Bool
#     false)
#   (define-fun X_INTRODUCED_138_ () Bool
#     true)
#   (define-fun X_INTRODUCED_143_ () Int
#     0)
#   (define-fun X_INTRODUCED_293_ () Int
#     0)
#   (define-fun X_INTRODUCED_122_ () Bool
#     false)
#   (define-fun X_INTRODUCED_762_ () Int
#     0)
#   (define-fun X_INTRODUCED_799_ () Bool
#     false)
#   (define-fun X_INTRODUCED_431_ () Int
#     0)
#   (define-fun X_INTRODUCED_744_ () Bool
#     false)
#   (define-fun X_INTRODUCED_530_ () Int
#     0)
#   (define-fun X_INTRODUCED_197_ () Bool
#     true)
#   (define-fun X_INTRODUCED_86_ () Bool
#     false)
#   (define-fun X_INTRODUCED_680_ () Bool
#     false)
#   (define-fun X_INTRODUCED_374_ () Int
#     0)
#   (define-fun X_INTRODUCED_63_ () Bool
#     false)
#   (define-fun X_INTRODUCED_260_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1003_ () Bool
#     false)
#   (define-fun X_INTRODUCED_696_ () Bool
#     false)
#   (define-fun X_INTRODUCED_989_ () Int
#     0)
#   (define-fun X_INTRODUCED_820_ () Bool
#     false)
#   (define-fun X_INTRODUCED_604_ () Bool
#     false)
#   (define-fun X_INTRODUCED_139_ () Bool
#     false)
#   (define-fun X_INTRODUCED_328_ () Int
#     0)
#   (define-fun X_INTRODUCED_533_ () Int
#     0)
#   (define-fun X_INTRODUCED_479_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1035_ () Int
#     10)
#   (define-fun X_INTRODUCED_448_ () Int
#     0)
#   (define-fun X_INTRODUCED_951_ () Bool
#     false)
#   (define-fun X_INTRODUCED_631_ () Bool
#     false)
#   (define-fun X_INTRODUCED_590_ () Bool
#     false)
#   (define-fun X_INTRODUCED_561_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1044_ () Bool
#     true)
#   (define-fun X_INTRODUCED_342_ () Bool
#     true)
#   (define-fun X_INTRODUCED_612_ () Bool
#     false)
#   (define-fun X_INTRODUCED_45_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_296_ () Bool
#     false)
#   (define-fun X_INTRODUCED_475_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1005_ () Bool
#     false)
#   (define-fun X_INTRODUCED_730_ () Int
#     0)
#   (define-fun X_INTRODUCED_887_ () Bool
#     false)
#   (define-fun X_INTRODUCED_95_ () Int
#     0)
#   (define-fun X_INTRODUCED_304_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1008_ () Int
#     0)
#   (define-fun X_INTRODUCED_841_ () Bool
#     false)
#   (define-fun X_INTRODUCED_264_ () Bool
#     false)
#   (define-fun X_INTRODUCED_391_ () Bool
#     false)
#   (define-fun X_INTRODUCED_126_ () Bool
#     false)
#   (define-fun X_INTRODUCED_520_ () Bool
#     false)
#   (define-fun X_INTRODUCED_572_ () Bool
#     false)
#   (define-fun X_INTRODUCED_322_ () Bool
#     true)
#   (define-fun X_INTRODUCED_869_ () Bool
#     false)
#   (define-fun X_INTRODUCED_806_ () Bool
#     false)
#   (define-fun X_INTRODUCED_508_ () Bool
#     false)
#   (define-fun X_INTRODUCED_521_ () Int
#     0)
#   (define-fun X_INTRODUCED_703_ () Int
#     0)
#   (define-fun X_INTRODUCED_528_ () Bool
#     true)
#   (define-fun X_INTRODUCED_174_ () Bool
#     false)
#   (define-fun X_INTRODUCED_791_ () Int
#     0)
#   (define-fun X_INTRODUCED_793_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Int
#     13)
#   (define-fun X_INTRODUCED_1006_ () Int
#     0)
#   (define-fun X_INTRODUCED_545_ () Int
#     0)
#   (define-fun X_INTRODUCED_102_ () Bool
#     false)
#   (define-fun X_INTRODUCED_755_ () Bool
#     false)
#   (define-fun X_INTRODUCED_640_ () Bool
#     false)
#   (define-fun X_INTRODUCED_338_ () Int
#     0)
#   (define-fun X_INTRODUCED_44_ () Bool
#     false)
#   (define-fun X_INTRODUCED_447_ () Bool
#     false)
#   (define-fun X_INTRODUCED_623_ () Int
#     0)
#   (define-fun X_INTRODUCED_6_ () Int
#     16)
#   (define-fun X_INTRODUCED_269_ () Int
#     0)
#   (define-fun X_INTRODUCED_268_ () Bool
#     false)
#   (define-fun X_INTRODUCED_19_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_983_ () Int
#     0)
#   (define-fun X_INTRODUCED_366_ () Bool
#     false)
#   (define-fun X_INTRODUCED_723_ () Int
#     0)
#   (define-fun X_INTRODUCED_955_ () Int
#     0)
#   (define-fun X_INTRODUCED_1052_ () Bool
#     true)
#   (define-fun X_INTRODUCED_352_ () Bool
#     false)
#   (define-fun X_INTRODUCED_710_ () Bool
#     false)
#   (define-fun X_INTRODUCED_128_ () Bool
#     false)
#   (define-fun X_INTRODUCED_481_ () Int
#     0)
#   (define-fun X_INTRODUCED_919_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1043_ () Bool
#     false)
#   (define-fun X_INTRODUCED_779_ () Int
#     0)
#   (define-fun X_INTRODUCED_891_ () Int
#     0)
#   (define-fun X_INTRODUCED_281_ () Int
#     0)
#   (define-fun X_INTRODUCED_271_ () Bool
#     true)
#   (define-fun X_INTRODUCED_630_ () Bool
#     false)
#   (define-fun X_INTRODUCED_856_ () Int
#     0)
#   (define-fun X_INTRODUCED_225_ () Int
#     0)
#   (define-fun X_INTRODUCED_649_ () Bool
#     false)
#   (define-fun X_INTRODUCED_68_ () Int
#     0)
#   (define-fun X_INTRODUCED_66_ () Int
#     0)
#   (define-fun X_INTRODUCED_708_ () Bool
#     false)
#   (define-fun X_INTRODUCED_275_ () Int
#     0)
#   (define-fun X_INTRODUCED_399_ () Int
#     0)
#   (define-fun X_INTRODUCED_25_ () Int
#     1)
#   (define-fun X_INTRODUCED_237_ () Int
#     0)
#   (define-fun X_INTRODUCED_413_ () Bool
#     false)
#   (define-fun X_INTRODUCED_279_ () Bool
#     true)
#   (define-fun X_INTRODUCED_319_ () Bool
#     false)
#   (define-fun X_INTRODUCED_499_ () Bool
#     false)
#   (define-fun X_INTRODUCED_433_ () Bool
#     false)
#   (define-fun X_INTRODUCED_356_ () Bool
#     true)
#   (define-fun X_INTRODUCED_738_ () Bool
#     false)
#   (define-fun X_INTRODUCED_104_ () Bool
#     true)
#   (define-fun X_INTRODUCED_764_ () Bool
#     false)
#   (define-fun X_INTRODUCED_206_ () Bool
#     false)
#   (define-fun X_INTRODUCED_308_ () Bool
#     false)
#   (define-fun X_INTRODUCED_263_ () Bool
#     true)
#   (define-fun X_INTRODUCED_39_ () Bool
#     false)
#   (define-fun X_INTRODUCED_558_ () Bool
#     false)
#   (define-fun X_INTRODUCED_761_ () Bool
#     false)
#   (define-fun X_INTRODUCED_541_ () Int
#     0)
#   (define-fun X_INTRODUCED_349_ () Bool
#     false)
#   (define-fun X_INTRODUCED_407_ () Bool
#     false)
#   (define-fun X_INTRODUCED_463_ () Bool
#     false)
#   (define-fun X_INTRODUCED_243_ () Bool
#     false)
#   (define-fun X_INTRODUCED_334_ () Bool
#     false)
#   (define-fun X_INTRODUCED_427_ () Int
#     0)
#   (define-fun X_INTRODUCED_309_ () Int
#     0)
#   (define-fun X_INTRODUCED_714_ () Bool
#     false)
#   (define-fun X_INTRODUCED_783_ () Bool
#     false)
#   (define-fun X_INTRODUCED_288_ () Bool
#     false)
#   (define-fun X_INTRODUCED_830_ () Bool
#     false)
#   (define-fun X_INTRODUCED_385_ () Int
#     0)
#   (define-fun X_INTRODUCED_71_ () Int
#     0)
#   (define-fun X_INTRODUCED_717_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1004_ () Int
#     0)
#   (define-fun X_INTRODUCED_359_ () Int
#     0)
#   (define-fun X_INTRODUCED_798_ () Int
#     0)
#   (define-fun X_INTRODUCED_175_ () Int
#     0)
#   (define-fun X_INTRODUCED_396_ () Bool
#     false)
#   (define-fun X_INTRODUCED_671_ () Bool
#     false)
#   (define-fun X_INTRODUCED_311_ () Bool
#     false)
#   (define-fun X_INTRODUCED_329_ () Bool
#     true)
#   (define-fun X_INTRODUCED_960_ () Int
#     0)
#   (define-fun X_INTRODUCED_654_ () Int
#     0)
#   (define-fun X_INTRODUCED_507_ () Bool
#     true)
#   (define-fun X_INTRODUCED_290_ () Bool
#     false)
#   (define-fun X_INTRODUCED_947_ () Bool
#     false)
#   (define-fun X_INTRODUCED_221_ () Int
#     0)
#   (define-fun X_INTRODUCED_267_ () Bool
#     true)
#   (define-fun X_INTRODUCED_493_ () Bool
#     true)
#   (define-fun X_INTRODUCED_332_ () Int
#     0)
#   (define-fun X_INTRODUCED_211_ () Bool
#     true)
#   (define-fun X_INTRODUCED_190_ () Bool
#     false)
#   (define-fun X_INTRODUCED_231_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1022_ () Int
#     0)
#   (define-fun X_INTRODUCED_970_ () Int
#     0)
#   (define-fun X_INTRODUCED_794_ () Int
#     0)
#   (define-fun X_INTRODUCED_440_ () Int
#     0)
#   (define-fun X_INTRODUCED_1053_ () Bool
#     false)
#   (define-fun X_INTRODUCED_689_ () Bool
#     false)
#   (define-fun X_INTRODUCED_173_ () Bool
#     false)
#   (define-fun X_INTRODUCED_976_ () Bool
#     false)
#   (define-fun X_INTRODUCED_55_ () Int
#     1)
#   (define-fun X_INTRODUCED_804_ () Int
#     0)
#   (define-fun X_INTRODUCED_765_ () Int
#     0)
#   (define-fun X_INTRODUCED_3_ () Int
#     10)
#   (define-fun X_INTRODUCED_966_ () Int
#     0)
#   (define-fun X_INTRODUCED_298_ () Bool
#     true)
#   (define-fun X_INTRODUCED_438_ () Bool
#     true)
#   (define-fun X_INTRODUCED_778_ () Bool
#     false)
#   (define-fun X_INTRODUCED_4_ () Int
#     6)
#   (define-fun X_INTRODUCED_76_ () Bool
#     false)
#   (define-fun X_INTRODUCED_776_ () Int
#     0)
#   (define-fun X_INTRODUCED_330_ () Bool
#     false)
#   (define-fun X_INTRODUCED_373_ () Bool
#     false)
#   (define-fun X_INTRODUCED_899_ () Int
#     0)
#   (define-fun X_INTRODUCED_650_ () Bool
#     false)
#   (define-fun X_INTRODUCED_861_ () Bool
#     false)
#   (define-fun X_INTRODUCED_101_ () Bool
#     false)
#   (define-fun X_INTRODUCED_119_ () Bool
#     false)
#   (define-fun X_INTRODUCED_523_ () Bool
#     false)
#   (define-fun X_INTRODUCED_963_ () Bool
#     false)
#   (define-fun X_INTRODUCED_614_ () Int
#     0)
#   (define-fun X_INTRODUCED_926_ () Int
#     0)
#   (define-fun X_INTRODUCED_1021_ () Bool
#     false)
#   (define-fun X_INTRODUCED_787_ () Bool
#     false)
#   (define-fun X_INTRODUCED_510_ () Bool
#     false)
#   (define-fun X_INTRODUCED_646_ () Bool
#     false)
#   (define-fun X_INTRODUCED_574_ () Bool
#     true)
#   (define-fun X_INTRODUCED_813_ () Int
#     0)
#   (define-fun X_INTRODUCED_585_ () Int
#     0)
#   (define-fun X_INTRODUCED_690_ () Bool
#     false)
#   (define-fun X_INTRODUCED_323_ () Bool
#     false)
#   (define-fun X_INTRODUCED_340_ () Bool
#     false)
#   (define-fun X_INTRODUCED_920_ () Int
#     0)
#   (define-fun X_INTRODUCED_727_ () Int
#     0)
#   (define-fun X_INTRODUCED_874_ () Int
#     0)
#   (define-fun X_INTRODUCED_864_ () Int
#     0)
#   (define-fun X_INTRODUCED_894_ () Int
#     0)
#   (define-fun X_INTRODUCED_361_ () Bool
#     false)
#   (define-fun X_INTRODUCED_488_ () Bool
#     false)
#   (define-fun X_INTRODUCED_948_ () Int
#     0)
#   (define-fun X_INTRODUCED_426_ () Bool
#     false)
#   (define-fun X_INTRODUCED_801_ () Int
#     0)
#   (define-fun X_INTRODUCED_875_ () Bool
#     false)
#   (define-fun X_INTRODUCED_752_ () Bool
#     false)
#   (define-fun X_INTRODUCED_849_ () Bool
#     false)
#   (define-fun X_INTRODUCED_879_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1055_ () Bool
#     true)
#   (define-fun X_INTRODUCED_89_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1050_ () Bool
#     false)
#   (define-fun X_INTRODUCED_497_ () Bool
#     false)
#   (define-fun X_INTRODUCED_587_ () Bool
#     false)
#   (define-fun X_INTRODUCED_432_ () Bool
#     true)
#   (define-fun X_INTRODUCED_435_ () Bool
#     true)
#   (define-fun X_INTRODUCED_529_ () Bool
#     false)
#   (define-fun X_INTRODUCED_610_ () Bool
#     false)
#   (define-fun X_INTRODUCED_553_ () Bool
#     false)
#   (define-fun X_INTRODUCED_559_ () Bool
#     false)
#   (define-fun X_INTRODUCED_273_ () Int
#     0)
#   (define-fun X_INTRODUCED_757_ () Bool
#     false)
#   (define-fun X_INTRODUCED_600_ () Bool
#     false)
#   (define-fun X_INTRODUCED_60_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_380_ () Int
#     0)
#   (define-fun X_INTRODUCED_554_ () Int
#     0)
#   (define-fun X_INTRODUCED_386_ () Bool
#     true)
#   (define-fun X_INTRODUCED_936_ () Int
#     0)
#   (define-fun X_INTRODUCED_665_ () Bool
#     false)
#   (define-fun X_INTRODUCED_784_ () Bool
#     false)
#   (define-fun X_INTRODUCED_822_ () Bool
#     false)
#   (define-fun X_INTRODUCED_767_ () Bool
#     false)
#   (define-fun X_INTRODUCED_100_ () Bool
#     true)
#   (define-fun X_INTRODUCED_538_ () Bool
#     false)
#   (define-fun X_INTRODUCED_815_ () Int
#     0)
#   (define-fun X_INTRODUCED_625_ () Bool
#     false)
#   (define-fun X_INTRODUCED_602_ () Int
#     0)
#   (define-fun X_INTRODUCED_223_ () Bool
#     true)
#   (define-fun X_INTRODUCED_943_ () Bool
#     false)
#   (define-fun X_INTRODUCED_240_ () Bool
#     false)
#   (define-fun X_INTRODUCED_882_ () Int
#     0)
#   (define-fun X_INTRODUCED_637_ () Bool
#     false)
#   (define-fun X_INTRODUCED_657_ () Int
#     0)
#   (define-fun obj () Int
#     1)
#   (define-fun X_INTRODUCED_254_ () Bool
#     false)
#   (define-fun X_INTRODUCED_460_ () Bool
#     false)
#   (define-fun X_INTRODUCED_509_ () Int
#     0)
#   (define-fun X_INTRODUCED_451_ () Bool
#     false)
#   (define-fun X_INTRODUCED_78_ () Bool
#     false)
#   (define-fun X_INTRODUCED_248_ () Int
#     0)
#   (define-fun X_INTRODUCED_712_ () Int
#     0)
#   (define-fun X_INTRODUCED_1026_ () Int
#     0)
#   (define-fun X_INTRODUCED_944_ () Int
#     0)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_29_ () Bool
#     false)
#   (define-fun X_INTRODUCED_115_ () Bool
#     false)
#   (define-fun X_INTRODUCED_327_ () Bool
#     false)
#   (define-fun X_INTRODUCED_429_ () Bool
#     true)
#   (define-fun X_INTRODUCED_934_ () Bool
#     false)
#   (define-fun X_INTRODUCED_135_ () Bool
#     false)
#   (define-fun X_INTRODUCED_210_ () Int
#     0)
#   (define-fun X_INTRODUCED_871_ () Int
#     0)
#   (define-fun X_INTRODUCED_831_ () Bool
#     false)
#   (define-fun X_INTRODUCED_877_ () Int
#     0)
#   (define-fun X_INTRODUCED_1030_ () Int
#     1)
#   (define-fun X_INTRODUCED_583_ () Bool
#     true)
#   (define-fun X_INTRODUCED_662_ () Bool
#     false)
#   (define-fun X_INTRODUCED_929_ () Bool
#     false)
#   (define-fun X_INTRODUCED_443_ () Int
#     0)
#   (define-fun X_INTRODUCED_629_ () Int
#     0)
#   (define-fun X_INTRODUCED_1002_ () Int
#     0)
#   (define-fun X_INTRODUCED_300_ () Bool
#     false)
#   (define-fun X_INTRODUCED_816_ () Bool
#     false)
#   (define-fun X_INTRODUCED_282_ () Bool
#     false)
#   (define-fun X_INTRODUCED_291_ () Bool
#     true)
#   (define-fun X_INTRODUCED_544_ () Bool
#     false)
#   (define-fun X_INTRODUCED_732_ () Bool
#     false)
#   (define-fun X_INTRODUCED_932_ () Bool
#     false)
#   (define-fun X_INTRODUCED_358_ () Bool
#     false)
#   (define-fun X_INTRODUCED_459_ () Bool
#     true)
#   (define-fun X_INTRODUCED_763_ () Bool
#     false)
#   (define-fun X_INTRODUCED_169_ () Bool
#     false)
#   (define-fun X_INTRODUCED_105_ () Bool
#     false)
#   (define-fun X_INTRODUCED_49_ () Bool
#     false)
#   (define-fun X_INTRODUCED_736_ () Int
#     0)
#   (define-fun X_INTRODUCED_251_ () Bool
#     true)
#   (define-fun X_INTRODUCED_245_ () Int
#     0)
#   (define-fun X_INTRODUCED_467_ () Int
#     0)
#   (define-fun X_INTRODUCED_132_ () Bool
#     false)
#   (define-fun X_INTRODUCED_986_ () Bool
#     false)
#   (define-fun X_INTRODUCED_153_ () Bool
#     false)
#   (define-fun X_INTRODUCED_597_ () Bool
#     false)
#   (define-fun X_INTRODUCED_495_ () Int
#     0)
#   (define-fun X_INTRODUCED_527_ () Int
#     0)
#   (define-fun X_INTRODUCED_196_ () Int
#     0)
#   (define-fun X_INTRODUCED_295_ () Bool
#     false)
#   (define-fun X_INTRODUCED_768_ () Int
#     0)
#   (define-fun X_INTRODUCED_235_ () Bool
#     true)
#   (define-fun X_INTRODUCED_158_ () Bool
#     false)
#   (define-fun X_INTRODUCED_516_ () Bool
#     true)
#   (define-fun X_INTRODUCED_466_ () Bool
#     false)
#   (define-fun X_INTRODUCED_858_ () Int
#     0)
#   (define-fun X_INTRODUCED_346_ () Bool
#     false)
#   (define-fun X_INTRODUCED_615_ () Bool
#     true)
#   (define-fun X_INTRODUCED_906_ () Bool
#     false)
#   (define-fun X_INTRODUCED_88_ () Bool
#     false)
#   (define-fun X_INTRODUCED_350_ () Int
#     0)
#   (define-fun X_INTRODUCED_378_ () Bool
#     true)
#   (define-fun X_INTRODUCED_387_ () Bool
#     false)
#   (define-fun X_INTRODUCED_938_ () Int
#     0)
#   (define-fun X_INTRODUCED_421_ () Bool
#     false)
#   (define-fun X_INTRODUCED_975_ () Int
#     0)
#   (define-fun X_INTRODUCED_797_ () Bool
#     false)
#   (define-fun X_INTRODUCED_257_ () Int
#     0)
#   (define-fun X_INTRODUCED_90_ () Bool
#     false)
#   (define-fun X_INTRODUCED_113_ () Int
#     0)
#   (define-fun X_INTRODUCED_501_ () Int
#     0)
#   (define-fun X_INTRODUCED_845_ () Bool
#     false)
#   (define-fun X_INTRODUCED_270_ () Bool
#     false)
#   (define-fun X_INTRODUCED_935_ () Bool
#     false)
#   (define-fun X_INTRODUCED_106_ () Bool
#     false)
#   (define-fun X_INTRODUCED_659_ () Bool
#     false)
#   (define-fun X_INTRODUCED_971_ () Bool
#     false)
#   (define-fun X_INTRODUCED_683_ () Bool
#     false)
#   (define-fun X_INTRODUCED_900_ () Bool
#     false)
#   (define-fun X_INTRODUCED_834_ () Bool
#     false)
#   (define-fun X_INTRODUCED_980_ () Bool
#     false)
#   (define-fun X_INTRODUCED_540_ () Bool
#     false)
#   (define-fun X_INTRODUCED_107_ () Int
#     0)
#   (define-fun X_INTRODUCED_979_ () Int
#     0)
#   (define-fun X_INTRODUCED_1028_ () Int
#     0)
#   (define-fun X_INTRODUCED_425_ () Bool
#     false)
#   (define-fun X_INTRODUCED_619_ () Bool
#     false)
#   (define-fun X_INTRODUCED_720_ () Bool
#     false)
#   (define-fun X_INTRODUCED_991_ () Int
#     0)
#   (define-fun X_INTRODUCED_760_ () Bool
#     false)
#   (define-fun X_INTRODUCED_555_ () Bool
#     false)
#   (define-fun X_INTRODUCED_262_ () Bool
#     false)
#   (define-fun X_INTRODUCED_98_ () Bool
#     false)
#   (define-fun X_INTRODUCED_292_ () Bool
#     false)
#   (define-fun X_INTRODUCED_838_ () Int
#     0)
#   (define-fun X_INTRODUCED_395_ () Bool
#     false)
#   (define-fun X_INTRODUCED_933_ () Int
#     0)
#   (define-fun X_INTRODUCED_721_ () Int
#     0)
#   (define-fun X_INTRODUCED_594_ () Int
#     0)
#   (define-fun X_INTRODUCED_166_ () Bool
#     false)
#   (define-fun X_INTRODUCED_522_ () Bool
#     false)
#   (define-fun X_INTRODUCED_827_ () Bool
#     false)
#   (define-fun X_INTRODUCED_928_ () Int
#     0)
#   (define-fun X_INTRODUCED_803_ () Bool
#     false)
#   (define-fun X_INTRODUCED_253_ () Int
#     0)
#   (define-fun X_INTRODUCED_238_ () Bool
#     false)
#   (define-fun X_INTRODUCED_810_ () Int
#     0)
#   (define-fun X_INTRODUCED_969_ () Bool
#     false)
#   (define-fun X_INTRODUCED_589_ () Bool
#     false)
#   (define-fun X_INTRODUCED_890_ () Bool
#     false)
#   (define-fun X_INTRODUCED_170_ () Bool
#     false)
#   (define-fun X_INTRODUCED_863_ () Bool
#     false)
#   (define-fun X_INTRODUCED_408_ () Int
#     0)
#   (define-fun X_INTRODUCED_550_ () Bool
#     false)
#   (define-fun X_INTRODUCED_536_ () Int
#     0)
#   (define-fun X_INTRODUCED_907_ () Int
#     0)
#   (define-fun X_INTRODUCED_185_ () Bool
#     true)
#   (define-fun X_INTRODUCED_24_ () Bool
#     false)
#   (define-fun X_INTRODUCED_136_ () Bool
#     false)
#   (define-fun X_INTRODUCED_294_ () Bool
#     true)
#   (define-fun X_INTRODUCED_69_ () Int
#     0)
#   (define-fun X_INTRODUCED_99_ () Int
#     0)
#   (define-fun X_INTRODUCED_1023_ () Bool
#     false)
#   (define-fun X_INTRODUCED_204_ () Int
#     0)
#   (define-fun X_INTRODUCED_0_ () Int
#     8)
#   (define-fun X_INTRODUCED_632_ () Int
#     0)
#   (define-fun X_INTRODUCED_423_ () Int
#     0)
#   (define-fun X_INTRODUCED_160_ () Bool
#     false)
#   (define-fun X_INTRODUCED_131_ () Bool
#     false)
#   (define-fun X_INTRODUCED_661_ () Bool
#     false)
#   (define-fun X_INTRODUCED_133_ () Int
#     0)
#   (define-fun X_INTRODUCED_742_ () Int
#     0)
#   (define-fun X_INTRODUCED_406_ () Bool
#     false)
#   (define-fun X_INTRODUCED_94_ () Bool
#     false)
#   (define-fun X_INTRODUCED_171_ () Int
#     0)
#   (define-fun X_INTRODUCED_430_ () Bool
#     false)
#   (define-fun X_INTRODUCED_565_ () Bool
#     false)
#   (define-fun X_INTRODUCED_354_ () Bool
#     false)
#   (define-fun X_INTRODUCED_607_ () Bool
#     false)
#   (define-fun X_INTRODUCED_333_ () Bool
#     true)
#   (define-fun X_INTRODUCED_255_ () Bool
#     true)
#   (define-fun X_INTRODUCED_884_ () Int
#     0)
#   (define-fun X_INTRODUCED_885_ () Bool
#     false)
#   (define-fun X_INTRODUCED_85_ () Bool
#     false)
#   (define-fun X_INTRODUCED_302_ () Bool
#     true)
#   (define-fun X_INTRODUCED_382_ () Bool
#     false)
#   (define-fun X_INTRODUCED_666_ () Int
#     0)
#   (define-fun X_INTRODUCED_420_ () Bool
#     true)
#   (define-fun X_INTRODUCED_795_ () Bool
#     false)
#   (define-fun X_INTRODUCED_50_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_694_ () Int
#     0)
#   (define-fun X_INTRODUCED_482_ () Bool
#     false)
#   (define-fun X_INTRODUCED_195_ () Bool
#     false)
#   (define-fun X_INTRODUCED_566_ () Bool
#     true)
#   (define-fun X_INTRODUCED_562_ () Bool
#     false)
#   (define-fun X_INTRODUCED_711_ () Bool
#     false)
#   (define-fun X_INTRODUCED_843_ () Bool
#     false)
#   (define-fun X_INTRODUCED_110_ () Bool
#     false)
#   (define-fun X_INTRODUCED_786_ () Bool
#     false)
#   (define-fun X_INTRODUCED_634_ () Bool
#     false)
#   (define-fun X_INTRODUCED_959_ () Bool
#     false)
#   (define-fun X_INTRODUCED_232_ () Bool
#     false)
#   (define-fun X_INTRODUCED_365_ () Bool
#     false)
#   (define-fun X_INTRODUCED_409_ () Bool
#     false)
#   (define-fun X_INTRODUCED_252_ () Bool
#     false)
#   (define-fun X_INTRODUCED_674_ () Int
#     0)
#   (define-fun X_INTRODUCED_881_ () Bool
#     false)
#   (define-fun X_INTRODUCED_81_ () Bool
#     false)
#   (define-fun X_INTRODUCED_417_ () Bool
#     false)
#   (define-fun X_INTRODUCED_618_ () Bool
#     true)
#   (define-fun X_INTRODUCED_645_ () Bool
#     false)
#   (define-fun X_INTRODUCED_846_ () Bool
#     false)
#   (define-fun X_INTRODUCED_669_ () Int
#     0)
#   (define-fun X_INTRODUCED_233_ () Int
#     0)
#   (define-fun X_INTRODUCED_272_ () Bool
#     false)
#   (define-fun X_INTRODUCED_178_ () Bool
#     false)
#   (define-fun X_INTRODUCED_579_ () Int
#     0)
#   (define-fun X_INTRODUCED_496_ () Bool
#     false)
#   (define-fun X_INTRODUCED_785_ () Int
#     0)
#   (define-fun X_INTRODUCED_116_ () Bool
#     false)
#   (define-fun X_INTRODUCED_212_ () Bool
#     false)
#   (define-fun X_INTRODUCED_651_ () Int
#     0)
#   (define-fun X_INTRODUCED_903_ () Int
#     0)
#   (define-fun X_INTRODUCED_611_ () Int
#     0)
#   (define-fun X_INTRODUCED_584_ () Bool
#     false)
#   (define-fun X_INTRODUCED_394_ () Bool
#     true)
#   (define-fun X_INTRODUCED_998_ () Int
#     0)
#   (define-fun X_INTRODUCED_502_ () Bool
#     false)
#   (define-fun X_INTRODUCED_751_ () Bool
#     false)
#   (define-fun X_INTRODUCED_684_ () Bool
#     false)
#   (define-fun X_INTRODUCED_297_ () Int
#     0)
#   (define-fun X_INTRODUCED_191_ () Bool
#     false)
#   (define-fun X_INTRODUCED_200_ () Int
#     0)
#   (define-fun X_INTRODUCED_693_ () Bool
#     false)
#   (define-fun X_INTRODUCED_393_ () Int
#     0)
#   (define-fun X_INTRODUCED_749_ () Bool
#     false)
#   (define-fun X_INTRODUCED_154_ () Bool
#     false)
#   (define-fun X_INTRODUCED_923_ () Bool
#     false)
#   (define-fun X_INTRODUCED_957_ () Bool
#     false)
#   (define-fun X_INTRODUCED_964_ () Int
#     0)
#   (define-fun X_INTRODUCED_753_ () Int
#     0)
#   (define-fun X_INTRODUCED_410_ () Bool
#     false)
#   (define-fun X_INTRODUCED_140_ () Bool
#     false)
#   (define-fun X_INTRODUCED_609_ () Bool
#     false)
#   (define-fun X_INTRODUCED_208_ () Int
#     0)
#   (define-fun X_INTRODUCED_524_ () Int
#     0)
#   (define-fun X_INTRODUCED_593_ () Bool
#     false)
#   (define-fun X_INTRODUCED_512_ () Bool
#     false)
#   (define-fun X_INTRODUCED_997_ () Bool
#     false)
#   (define-fun X_INTRODUCED_914_ () Int
#     0)
#   (define-fun X_INTRODUCED_660_ () Int
#     0)
#   (define-fun X_INTRODUCED_462_ () Bool
#     true)
#   (define-fun X_INTRODUCED_377_ () Int
#     0)
#   (define-fun X_INTRODUCED_33_ () Bool
#     false)
#   (define-fun X_INTRODUCED_912_ () Bool
#     true)
#   (define-fun X_INTRODUCED_577_ () Bool
#     false)
#   (define-fun X_INTRODUCED_324_ () Int
#     0)
#   (define-fun X_INTRODUCED_335_ () Bool
#     false)
#   (define-fun X_INTRODUCED_357_ () Bool
#     false)
#   (define-fun X_INTRODUCED_868_ () Int
#     0)
#   (define-fun X_INTRODUCED_847_ () Int
#     0)
#   (define-fun X_INTRODUCED_692_ () Bool
#     false)
#   (define-fun X_INTRODUCED_837_ () Bool
#     false)
#   (define-fun M () Int
#     0)
#   (define-fun X_INTRODUCED_519_ () Bool
#     true)
#   (define-fun X_INTRODUCED_82_ () Bool
#     false)
#   (define-fun X_INTRODUCED_617_ () Int
#     0)
#   (define-fun X_INTRODUCED_668_ () Bool
#     false)
#   (define-fun X_INTRODUCED_383_ () Bool
#     true)
#   (define-fun X_INTRODUCED_628_ () Bool
#     false)
#   (define-fun X_INTRODUCED_326_ () Bool
#     false)
#   (define-fun X_INTRODUCED_321_ () Bool
#     false)
#   (define-fun X_INTRODUCED_392_ () Bool
#     false)
#   (define-fun X_INTRODUCED_825_ () Bool
#     false)
#   (define-fun X_INTRODUCED_855_ () Bool
#     false)
#   (define-fun X_INTRODUCED_8_ () Int
#     12)
#   (define-fun X_INTRODUCED_709_ () Int
#     0)
#   (define-fun X_INTRODUCED_942_ () Int
#     0)
#   (define-fun X_INTRODUCED_580_ () Bool
#     true)
#   (define-fun X_INTRODUCED_924_ () Int
#     0)
#   (define-fun X_INTRODUCED_1000_ () Int
#     0)
#   (define-fun X_INTRODUCED_658_ () Bool
#     false)
#   (define-fun X_INTRODUCED_370_ () Bool
#     false)
#   (define-fun X_INTRODUCED_152_ () Bool
#     true)
#   (define-fun X_INTRODUCED_405_ () Int
#     0)
#   (define-fun X_INTRODUCED_902_ () Bool
#     false)
#   (define-fun X_INTRODUCED_941_ () Bool
#     false)
#   (define-fun X_INTRODUCED_921_ () Bool
#     false)
#   (define-fun X_INTRODUCED_735_ () Bool
#     false)
#   (define-fun X_INTRODUCED_972_ () Bool
#     false)
#   (define-fun X_INTRODUCED_922_ () Int
#     0)
#   (define-fun X_INTRODUCED_1056_ () Bool
#     false)
#   (define-fun X_INTRODUCED_939_ () Bool
#     false)
#   (define-fun X_INTRODUCED_23_ () Bool
#     false)
#   (define-fun X_INTRODUCED_733_ () Int
#     0)
#   (define-fun X_INTRODUCED_283_ () Bool
#     false)
#   (define-fun X_INTRODUCED_53_ () Bool
#     false)
#   (define-fun X_INTRODUCED_93_ () Bool
#     true)
#   (define-fun X_INTRODUCED_371_ () Int
#     0)
#   (define-fun X_INTRODUCED_1014_ () Int
#     1)
#   (define-fun X_INTRODUCED_46_ () Bool
#     false)
#   (define-fun X_INTRODUCED_478_ () Bool
#     false)
#   (define-fun X_INTRODUCED_729_ () Bool
#     false)
#   (define-fun X_INTRODUCED_241_ () Int
#     0)
#   (define-fun X_INTRODUCED_199_ () Bool
#     false)
#   (define-fun X_INTRODUCED_867_ () Bool
#     false)
#   (define-fun X_INTRODUCED_172_ () Bool
#     true)
#   (define-fun X_INTRODUCED_705_ () Bool
#     false)
#   (define-fun X_INTRODUCED_422_ () Bool
#     false)
#   (define-fun X_INTRODUCED_771_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1_ () Int
#     3)
#   (define-fun X_INTRODUCED_873_ () Bool
#     false)
#   (define-fun X_INTRODUCED_984_ () Bool
#     false)
#   (define-fun X_INTRODUCED_379_ () Bool
#     false)
#   (define-fun X_INTRODUCED_592_ () Bool
#     false)
#   (define-fun X_INTRODUCED_214_ () Bool
#     true)
#   (define-fun X_INTRODUCED_83_ () Int
#     0)
#   (define-fun X_INTRODUCED_1040_ () Bool
#     false)
#   (define-fun X_INTRODUCED_582_ () Int
#     0)
#   (define-fun X_INTRODUCED_774_ () Int
#     0)
#   (define-fun X_INTRODUCED_123_ () Bool
#     true)
#   (define-fun X_INTRODUCED_506_ () Bool
#     false)
#   (define-fun X_INTRODUCED_73_ () Int
#     0)
#   (define-fun X_INTRODUCED_973_ () Int
#     0)
#   (define-fun X_INTRODUCED_560_ () Int
#     0)
#   (define-fun X_INTRODUCED_826_ () Int
#     0)
#   (define-fun X_INTRODUCED_571_ () Bool
#     true)
#   (define-fun X_INTRODUCED_446_ () Bool
#     false)
#   (define-fun X_INTRODUCED_120_ () Bool
#     false)
#   (define-fun X_INTRODUCED_367_ () Int
#     0)
#   (define-fun X_INTRODUCED_988_ () Bool
#     false)
#   (define-fun X_INTRODUCED_347_ () Int
#     0)
#   (define-fun X_INTRODUCED_205_ () Bool
#     true)
#   (define-fun X_INTRODUCED_186_ () Bool
#     false)
#   (define-fun X_INTRODUCED_239_ () Bool
#     true)
#   (define-fun X_INTRODUCED_437_ () Int
#     0)
#   (define-fun X_INTRODUCED_452_ () Int
#     0)
#   (define-fun X_INTRODUCED_745_ () Int
#     0)
#   (define-fun X_INTRODUCED_314_ () Bool
#     false)
#   (define-fun X_INTRODUCED_605_ () Int
#     0)
#   (define-fun X_INTRODUCED_809_ () Bool
#     false)
#   (define-fun X_INTRODUCED_118_ () Bool
#     true)
#   (define-fun X_INTRODUCED_872_ () Bool
#     false)
#   (define-fun X_INTRODUCED_480_ () Bool
#     false)
#   (define-fun X_INTRODUCED_994_ () Int
#     0)
#   (define-fun X_INTRODUCED_534_ () Bool
#     false)
#   (define-fun X_INTRODUCED_802_ () Bool
#     false)
#   (define-fun X_INTRODUCED_345_ () Bool
#     false)
#   (define-fun X_INTRODUCED_952_ () Int
#     0)
#   (define-fun X_INTRODUCED_962_ () Int
#     0)
#   (define-fun X_INTRODUCED_1036_ () Int
#     16)
#   (define-fun X_INTRODUCED_905_ () Int
#     0)
#   (define-fun X_INTRODUCED_183_ () Bool
#     false)
#   (define-fun X_INTRODUCED_913_ () Bool
#     false)
#   (define-fun X_INTRODUCED_888_ () Int
#     0)
#   (define-fun X_INTRODUCED_277_ () Bool
#     false)
#   (define-fun X_INTRODUCED_35_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_26_ () Bool
#     false)
#   (define-fun X_INTRODUCED_949_ () Bool
#     false)
#   (define-fun X_INTRODUCED_30_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_56_ () Bool
#     false)
#   (define-fun X_INTRODUCED_821_ () Int
#     0)
#   (define-fun X_INTRODUCED_570_ () Int
#     0)
#   (define-fun X_INTRODUCED_469_ () Bool
#     false)
#   (define-fun X_INTRODUCED_517_ () Bool
#     false)
#   (define-fun X_INTRODUCED_261_ () Int
#     0)
#   (define-fun X_INTRODUCED_77_ () Bool
#     true)
#   (define-fun X_INTRODUCED_390_ () Bool
#     true)
#   (define-fun X_INTRODUCED_483_ () Bool
#     true)
#   (define-fun X_INTRODUCED_532_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1024_ () Int
#     0)
#   (define-fun X_INTRODUCED_531_ () Bool
#     true)
#   (define-fun X_INTRODUCED_547_ () Bool
#     false)
#   (define-fun X_INTRODUCED_699_ () Bool
#     false)
#   (define-fun X_INTRODUCED_999_ () Bool
#     false)
#   (define-fun X_INTRODUCED_289_ () Int
#     0)
#   (define-fun X_INTRODUCED_828_ () Bool
#     false)
#   (define-fun X_INTRODUCED_557_ () Int
#     0)
#   (define-fun X_INTRODUCED_165_ () Bool
#     false)
#   (define-fun X_INTRODUCED_325_ () Bool
#     true)
#   (define-fun X_INTRODUCED_606_ () Bool
#     false)
#   (define-fun X_INTRODUCED_318_ () Bool
#     true)
#   (define-fun X_INTRODUCED_930_ () Int
#     0)
#   (define-fun X_INTRODUCED_473_ () Int
#     0)
#   (define-fun X_INTRODUCED_639_ () Bool
#     false)
#   (define-fun X_INTRODUCED_775_ () Bool
#     false)
#   (define-fun X_INTRODUCED_355_ () Int
#     0)
#   (define-fun X_INTRODUCED_227_ () Bool
#     true)
#   (define-fun X_INTRODUCED_916_ () Bool
#     false)
#   (define-fun X_INTRODUCED_682_ () Int
#     0)
#   (define-fun X_INTRODUCED_201_ () Bool
#     true)
#   (define-fun X_INTRODUCED_31_ () Bool
#     false)
#   (define-fun X_INTRODUCED_485_ () Int
#     0)
#   (define-fun X_INTRODUCED_471_ () Bool
#     true)
#   (define-fun X_INTRODUCED_54_ () Bool
#     false)
#   (define-fun X_INTRODUCED_72_ () Int
#     0)
#   (define-fun X_INTRODUCED_121_ () Int
#     0)
#   (define-fun X_INTRODUCED_747_ () Bool
#     false)
#   (define-fun X_INTRODUCED_927_ () Bool
#     false)
#   (define-fun X_INTRODUCED_331_ () Bool
#     false)
#   (define-fun X_INTRODUCED_130_ () Bool
#     true)
#   (define-fun X_INTRODUCED_748_ () Int
#     0)
#   (define-fun X_INTRODUCED_179_ () Int
#     0)
#   (define-fun X_INTRODUCED_207_ () Bool
#     false)
#   (define-fun X_INTRODUCED_526_ () Bool
#     false)
#   (define-fun X_INTRODUCED_112_ () Bool
#     false)
#   (define-fun X_INTRODUCED_189_ () Bool
#     true)
#   (define-fun X_INTRODUCED_549_ () Bool
#     true)
#   (define-fun X_INTRODUCED_781_ () Bool
#     false)
#   (define-fun X_INTRODUCED_125_ () Int
#     0)
#   (define-fun X_INTRODUCED_87_ () Int
#     0)
#   (define-fun X_INTRODUCED_1019_ () Bool
#     false)
#   (define-fun X_INTRODUCED_144_ () Bool
#     false)
#   (define-fun X_INTRODUCED_981_ () Int
#     0)
#   (define-fun X_INTRODUCED_62_ () Int
#     1)
#   (define-fun X_INTRODUCED_57_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_52_ () Int
#     1)
#   (define-fun X_INTRODUCED_47_ () Int
#     1)
#   (define-fun X_INTRODUCED_42_ () Int
#     1)
#   (define-fun X_INTRODUCED_37_ () Int
#     1)
#   (define-fun X_INTRODUCED_32_ () Int
#     1)
#   (define-fun X_INTRODUCED_27_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_22_ () Int
#     1)
#   (define-fun X_INTRODUCED_1020_ () Int
#     0)
#   (define-fun X_INTRODUCED_977_ () Int
#     0)
#   (define-fun X_INTRODUCED_940_ () Int
#     0)
#   (define-fun X_INTRODUCED_901_ () Int
#     0)
#   (define-fun X_INTRODUCED_860_ () Int
#     0)
#   (define-fun X_INTRODUCED_817_ () Int
#     0)
#   (define-fun X_INTRODUCED_772_ () Int
#     0)
#   (define-fun X_INTRODUCED_725_ () Int
#     0)
#   (define-fun X_INTRODUCED_676_ () Int
#     0)
#   (define-fun X_INTRODUCED_626_ () Int
#     0)
#   (define-fun X_INTRODUCED_573_ () Int
#     0)
#   (define-fun X_INTRODUCED_518_ () Int
#     0)
#   (define-fun X_INTRODUCED_461_ () Int
#     0)
#   (define-fun X_INTRODUCED_402_ () Int
#     0)
#   (define-fun X_INTRODUCED_341_ () Int
#     0)
#   (define-fun X_INTRODUCED_278_ () Int
#     0)
#   (define-fun X_INTRODUCED_213_ () Int
#     0)
#   (define-fun X_INTRODUCED_146_ () Int
#     0)
#   (define-fun X_INTRODUCED_79_ () Int
#     0)
#   (define-fun S () Int
#     0)
#   (define-fun X_INTRODUCED_17_ () Int
#     11)
#   (define-fun X_INTRODUCED_16_ () Int
#     14)
#   (define-fun X_INTRODUCED_15_ () Int
#     15)
#   (define-fun X_INTRODUCED_14_ () Int
#     1)
#   (define-fun X_INTRODUCED_13_ () Int
#     5)
#   (define-fun X_INTRODUCED_12_ () Int
#     9)
#   (define-fun X_INTRODUCED_11_ () Int
#     17)
#   (define-fun X_INTRODUCED_10_ () Int
#     4)
#   (define-fun X_INTRODUCED_9_ () Int
#     7)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz1-noAbs/v3/R033-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 264)
# )
# (model
#   (define-fun X_INTRODUCED_61_ () Bool
#     false)
#   (define-fun X_INTRODUCED_126_ () Int
#     3)
#   (define-fun X_INTRODUCED_79_ () Bool
#     false)
#   (define-fun X_INTRODUCED_134_ () Int
#     0)
#   (define-fun X_INTRODUCED_32_ () Bool
#     false)
#   (define-fun X_INTRODUCED_105_ () Bool
#     false)
#   (define-fun X_INTRODUCED_49_ () Bool
#     false)
#   (define-fun X_INTRODUCED_117_ () Bool
#     false)
#   (define-fun X_INTRODUCED_55_ () Int
#     0)
#   (define-fun X_INTRODUCED_22_ () Bool
#     false)
#   (define-fun X_INTRODUCED_120_ () Int
#     0)
#   (define-fun X_INTRODUCED_17_ () Bool
#     true)
#   (define-fun X_INTRODUCED_40_ () Bool
#     false)
#   (define-fun X_INTRODUCED_42_ () Bool
#     false)
#   (define-fun X_INTRODUCED_76_ () Bool
#     false)
#   (define-fun X_INTRODUCED_92_ () Bool
#     false)
#   (define-fun X_INTRODUCED_13_ () Int
#     (- 3))
#   (define-fun X_INTRODUCED_88_ () Bool
#     false)
#   (define-fun X_INTRODUCED_101_ () Bool
#     true)
#   (define-fun X_INTRODUCED_119_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Int
#     1)
#   (define-fun X_INTRODUCED_64_ () Int
#     0)
#   (define-fun X_INTRODUCED_102_ () Bool
#     false)
#   (define-fun X_INTRODUCED_75_ () Bool
#     true)
#   (define-fun X_INTRODUCED_114_ () Bool
#     false)
#   (define-fun X_INTRODUCED_44_ () Bool
#     false)
#   (define-fun X_INTRODUCED_12_ () Bool
#     false)
#   (define-fun X_INTRODUCED_118_ () Int
#     0)
#   (define-fun X_INTRODUCED_19_ () Bool
#     false)
#   (define-fun X_INTRODUCED_106_ () Int
#     0)
#   (define-fun X_INTRODUCED_109_ () Int
#     0)
#   (define-fun X_INTRODUCED_41_ () Int
#     0)
#   (define-fun X_INTRODUCED_107_ () Bool
#     false)
#   (define-fun X_INTRODUCED_48_ () Bool
#     true)
#   (define-fun X_INTRODUCED_108_ () Bool
#     false)
#   (define-fun X_INTRODUCED_128_ () Int
#     1)
#   (define-fun X_INTRODUCED_2_ () Int
#     2)
#   (define-fun X_INTRODUCED_11_ () Bool
#     false)
#   (define-fun X_INTRODUCED_98_ () Int
#     1)
#   (define-fun X_INTRODUCED_35_ () Int
#     0)
#   (define-fun X_INTRODUCED_80_ () Int
#     0)
#   (define-fun X_INTRODUCED_67_ () Bool
#     false)
#   (define-fun X_INTRODUCED_9_ () Bool
#     false)
#   (define-fun X_INTRODUCED_30_ () Bool
#     true)
#   (define-fun X_INTRODUCED_70_ () Bool
#     false)
#   (define-fun X_INTRODUCED_33_ () Bool
#     true)
#   (define-fun X_INTRODUCED_89_ () Int
#     0)
#   (define-fun X_INTRODUCED_68_ () Bool
#     false)
#   (define-fun X_INTRODUCED_59_ () Int
#     0)
#   (define-fun X_INTRODUCED_77_ () Int
#     0)
#   (define-fun X_INTRODUCED_66_ () Int
#     0)
#   (define-fun X_INTRODUCED_43_ () Bool
#     true)
#   (define-fun X_INTRODUCED_38_ () Bool
#     false)
#   (define-fun M () Int
#     1)
#   (define-fun X_INTRODUCED_57_ () Bool
#     false)
#   (define-fun X_INTRODUCED_84_ () Bool
#     true)
#   (define-fun X_INTRODUCED_16_ () Bool
#     true)
#   (define-fun X_INTRODUCED_24_ () Int
#     1)
#   (define-fun X_INTRODUCED_99_ () Bool
#     false)
#   (define-fun X_INTRODUCED_122_ () Int
#     0)
#   (define-fun X_INTRODUCED_136_ () Int
#     0)
#   (define-fun X_INTRODUCED_25_ () Int
#     0)
#   (define-fun X_INTRODUCED_58_ () Bool
#     false)
#   (define-fun X_INTRODUCED_0_ () Int
#     4)
#   (define-fun X_INTRODUCED_18_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_103_ () Int
#     0)
#   (define-fun X_INTRODUCED_63_ () Bool
#     false)
#   (define-fun X_INTRODUCED_111_ () Int
#     0)
#   (define-fun X_INTRODUCED_131_ () Bool
#     false)
#   (define-fun X_INTRODUCED_47_ () Int
#     1)
#   (define-fun X_INTRODUCED_133_ () Bool
#     false)
#   (define-fun X_INTRODUCED_14_ () Bool
#     false)
#   (define-fun X_INTRODUCED_94_ () Bool
#     false)
#   (define-fun X_INTRODUCED_52_ () Bool
#     false)
#   (define-fun X_INTRODUCED_39_ () Bool
#     false)
#   (define-fun X_INTRODUCED_139_ () Int
#     5)
#   (define-fun X_INTRODUCED_34_ () Bool
#     false)
#   (define-fun X_INTRODUCED_23_ () Int
#     0)
#   (define-fun obj () Int
#     264)
#   (define-fun X_INTRODUCED_53_ () Bool
#     true)
#   (define-fun X_INTRODUCED_96_ () Int
#     0)
#   (define-fun X_INTRODUCED_54_ () Bool
#     false)
#   (define-fun X_INTRODUCED_85_ () Bool
#     true)
#   (define-fun X_INTRODUCED_78_ () Bool
#     true)
#   (define-fun X_INTRODUCED_72_ () Int
#     0)
#   (define-fun X_INTRODUCED_93_ () Int
#     0)
#   (define-fun X_INTRODUCED_130_ () Int
#     3)
#   (define-fun X_INTRODUCED_91_ () Bool
#     false)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_29_ () Bool
#     true)
#   (define-fun X_INTRODUCED_71_ () Bool
#     false)
#   (define-fun X_INTRODUCED_115_ () Int
#     0)
#   (define-fun X_INTRODUCED_135_ () Bool
#     false)
#   (define-fun X_INTRODUCED_112_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1_ () Int
#     6)
#   (define-fun X_INTRODUCED_45_ () Int
#     0)
#   (define-fun X_INTRODUCED_87_ () Bool
#     true)
#   (define-fun X_INTRODUCED_83_ () Int
#     0)
#   (define-fun X_INTRODUCED_95_ () Bool
#     false)
#   (define-fun X_INTRODUCED_20_ () Int
#     1)
#   (define-fun X_INTRODUCED_15_ () Int
#     3)
#   (define-fun X_INTRODUCED_10_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_132_ () Int
#     0)
#   (define-fun X_INTRODUCED_113_ () Int
#     0)
#   (define-fun X_INTRODUCED_100_ () Int
#     0)
#   (define-fun X_INTRODUCED_86_ () Int
#     1)
#   (define-fun X_INTRODUCED_69_ () Int
#     0)
#   (define-fun X_INTRODUCED_50_ () Int
#     0)
#   (define-fun X_INTRODUCED_31_ () Int
#     1)
#   (define-fun S () Int
#     1)
#   (define-fun X_INTRODUCED_5_ () Int
#     1)
#   (define-fun X_INTRODUCED_4_ () Int
#     3)
#   (define-fun X_INTRODUCED_3_ () Int
#     5)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz1-noAbs/v3/R034-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 1)
# )
# (model
#   (define-fun X_INTRODUCED_61_ () Bool
#     true)
#   (define-fun X_INTRODUCED_126_ () Int
#     1)
#   (define-fun X_INTRODUCED_79_ () Bool
#     false)
#   (define-fun X_INTRODUCED_134_ () Int
#     1)
#   (define-fun X_INTRODUCED_32_ () Bool
#     true)
#   (define-fun X_INTRODUCED_105_ () Bool
#     false)
#   (define-fun X_INTRODUCED_49_ () Bool
#     false)
#   (define-fun X_INTRODUCED_117_ () Bool
#     false)
#   (define-fun X_INTRODUCED_55_ () Int
#     0)
#   (define-fun X_INTRODUCED_22_ () Bool
#     false)
#   (define-fun X_INTRODUCED_120_ () Int
#     0)
#   (define-fun X_INTRODUCED_17_ () Bool
#     false)
#   (define-fun X_INTRODUCED_40_ () Bool
#     false)
#   (define-fun X_INTRODUCED_42_ () Bool
#     true)
#   (define-fun X_INTRODUCED_76_ () Bool
#     false)
#   (define-fun X_INTRODUCED_92_ () Bool
#     false)
#   (define-fun X_INTRODUCED_13_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_88_ () Bool
#     false)
#   (define-fun X_INTRODUCED_101_ () Bool
#     false)
#   (define-fun X_INTRODUCED_119_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_64_ () Int
#     0)
#   (define-fun X_INTRODUCED_102_ () Bool
#     false)
#   (define-fun X_INTRODUCED_75_ () Bool
#     false)
#   (define-fun X_INTRODUCED_114_ () Bool
#     false)
#   (define-fun X_INTRODUCED_44_ () Bool
#     false)
#   (define-fun X_INTRODUCED_12_ () Bool
#     false)
#   (define-fun X_INTRODUCED_118_ () Int
#     0)
#   (define-fun X_INTRODUCED_19_ () Bool
#     false)
#   (define-fun X_INTRODUCED_106_ () Int
#     0)
#   (define-fun X_INTRODUCED_109_ () Int
#     0)
#   (define-fun X_INTRODUCED_41_ () Int
#     0)
#   (define-fun X_INTRODUCED_107_ () Bool
#     true)
#   (define-fun X_INTRODUCED_48_ () Bool
#     false)
#   (define-fun X_INTRODUCED_108_ () Bool
#     false)
#   (define-fun X_INTRODUCED_128_ () Int
#     1)
#   (define-fun X_INTRODUCED_2_ () Int
#     5)
#   (define-fun X_INTRODUCED_11_ () Bool
#     false)
#   (define-fun X_INTRODUCED_98_ () Int
#     0)
#   (define-fun X_INTRODUCED_35_ () Int
#     0)
#   (define-fun X_INTRODUCED_80_ () Int
#     0)
#   (define-fun X_INTRODUCED_67_ () Bool
#     true)
#   (define-fun X_INTRODUCED_70_ () Bool
#     true)
#   (define-fun X_INTRODUCED_30_ () Bool
#     false)
#   (define-fun X_INTRODUCED_9_ () Bool
#     false)
#   (define-fun X_INTRODUCED_33_ () Bool
#     false)
#   (define-fun X_INTRODUCED_89_ () Int
#     0)
#   (define-fun X_INTRODUCED_68_ () Bool
#     false)
#   (define-fun X_INTRODUCED_59_ () Int
#     0)
#   (define-fun X_INTRODUCED_77_ () Int
#     0)
#   (define-fun X_INTRODUCED_66_ () Int
#     0)
#   (define-fun X_INTRODUCED_43_ () Bool
#     false)
#   (define-fun X_INTRODUCED_38_ () Bool
#     false)
#   (define-fun M () Int
#     0)
#   (define-fun X_INTRODUCED_57_ () Bool
#     true)
#   (define-fun X_INTRODUCED_84_ () Bool
#     true)
#   (define-fun X_INTRODUCED_16_ () Bool
#     false)
#   (define-fun X_INTRODUCED_24_ () Int
#     0)
#   (define-fun X_INTRODUCED_99_ () Bool
#     false)
#   (define-fun X_INTRODUCED_122_ () Int
#     0)
#   (define-fun X_INTRODUCED_136_ () Int
#     0)
#   (define-fun X_INTRODUCED_25_ () Int
#     0)
#   (define-fun X_INTRODUCED_58_ () Bool
#     false)
#   (define-fun X_INTRODUCED_0_ () Int
#     4)
#   (define-fun X_INTRODUCED_18_ () Int
#     1)
#   (define-fun X_INTRODUCED_103_ () Int
#     0)
#   (define-fun X_INTRODUCED_63_ () Bool
#     false)
#   (define-fun X_INTRODUCED_111_ () Int
#     0)
#   (define-fun X_INTRODUCED_131_ () Bool
#     false)
#   (define-fun X_INTRODUCED_47_ () Int
#     0)
#   (define-fun X_INTRODUCED_133_ () Bool
#     true)
#   (define-fun X_INTRODUCED_62_ () Bool
#     false)
#   (define-fun X_INTRODUCED_14_ () Bool
#     false)
#   (define-fun X_INTRODUCED_94_ () Bool
#     true)
#   (define-fun X_INTRODUCED_139_ () Int
#     6)
#   (define-fun X_INTRODUCED_34_ () Bool
#     false)
#   (define-fun X_INTRODUCED_23_ () Int
#     0)
#   (define-fun obj () Int
#     1)
#   (define-fun X_INTRODUCED_53_ () Bool
#     false)
#   (define-fun X_INTRODUCED_96_ () Int
#     0)
#   (define-fun X_INTRODUCED_54_ () Bool
#     false)
#   (define-fun X_INTRODUCED_85_ () Bool
#     false)
#   (define-fun X_INTRODUCED_78_ () Bool
#     false)
#   (define-fun X_INTRODUCED_72_ () Int
#     0)
#   (define-fun X_INTRODUCED_93_ () Int
#     0)
#   (define-fun X_INTRODUCED_130_ () Int
#     1)
#   (define-fun X_INTRODUCED_91_ () Bool
#     false)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_28_ () Bool
#     false)
#   (define-fun X_INTRODUCED_29_ () Bool
#     true)
#   (define-fun X_INTRODUCED_71_ () Bool
#     false)
#   (define-fun X_INTRODUCED_115_ () Int
#     0)
#   (define-fun X_INTRODUCED_135_ () Bool
#     false)
#   (define-fun X_INTRODUCED_112_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1_ () Int
#     2)
#   (define-fun X_INTRODUCED_45_ () Int
#     0)
#   (define-fun X_INTRODUCED_87_ () Bool
#     false)
#   (define-fun X_INTRODUCED_83_ () Int
#     0)
#   (define-fun X_INTRODUCED_95_ () Bool
#     false)
#   (define-fun X_INTRODUCED_20_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_15_ () Int
#     1)
#   (define-fun X_INTRODUCED_10_ () Int
#     1)
#   (define-fun X_INTRODUCED_132_ () Int
#     0)
#   (define-fun X_INTRODUCED_113_ () Int
#     0)
#   (define-fun X_INTRODUCED_100_ () Int
#     0)
#   (define-fun X_INTRODUCED_86_ () Int
#     0)
#   (define-fun X_INTRODUCED_69_ () Int
#     0)
#   (define-fun X_INTRODUCED_50_ () Int
#     0)
#   (define-fun X_INTRODUCED_31_ () Int
#     0)
#   (define-fun S () Int
#     0)
#   (define-fun X_INTRODUCED_5_ () Int
#     6)
#   (define-fun X_INTRODUCED_4_ () Int
#     1)
#   (define-fun X_INTRODUCED_3_ () Int
#     3)
# )

# %% [markdown]
# #### Tests with `smt2` from $Mz_2$

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz2-noAbs/v3/A004-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 88)
# )
# (model
#   (define-fun X_INTRODUCED_36_ () Int
#     0)
#   (define-fun X_INTRODUCED_56_ () Int
#     1)
#   (define-fun X_INTRODUCED_5_ () Int
#     1)
#   (define-fun X_INTRODUCED_39_ () Bool
#     true)
#   (define-fun X_INTRODUCED_31_ () Bool
#     false)
#   (define-fun X_INTRODUCED_12_ () Bool
#     false)
#   (define-fun X_INTRODUCED_27_ () Bool
#     false)
#   (define-fun X_INTRODUCED_59_ () Bool
#     false)
#   (define-fun X_INTRODUCED_34_ () Bool
#     false)
#   (define-fun X_INTRODUCED_44_ () Int
#     0)
#   (define-fun obj () Int
#     88)
#   (define-fun X_INTRODUCED_15_ () Bool
#     true)
#   (define-fun X_INTRODUCED_43_ () Bool
#     false)
#   (define-fun X_INTRODUCED_38_ () Int
#     0)
#   (define-fun M () Int
#     1)
#   (define-fun X_INTRODUCED_54_ () Int
#     3)
#   (define-fun X_INTRODUCED_49_ () Int
#     0)
#   (define-fun X_INTRODUCED_50_ () Int
#     0)
#   (define-fun X_INTRODUCED_46_ () Bool
#     false)
#   (define-fun X_INTRODUCED_16_ () Int
#     0)
#   (define-fun X_INTRODUCED_10_ () Bool
#     false)
#   (define-fun X_INTRODUCED_28_ () Int
#     0)
#   (define-fun X_INTRODUCED_29_ () Int
#     1)
#   (define-fun X_INTRODUCED_25_ () Bool
#     false)
#   (define-fun X_INTRODUCED_22_ () Bool
#     true)
#   (define-fun X_INTRODUCED_48_ () Bool
#     false)
#   (define-fun X_INTRODUCED_58_ () Int
#     3)
#   (define-fun X_INTRODUCED_0_ () Int
#     2)
#   (define-fun X_INTRODUCED_17_ () Int
#     1)
#   (define-fun X_INTRODUCED_40_ () Bool
#     true)
#   (define-fun X_INTRODUCED_60_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1_ () Int
#     4)
#   (define-fun X_INTRODUCED_11_ () Int
#     (- 3))
#   (define-fun X_INTRODUCED_45_ () Int
#     1)
#   (define-fun X_INTRODUCED_42_ () Bool
#     false)
#   (define-fun X_INTRODUCED_35_ () Bool
#     false)
#   (define-fun X_INTRODUCED_26_ () Bool
#     false)
#   (define-fun X_INTRODUCED_20_ () Bool
#     true)
#   (define-fun X_INTRODUCED_9_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Bool
#     false)
#   (define-fun X_INTRODUCED_14_ () Bool
#     true)
#   (define-fun X_INTRODUCED_62_ () Int
#     0)
#   (define-fun X_INTRODUCED_13_ () Int
#     3)
#   (define-fun X_INTRODUCED_8_ () Int
#     (- 1))
#   (define-fun N () Int
#     0)
#   (define-fun X_INTRODUCED_61_ () Int
#     0)
#   (define-fun X_INTRODUCED_47_ () Int
#     0)
#   (define-fun X_INTRODUCED_41_ () Int
#     1)
#   (define-fun X_INTRODUCED_32_ () Int
#     0)
#   (define-fun X_INTRODUCED_23_ () Int
#     1)
#   (define-fun S () Int
#     1)
#   (define-fun X_INTRODUCED_3_ () Int
#     1)
#   (define-fun X_INTRODUCED_2_ () Int
#     3)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz2-noAbs/v3/A012-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 0)
# )
# (model
#   (define-fun X_INTRODUCED_5_ () Bool
#     false)
#   (define-fun X_INTRODUCED_22_ () Bool
#     true)
#   (define-fun X_INTRODUCED_8_ () Bool
#     false)
#   (define-fun S () Int
#     0)
#   (define-fun X_INTRODUCED_0_ () Int
#     2)
#   (define-fun X_INTRODUCED_3_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_17_ () Int
#     1)
#   (define-fun X_INTRODUCED_7_ () Bool
#     false)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_6_ () Int
#     1)
#   (define-fun obj () Int
#     0)
#   (define-fun X_INTRODUCED_1_ () Int
#     1)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz2-noAbs/v3/R008-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 1)
# )
# (model
#   (define-fun X_INTRODUCED_850_ () Int
#     0)
#   (define-fun X_INTRODUCED_348_ () Bool
#     true)
#   (define-fun X_INTRODUCED_790_ () Bool
#     false)
#   (define-fun X_INTRODUCED_925_ () Bool
#     false)
#   (define-fun X_INTRODUCED_746_ () Int
#     0)
#   (define-fun X_INTRODUCED_369_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1010_ () Int
#     0)
#   (define-fun X_INTRODUCED_985_ () Int
#     0)
#   (define-fun X_INTRODUCED_911_ () Int
#     0)
#   (define-fun X_INTRODUCED_307_ () Bool
#     false)
#   (define-fun X_INTRODUCED_97_ () Bool
#     true)
#   (define-fun X_INTRODUCED_844_ () Int
#     0)
#   (define-fun X_INTRODUCED_164_ () Bool
#     true)
#   (define-fun X_INTRODUCED_910_ () Bool
#     false)
#   (define-fun X_INTRODUCED_168_ () Bool
#     false)
#   (define-fun X_INTRODUCED_917_ () Int
#     0)
#   (define-fun X_INTRODUCED_64_ () Bool
#     false)
#   (define-fun X_INTRODUCED_883_ () Bool
#     false)
#   (define-fun X_INTRODUCED_219_ () Bool
#     true)
#   (define-fun X_INTRODUCED_739_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1007_ () Bool
#     false)
#   (define-fun X_INTRODUCED_305_ () Bool
#     true)
#   (define-fun X_INTRODUCED_967_ () Bool
#     false)
#   (define-fun X_INTRODUCED_278_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1031_ () Int
#     1)
#   (define-fun X_INTRODUCED_642_ () Bool
#     false)
#   (define-fun X_INTRODUCED_109_ () Bool
#     false)
#   (define-fun X_INTRODUCED_284_ () Bool
#     true)
#   (define-fun X_INTRODUCED_718_ () Bool
#     false)
#   (define-fun X_INTRODUCED_687_ () Int
#     0)
#   (define-fun X_INTRODUCED_982_ () Bool
#     false)
#   (define-fun X_INTRODUCED_543_ () Int
#     0)
#   (define-fun X_INTRODUCED_737_ () Int
#     0)
#   (define-fun X_INTRODUCED_48_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_146_ () Bool
#     true)
#   (define-fun X_INTRODUCED_995_ () Bool
#     false)
#   (define-fun X_INTRODUCED_766_ () Int
#     0)
#   (define-fun X_INTRODUCED_247_ () Bool
#     true)
#   (define-fun X_INTRODUCED_620_ () Bool
#     true)
#   (define-fun X_INTRODUCED_807_ () Bool
#     false)
#   (define-fun X_INTRODUCED_685_ () Bool
#     false)
#   (define-fun X_INTRODUCED_731_ () Int
#     0)
#   (define-fun X_INTRODUCED_792_ () Int
#     0)
#   (define-fun X_INTRODUCED_954_ () Bool
#     false)
#   (define-fun X_INTRODUCED_472_ () Bool
#     true)
#   (define-fun X_INTRODUCED_535_ () Bool
#     false)
#   (define-fun X_INTRODUCED_563_ () Bool
#     true)
#   (define-fun X_INTRODUCED_194_ () Bool
#     false)
#   (define-fun X_INTRODUCED_601_ () Int
#     0)
#   (define-fun X_INTRODUCED_596_ () Int
#     0)
#   (define-fun X_INTRODUCED_436_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1016_ () Int
#     1)
#   (define-fun X_INTRODUCED_38_ () Int
#     1)
#   (define-fun X_INTRODUCED_192_ () Int
#     0)
#   (define-fun X_INTRODUCED_229_ () Int
#     0)
#   (define-fun X_INTRODUCED_442_ () Bool
#     true)
#   (define-fun X_INTRODUCED_515_ () Bool
#     false)
#   (define-fun X_INTRODUCED_958_ () Int
#     0)
#   (define-fun X_INTRODUCED_453_ () Bool
#     true)
#   (define-fun X_INTRODUCED_691_ () Bool
#     false)
#   (define-fun X_INTRODUCED_317_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1025_ () Bool
#     false)
#   (define-fun X_INTRODUCED_719_ () Int
#     0)
#   (define-fun X_INTRODUCED_157_ () Bool
#     false)
#   (define-fun X_INTRODUCED_58_ () Int
#     1)
#   (define-fun X_INTRODUCED_147_ () Bool
#     false)
#   (define-fun X_INTRODUCED_484_ () Bool
#     false)
#   (define-fun X_INTRODUCED_647_ () Bool
#     false)
#   (define-fun X_INTRODUCED_111_ () Int
#     0)
#   (define-fun X_INTRODUCED_852_ () Bool
#     false)
#   (define-fun X_INTRODUCED_697_ () Bool
#     false)
#   (define-fun X_INTRODUCED_713_ () Int
#     0)
#   (define-fun X_INTRODUCED_492_ () Bool
#     false)
#   (define-fun X_INTRODUCED_259_ () Bool
#     true)
#   (define-fun X_INTRODUCED_990_ () Bool
#     false)
#   (define-fun X_INTRODUCED_552_ () Bool
#     false)
#   (define-fun X_INTRODUCED_788_ () Bool
#     false)
#   (define-fun X_INTRODUCED_161_ () Bool
#     false)
#   (define-fun X_INTRODUCED_236_ () Bool
#     false)
#   (define-fun X_INTRODUCED_458_ () Bool
#     false)
#   (define-fun X_INTRODUCED_34_ () Bool
#     false)
#   (define-fun X_INTRODUCED_546_ () Bool
#     false)
#   (define-fun X_INTRODUCED_439_ () Bool
#     true)
#   (define-fun X_INTRODUCED_149_ () Int
#     0)
#   (define-fun X_INTRODUCED_586_ () Bool
#     false)
#   (define-fun X_INTRODUCED_216_ () Int
#     0)
#   (define-fun X_INTRODUCED_336_ () Bool
#     false)
#   (define-fun X_INTRODUCED_641_ () Bool
#     false)
#   (define-fun X_INTRODUCED_177_ () Bool
#     false)
#   (define-fun X_INTRODUCED_859_ () Bool
#     false)
#   (define-fun X_INTRODUCED_965_ () Bool
#     false)
#   (define-fun X_INTRODUCED_454_ () Bool
#     false)
#   (define-fun X_INTRODUCED_187_ () Int
#     0)
#   (define-fun X_INTRODUCED_987_ () Int
#     0)
#   (define-fun X_INTRODUCED_551_ () Bool
#     true)
#   (define-fun X_INTRODUCED_389_ () Int
#     0)
#   (define-fun X_INTRODUCED_758_ () Bool
#     false)
#   (define-fun X_INTRODUCED_833_ () Bool
#     false)
#   (define-fun X_INTRODUCED_198_ () Bool
#     false)
#   (define-fun X_INTRODUCED_137_ () Int
#     0)
#   (define-fun X_INTRODUCED_265_ () Int
#     0)
#   (define-fun X_INTRODUCED_209_ () Bool
#     true)
#   (define-fun X_INTRODUCED_36_ () Bool
#     false)
#   (define-fun X_INTRODUCED_805_ () Int
#     0)
#   (define-fun X_INTRODUCED_61_ () Bool
#     false)
#   (define-fun X_INTRODUCED_663_ () Bool
#     false)
#   (define-fun X_INTRODUCED_360_ () Bool
#     true)
#   (define-fun X_INTRODUCED_362_ () Bool
#     false)
#   (define-fun X_INTRODUCED_978_ () Bool
#     false)
#   (define-fun X_INTRODUCED_789_ () Int
#     0)
#   (define-fun X_INTRODUCED_456_ () Int
#     0)
#   (define-fun X_INTRODUCED_134_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1027_ () Int
#     0)
#   (define-fun X_INTRODUCED_503_ () Bool
#     false)
#   (define-fun X_INTRODUCED_280_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1001_ () Bool
#     false)
#   (define-fun X_INTRODUCED_500_ () Bool
#     false)
#   (define-fun X_INTRODUCED_525_ () Bool
#     false)
#   (define-fun X_INTRODUCED_148_ () Bool
#     false)
#   (define-fun X_INTRODUCED_315_ () Bool
#     false)
#   (define-fun X_INTRODUCED_464_ () Bool
#     false)
#   (define-fun X_INTRODUCED_498_ () Bool
#     false)
#   (define-fun X_INTRODUCED_548_ () Bool
#     false)
#   (define-fun X_INTRODUCED_603_ () Bool
#     false)
#   (define-fun X_INTRODUCED_244_ () Bool
#     false)
#   (define-fun X_INTRODUCED_667_ () Bool
#     false)
#   (define-fun X_INTRODUCED_679_ () Bool
#     false)
#   (define-fun X_INTRODUCED_285_ () Bool
#     false)
#   (define-fun X_INTRODUCED_403_ () Int
#     0)
#   (define-fun X_INTRODUCED_401_ () Int
#     0)
#   (define-fun X_INTRODUCED_489_ () Int
#     0)
#   (define-fun X_INTRODUCED_203_ () Bool
#     false)
#   (define-fun X_INTRODUCED_299_ () Bool
#     false)
#   (define-fun X_INTRODUCED_945_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1032_ () Int
#     0)
#   (define-fun X_INTRODUCED_756_ () Bool
#     false)
#   (define-fun X_INTRODUCED_839_ () Bool
#     false)
#   (define-fun X_INTRODUCED_695_ () Bool
#     false)
#   (define-fun X_INTRODUCED_353_ () Int
#     0)
#   (define-fun X_INTRODUCED_375_ () Int
#     0)
#   (define-fun X_INTRODUCED_114_ () Bool
#     false)
#   (define-fun X_INTRODUCED_897_ () Int
#     0)
#   (define-fun X_INTRODUCED_344_ () Int
#     0)
#   (define-fun X_INTRODUCED_411_ () Bool
#     false)
#   (define-fun X_INTRODUCED_312_ () Int
#     0)
#   (define-fun X_INTRODUCED_840_ () Int
#     0)
#   (define-fun X_INTRODUCED_266_ () Bool
#     false)
#   (define-fun X_INTRODUCED_230_ () Bool
#     false)
#   (define-fun X_INTRODUCED_127_ () Bool
#     false)
#   (define-fun X_INTRODUCED_416_ () Bool
#     false)
#   (define-fun X_INTRODUCED_511_ () Bool
#     false)
#   (define-fun X_INTRODUCED_578_ () Int
#     0)
#   (define-fun X_INTRODUCED_376_ () Bool
#     false)
#   (define-fun X_INTRODUCED_567_ () Bool
#     false)
#   (define-fun X_INTRODUCED_569_ () Bool
#     false)
#   (define-fun X_INTRODUCED_823_ () Bool
#     false)
#   (define-fun X_INTRODUCED_643_ () Int
#     0)
#   (define-fun X_INTRODUCED_441_ () Int
#     0)
#   (define-fun X_INTRODUCED_470_ () Bool
#     false)
#   (define-fun X_INTRODUCED_397_ () Int
#     0)
#   (define-fun X_INTRODUCED_108_ () Bool
#     true)
#   (define-fun X_INTRODUCED_228_ () Bool
#     false)
#   (define-fun X_INTRODUCED_445_ () Bool
#     true)
#   (define-fun X_INTRODUCED_573_ () Bool
#     true)
#   (define-fun X_INTRODUCED_993_ () Bool
#     false)
#   (define-fun X_INTRODUCED_644_ () Bool
#     false)
#   (define-fun X_INTRODUCED_832_ () Int
#     0)
#   (define-fun X_INTRODUCED_811_ () Int
#     0)
#   (define-fun X_INTRODUCED_400_ () Bool
#     false)
#   (define-fun X_INTRODUCED_616_ () Int
#     0)
#   (define-fun X_INTRODUCED_1046_ () Bool
#     false)
#   (define-fun X_INTRODUCED_656_ () Int
#     0)
#   (define-fun X_INTRODUCED_434_ () Bool
#     false)
#   (define-fun X_INTRODUCED_702_ () Int
#     0)
#   (define-fun X_INTRODUCED_513_ () Bool
#     false)
#   (define-fun X_INTRODUCED_220_ () Bool
#     false)
#   (define-fun X_INTRODUCED_896_ () Bool
#     false)
#   (define-fun X_INTRODUCED_961_ () Bool
#     false)
#   (define-fun X_INTRODUCED_51_ () Bool
#     false)
#   (define-fun X_INTRODUCED_893_ () Bool
#     false)
#   (define-fun X_INTRODUCED_754_ () Int
#     0)
#   (define-fun X_INTRODUCED_853_ () Int
#     0)
#   (define-fun X_INTRODUCED_103_ () Int
#     0)
#   (define-fun X_INTRODUCED_743_ () Int
#     0)
#   (define-fun X_INTRODUCED_862_ () Int
#     0)
#   (define-fun X_INTRODUCED_256_ () Int
#     0)
#   (define-fun X_INTRODUCED_287_ () Bool
#     false)
#   (define-fun X_INTRODUCED_494_ () Bool
#     false)
#   (define-fun X_INTRODUCED_588_ () Bool
#     true)
#   (define-fun X_INTRODUCED_162_ () Bool
#     false)
#   (define-fun X_INTRODUCED_931_ () Bool
#     false)
#   (define-fun X_INTRODUCED_316_ () Int
#     0)
#   (define-fun X_INTRODUCED_301_ () Bool
#     true)
#   (define-fun X_INTRODUCED_886_ () Int
#     0)
#   (define-fun X_INTRODUCED_320_ () Bool
#     true)
#   (define-fun X_INTRODUCED_866_ () Int
#     0)
#   (define-fun X_INTRODUCED_258_ () Bool
#     false)
#   (define-fun X_INTRODUCED_715_ () Bool
#     false)
#   (define-fun X_INTRODUCED_950_ () Int
#     0)
#   (define-fun X_INTRODUCED_996_ () Int
#     0)
#   (define-fun X_INTRODUCED_388_ () Bool
#     false)
#   (define-fun X_INTRODUCED_218_ () Int
#     0)
#   (define-fun X_INTRODUCED_556_ () Int
#     0)
#   (define-fun X_INTRODUCED_96_ () Bool
#     false)
#   (define-fun X_INTRODUCED_909_ () Int
#     0)
#   (define-fun X_INTRODUCED_1037_ () Bool
#     false)
#   (define-fun X_INTRODUCED_424_ () Bool
#     true)
#   (define-fun X_INTRODUCED_880_ () Int
#     0)
#   (define-fun X_INTRODUCED_384_ () Int
#     0)
#   (define-fun X_INTRODUCED_908_ () Bool
#     false)
#   (define-fun X_INTRODUCED_474_ () Int
#     0)
#   (define-fun X_INTRODUCED_750_ () Bool
#     false)
#   (define-fun X_INTRODUCED_904_ () Bool
#     false)
#   (define-fun X_INTRODUCED_91_ () Int
#     0)
#   (define-fun X_INTRODUCED_704_ () Bool
#     false)
#   (define-fun X_INTRODUCED_504_ () Bool
#     false)
#   (define-fun X_INTRODUCED_226_ () Bool
#     false)
#   (define-fun X_INTRODUCED_193_ () Bool
#     true)
#   (define-fun X_INTRODUCED_812_ () Bool
#     true)
#   (define-fun X_INTRODUCED_468_ () Int
#     0)
#   (define-fun X_INTRODUCED_276_ () Bool
#     false)
#   (define-fun X_INTRODUCED_129_ () Int
#     0)
#   (define-fun X_INTRODUCED_653_ () Int
#     0)
#   (define-fun X_INTRODUCED_1020_ () Bool
#     false)
#   (define-fun X_INTRODUCED_414_ () Bool
#     false)
#   (define-fun X_INTRODUCED_568_ () Bool
#     true)
#   (define-fun X_INTRODUCED_364_ () Bool
#     true)
#   (define-fun X_INTRODUCED_159_ () Int
#     0)
#   (define-fun X_INTRODUCED_167_ () Int
#     0)
#   (define-fun X_INTRODUCED_782_ () Bool
#     false)
#   (define-fun X_INTRODUCED_677_ () Bool
#     false)
#   (define-fun X_INTRODUCED_163_ () Int
#     0)
#   (define-fun X_INTRODUCED_418_ () Int
#     0)
#   (define-fun X_INTRODUCED_608_ () Bool
#     false)
#   (define-fun X_INTRODUCED_865_ () Bool
#     false)
#   (define-fun X_INTRODUCED_363_ () Int
#     0)
#   (define-fun X_INTRODUCED_1029_ () Int
#     0)
#   (define-fun X_INTRODUCED_491_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1018_ () Int
#     1)
#   (define-fun X_INTRODUCED_22_ () Bool
#     true)
#   (define-fun X_INTRODUCED_141_ () Int
#     0)
#   (define-fun X_INTRODUCED_455_ () Bool
#     false)
#   (define-fun X_INTRODUCED_487_ () Bool
#     true)
#   (define-fun X_INTRODUCED_215_ () Bool
#     false)
#   (define-fun X_INTRODUCED_92_ () Bool
#     true)
#   (define-fun X_INTRODUCED_706_ () Bool
#     false)
#   (define-fun X_INTRODUCED_800_ () Bool
#     false)
#   (define-fun X_INTRODUCED_339_ () Bool
#     true)
#   (define-fun X_INTRODUCED_124_ () Bool
#     false)
#   (define-fun X_INTRODUCED_581_ () Int
#     0)
#   (define-fun X_INTRODUCED_539_ () Int
#     0)
#   (define-fun X_INTRODUCED_234_ () Bool
#     false)
#   (define-fun X_INTRODUCED_842_ () Int
#     0)
#   (define-fun X_INTRODUCED_876_ () Bool
#     false)
#   (define-fun X_INTRODUCED_181_ () Bool
#     false)
#   (define-fun X_INTRODUCED_576_ () Bool
#     true)
#   (define-fun X_INTRODUCED_224_ () Int
#     0)
#   (define-fun X_INTRODUCED_829_ () Int
#     0)
#   (define-fun X_INTRODUCED_246_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1049_ () Bool
#     false)
#   (define-fun X_INTRODUCED_202_ () Bool
#     true)
#   (define-fun X_INTRODUCED_796_ () Bool
#     false)
#   (define-fun X_INTRODUCED_145_ () Int
#     0)
#   (define-fun X_INTRODUCED_835_ () Int
#     0)
#   (define-fun X_INTRODUCED_599_ () Bool
#     false)
#   (define-fun X_INTRODUCED_41_ () Bool
#     false)
#   (define-fun X_INTRODUCED_740_ () Int
#     0)
#   (define-fun X_INTRODUCED_627_ () Bool
#     false)
#   (define-fun X_INTRODUCED_759_ () Bool
#     false)
#   (define-fun X_INTRODUCED_2_ () Int
#     17)
#   (define-fun X_INTRODUCED_450_ () Bool
#     false)
#   (define-fun X_INTRODUCED_819_ () Bool
#     false)
#   (define-fun X_INTRODUCED_222_ () Bool
#     true)
#   (define-fun X_INTRODUCED_80_ () Int
#     0)
#   (define-fun X_INTRODUCED_476_ () Bool
#     false)
#   (define-fun X_INTRODUCED_67_ () Bool
#     false)
#   (define-fun X_INTRODUCED_310_ () Bool
#     false)
#   (define-fun X_INTRODUCED_946_ () Int
#     0)
#   (define-fun X_INTRODUCED_412_ () Int
#     0)
#   (define-fun X_INTRODUCED_5_ () Int
#     2)
#   (define-fun X_INTRODUCED_613_ () Int
#     0)
#   (define-fun X_INTRODUCED_681_ () Int
#     0)
#   (define-fun X_INTRODUCED_59_ () Bool
#     false)
#   (define-fun X_INTRODUCED_870_ () Bool
#     false)
#   (define-fun X_INTRODUCED_449_ () Bool
#     true)
#   (define-fun X_INTRODUCED_151_ () Int
#     0)
#   (define-fun X_INTRODUCED_182_ () Bool
#     false)
#   (define-fun X_INTRODUCED_404_ () Bool
#     false)
#   (define-fun X_INTRODUCED_591_ () Bool
#     false)
#   (define-fun X_INTRODUCED_43_ () Int
#     1)
#   (define-fun X_INTRODUCED_968_ () Int
#     0)
#   (define-fun X_INTRODUCED_724_ () Int
#     0)
#   (define-fun X_INTRODUCED_84_ () Bool
#     false)
#   (define-fun X_INTRODUCED_143_ () Bool
#     false)
#   (define-fun X_INTRODUCED_138_ () Bool
#     true)
#   (define-fun X_INTRODUCED_293_ () Bool
#     false)
#   (define-fun X_INTRODUCED_303_ () Bool
#     false)
#   (define-fun X_INTRODUCED_122_ () Bool
#     true)
#   (define-fun X_INTRODUCED_762_ () Bool
#     false)
#   (define-fun X_INTRODUCED_381_ () Int
#     0)
#   (define-fun X_INTRODUCED_431_ () Int
#     0)
#   (define-fun X_INTRODUCED_530_ () Int
#     0)
#   (define-fun X_INTRODUCED_799_ () Int
#     0)
#   (define-fun X_INTRODUCED_197_ () Bool
#     true)
#   (define-fun X_INTRODUCED_86_ () Bool
#     false)
#   (define-fun X_INTRODUCED_680_ () Bool
#     false)
#   (define-fun X_INTRODUCED_374_ () Bool
#     false)
#   (define-fun X_INTRODUCED_74_ () Int
#     0)
#   (define-fun X_INTRODUCED_63_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_260_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1003_ () Bool
#     false)
#   (define-fun X_INTRODUCED_542_ () Bool
#     false)
#   (define-fun X_INTRODUCED_696_ () Int
#     0)
#   (define-fun X_INTRODUCED_989_ () Int
#     0)
#   (define-fun X_INTRODUCED_820_ () Int
#     0)
#   (define-fun X_INTRODUCED_604_ () Int
#     0)
#   (define-fun X_INTRODUCED_139_ () Bool
#     false)
#   (define-fun X_INTRODUCED_328_ () Bool
#     true)
#   (define-fun X_INTRODUCED_533_ () Int
#     0)
#   (define-fun X_INTRODUCED_341_ () Bool
#     false)
#   (define-fun X_INTRODUCED_479_ () Bool
#     false)
#   (define-fun X_INTRODUCED_951_ () Bool
#     false)
#   (define-fun X_INTRODUCED_631_ () Int
#     0)
#   (define-fun X_INTRODUCED_590_ () Int
#     0)
#   (define-fun X_INTRODUCED_561_ () Bool
#     false)
#   (define-fun X_INTRODUCED_342_ () Int
#     0)
#   (define-fun X_INTRODUCED_612_ () Bool
#     false)
#   (define-fun X_INTRODUCED_475_ () Bool
#     true)
#   (define-fun X_INTRODUCED_730_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1005_ () Bool
#     false)
#   (define-fun X_INTRODUCED_296_ () Int
#     0)
#   (define-fun X_INTRODUCED_887_ () Bool
#     false)
#   (define-fun X_INTRODUCED_95_ () Int
#     0)
#   (define-fun X_INTRODUCED_304_ () Int
#     0)
#   (define-fun X_INTRODUCED_722_ () Int
#     0)
#   (define-fun X_INTRODUCED_841_ () Bool
#     false)
#   (define-fun X_INTRODUCED_264_ () Bool
#     false)
#   (define-fun X_INTRODUCED_391_ () Bool
#     false)
#   (define-fun X_INTRODUCED_824_ () Int
#     0)
#   (define-fun X_INTRODUCED_1008_ () Int
#     0)
#   (define-fun X_INTRODUCED_126_ () Bool
#     true)
#   (define-fun X_INTRODUCED_520_ () Bool
#     false)
#   (define-fun X_INTRODUCED_572_ () Int
#     0)
#   (define-fun X_INTRODUCED_322_ () Int
#     0)
#   (define-fun X_INTRODUCED_869_ () Bool
#     false)
#   (define-fun X_INTRODUCED_636_ () Bool
#     false)
#   (define-fun X_INTRODUCED_508_ () Int
#     0)
#   (define-fun X_INTRODUCED_528_ () Bool
#     true)
#   (define-fun X_INTRODUCED_174_ () Bool
#     false)
#   (define-fun X_INTRODUCED_791_ () Bool
#     false)
#   (define-fun X_INTRODUCED_42_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Int
#     14)
#   (define-fun X_INTRODUCED_1006_ () Int
#     0)
#   (define-fun X_INTRODUCED_368_ () Bool
#     true)
#   (define-fun X_INTRODUCED_102_ () Bool
#     false)
#   (define-fun X_INTRODUCED_545_ () Bool
#     false)
#   (define-fun X_INTRODUCED_755_ () Bool
#     false)
#   (define-fun X_INTRODUCED_640_ () Int
#     0)
#   (define-fun X_INTRODUCED_338_ () Int
#     0)
#   (define-fun X_INTRODUCED_44_ () Bool
#     false)
#   (define-fun X_INTRODUCED_447_ () Int
#     0)
#   (define-fun X_INTRODUCED_6_ () Int
#     15)
#   (define-fun X_INTRODUCED_670_ () Bool
#     false)
#   (define-fun X_INTRODUCED_19_ () Bool
#     false)
#   (define-fun X_INTRODUCED_268_ () Bool
#     false)
#   (define-fun X_INTRODUCED_306_ () Bool
#     false)
#   (define-fun X_INTRODUCED_269_ () Int
#     0)
#   (define-fun X_INTRODUCED_983_ () Int
#     0)
#   (define-fun X_INTRODUCED_366_ () Bool
#     false)
#   (define-fun X_INTRODUCED_955_ () Int
#     0)
#   (define-fun X_INTRODUCED_1052_ () Bool
#     true)
#   (define-fun X_INTRODUCED_352_ () Bool
#     false)
#   (define-fun X_INTRODUCED_710_ () Int
#     0)
#   (define-fun X_INTRODUCED_128_ () Bool
#     false)
#   (define-fun X_INTRODUCED_919_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1043_ () Bool
#     true)
#   (define-fun X_INTRODUCED_779_ () Bool
#     false)
#   (define-fun X_INTRODUCED_891_ () Int
#     0)
#   (define-fun X_INTRODUCED_281_ () Int
#     0)
#   (define-fun X_INTRODUCED_271_ () Bool
#     true)
#   (define-fun X_INTRODUCED_630_ () Bool
#     false)
#   (define-fun X_INTRODUCED_856_ () Int
#     0)
#   (define-fun X_INTRODUCED_649_ () Int
#     0)
#   (define-fun X_INTRODUCED_728_ () Int
#     0)
#   (define-fun X_INTRODUCED_68_ () Int
#     1)
#   (define-fun X_INTRODUCED_486_ () Bool
#     false)
#   (define-fun X_INTRODUCED_66_ () Bool
#     false)
#   (define-fun X_INTRODUCED_275_ () Bool
#     true)
#   (define-fun X_INTRODUCED_399_ () Bool
#     false)
#   (define-fun X_INTRODUCED_237_ () Int
#     0)
#   (define-fun X_INTRODUCED_413_ () Bool
#     false)
#   (define-fun X_INTRODUCED_279_ () Bool
#     true)
#   (define-fun X_INTRODUCED_319_ () Int
#     0)
#   (define-fun X_INTRODUCED_499_ () Int
#     0)
#   (define-fun X_INTRODUCED_433_ () Bool
#     true)
#   (define-fun X_INTRODUCED_356_ () Int
#     0)
#   (define-fun X_INTRODUCED_104_ () Bool
#     true)
#   (define-fun X_INTRODUCED_764_ () Bool
#     false)
#   (define-fun X_INTRODUCED_206_ () Bool
#     false)
#   (define-fun X_INTRODUCED_308_ () Int
#     0)
#   (define-fun X_INTRODUCED_263_ () Bool
#     true)
#   (define-fun X_INTRODUCED_39_ () Bool
#     false)
#   (define-fun X_INTRODUCED_558_ () Bool
#     false)
#   (define-fun X_INTRODUCED_541_ () Bool
#     true)
#   (define-fun X_INTRODUCED_761_ () Bool
#     false)
#   (define-fun X_INTRODUCED_349_ () Bool
#     false)
#   (define-fun X_INTRODUCED_407_ () Bool
#     false)
#   (define-fun X_INTRODUCED_463_ () Bool
#     true)
#   (define-fun X_INTRODUCED_176_ () Bool
#     true)
#   (define-fun X_INTRODUCED_243_ () Bool
#     true)
#   (define-fun X_INTRODUCED_334_ () Int
#     0)
#   (define-fun X_INTRODUCED_427_ () Int
#     0)
#   (define-fun X_INTRODUCED_309_ () Bool
#     true)
#   (define-fun X_INTRODUCED_783_ () Int
#     0)
#   (define-fun X_INTRODUCED_830_ () Bool
#     false)
#   (define-fun X_INTRODUCED_288_ () Int
#     0)
#   (define-fun X_INTRODUCED_71_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1004_ () Int
#     0)
#   (define-fun X_INTRODUCED_798_ () Bool
#     false)
#   (define-fun X_INTRODUCED_359_ () Int
#     0)
#   (define-fun X_INTRODUCED_337_ () Bool
#     false)
#   (define-fun X_INTRODUCED_396_ () Bool
#     false)
#   (define-fun X_INTRODUCED_175_ () Int
#     0)
#   (define-fun X_INTRODUCED_671_ () Int
#     0)
#   (define-fun X_INTRODUCED_311_ () Bool
#     false)
#   (define-fun X_INTRODUCED_329_ () Bool
#     false)
#   (define-fun X_INTRODUCED_960_ () Int
#     0)
#   (define-fun X_INTRODUCED_716_ () Int
#     0)
#   (define-fun X_INTRODUCED_507_ () Bool
#     false)
#   (define-fun X_INTRODUCED_290_ () Bool
#     false)
#   (define-fun X_INTRODUCED_947_ () Bool
#     false)
#   (define-fun X_INTRODUCED_769_ () Int
#     0)
#   (define-fun X_INTRODUCED_79_ () Int
#     0)
#   (define-fun X_INTRODUCED_267_ () Bool
#     true)
#   (define-fun X_INTRODUCED_242_ () Bool
#     false)
#   (define-fun X_INTRODUCED_332_ () Bool
#     false)
#   (define-fun X_INTRODUCED_493_ () Int
#     0)
#   (define-fun X_INTRODUCED_211_ () Bool
#     false)
#   (define-fun X_INTRODUCED_190_ () Bool
#     false)
#   (define-fun X_INTRODUCED_231_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1022_ () Bool
#     false)
#   (define-fun X_INTRODUCED_970_ () Int
#     0)
#   (define-fun X_INTRODUCED_794_ () Bool
#     false)
#   (define-fun X_INTRODUCED_440_ () Bool
#     false)
#   (define-fun X_INTRODUCED_689_ () Bool
#     false)
#   (define-fun X_INTRODUCED_173_ () Bool
#     false)
#   (define-fun X_INTRODUCED_976_ () Bool
#     false)
#   (define-fun X_INTRODUCED_804_ () Bool
#     false)
#   (define-fun X_INTRODUCED_765_ () Bool
#     false)
#   (define-fun X_INTRODUCED_3_ () Int
#     9)
#   (define-fun X_INTRODUCED_966_ () Int
#     0)
#   (define-fun X_INTRODUCED_298_ () Bool
#     true)
#   (define-fun X_INTRODUCED_438_ () Int
#     0)
#   (define-fun X_INTRODUCED_428_ () Bool
#     true)
#   (define-fun X_INTRODUCED_4_ () Int
#     6)
#   (define-fun X_INTRODUCED_652_ () Bool
#     false)
#   (define-fun X_INTRODUCED_776_ () Bool
#     false)
#   (define-fun X_INTRODUCED_76_ () Int
#     0)
#   (define-fun X_INTRODUCED_373_ () Bool
#     true)
#   (define-fun X_INTRODUCED_330_ () Int
#     0)
#   (define-fun X_INTRODUCED_899_ () Int
#     0)
#   (define-fun X_INTRODUCED_861_ () Bool
#     false)
#   (define-fun X_INTRODUCED_274_ () Bool
#     false)
#   (define-fun X_INTRODUCED_101_ () Bool
#     true)
#   (define-fun X_INTRODUCED_119_ () Bool
#     true)
#   (define-fun X_INTRODUCED_523_ () Bool
#     false)
#   (define-fun X_INTRODUCED_614_ () Bool
#     false)
#   (define-fun X_INTRODUCED_963_ () Bool
#     false)
#   (define-fun X_INTRODUCED_926_ () Int
#     0)
#   (define-fun X_INTRODUCED_1021_ () Bool
#     false)
#   (define-fun X_INTRODUCED_787_ () Bool
#     false)
#   (define-fun X_INTRODUCED_510_ () Bool
#     false)
#   (define-fun X_INTRODUCED_646_ () Int
#     0)
#   (define-fun X_INTRODUCED_574_ () Bool
#     false)
#   (define-fun X_INTRODUCED_27_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_813_ () Bool
#     false)
#   (define-fun X_INTRODUCED_585_ () Bool
#     true)
#   (define-fun X_INTRODUCED_351_ () Bool
#     false)
#   (define-fun X_INTRODUCED_690_ () Int
#     0)
#   (define-fun X_INTRODUCED_340_ () Bool
#     false)
#   (define-fun X_INTRODUCED_920_ () Int
#     0)
#   (define-fun X_INTRODUCED_727_ () Bool
#     false)
#   (define-fun X_INTRODUCED_874_ () Int
#     0)
#   (define-fun X_INTRODUCED_864_ () Int
#     0)
#   (define-fun X_INTRODUCED_894_ () Int
#     0)
#   (define-fun X_INTRODUCED_361_ () Bool
#     false)
#   (define-fun X_INTRODUCED_249_ () Int
#     0)
#   (define-fun X_INTRODUCED_488_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1042_ () Bool
#     false)
#   (define-fun X_INTRODUCED_948_ () Int
#     0)
#   (define-fun X_INTRODUCED_426_ () Bool
#     false)
#   (define-fun X_INTRODUCED_801_ () Bool
#     false)
#   (define-fun X_INTRODUCED_875_ () Bool
#     false)
#   (define-fun X_INTRODUCED_752_ () Bool
#     false)
#   (define-fun X_INTRODUCED_849_ () Bool
#     false)
#   (define-fun X_INTRODUCED_879_ () Bool
#     false)
#   (define-fun X_INTRODUCED_707_ () Int
#     0)
#   (define-fun X_INTRODUCED_89_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1039_ () Bool
#     false)
#   (define-fun X_INTRODUCED_497_ () Bool
#     true)
#   (define-fun X_INTRODUCED_587_ () Int
#     0)
#   (define-fun X_INTRODUCED_435_ () Int
#     0)
#   (define-fun X_INTRODUCED_529_ () Bool
#     false)
#   (define-fun X_INTRODUCED_610_ () Int
#     0)
#   (define-fun X_INTRODUCED_553_ () Int
#     0)
#   (define-fun X_INTRODUCED_664_ () Bool
#     false)
#   (define-fun X_INTRODUCED_559_ () Int
#     0)
#   (define-fun X_INTRODUCED_273_ () Int
#     0)
#   (define-fun X_INTRODUCED_757_ () Int
#     0)
#   (define-fun X_INTRODUCED_600_ () Bool
#     false)
#   (define-fun X_INTRODUCED_622_ () Int
#     0)
#   (define-fun X_INTRODUCED_142_ () Bool
#     true)
#   (define-fun X_INTRODUCED_380_ () Bool
#     false)
#   (define-fun X_INTRODUCED_554_ () Bool
#     false)
#   (define-fun X_INTRODUCED_386_ () Bool
#     false)
#   (define-fun X_INTRODUCED_936_ () Int
#     0)
#   (define-fun X_INTRODUCED_665_ () Int
#     0)
#   (define-fun X_INTRODUCED_784_ () Bool
#     false)
#   (define-fun X_INTRODUCED_822_ () Int
#     0)
#   (define-fun X_INTRODUCED_767_ () Bool
#     false)
#   (define-fun X_INTRODUCED_100_ () Bool
#     false)
#   (define-fun X_INTRODUCED_538_ () Bool
#     false)
#   (define-fun X_INTRODUCED_625_ () Int
#     0)
#   (define-fun X_INTRODUCED_602_ () Bool
#     false)
#   (define-fun X_INTRODUCED_223_ () Bool
#     false)
#   (define-fun X_INTRODUCED_943_ () Bool
#     false)
#   (define-fun X_INTRODUCED_240_ () Bool
#     false)
#   (define-fun X_INTRODUCED_882_ () Int
#     0)
#   (define-fun X_INTRODUCED_637_ () Int
#     0)
#   (define-fun obj () Int
#     1)
#   (define-fun X_INTRODUCED_254_ () Bool
#     false)
#   (define-fun X_INTRODUCED_460_ () Int
#     0)
#   (define-fun X_INTRODUCED_451_ () Bool
#     false)
#   (define-fun X_INTRODUCED_248_ () Bool
#     false)
#   (define-fun X_INTRODUCED_712_ () Bool
#     false)
#   (define-fun X_INTRODUCED_673_ () Bool
#     false)
#   (define-fun X_INTRODUCED_78_ () Int
#     0)
#   (define-fun X_INTRODUCED_944_ () Int
#     0)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_29_ () Bool
#     false)
#   (define-fun X_INTRODUCED_210_ () Bool
#     false)
#   (define-fun X_INTRODUCED_327_ () Bool
#     false)
#   (define-fun X_INTRODUCED_429_ () Bool
#     false)
#   (define-fun X_INTRODUCED_934_ () Bool
#     false)
#   (define-fun X_INTRODUCED_135_ () Bool
#     true)
#   (define-fun X_INTRODUCED_115_ () Int
#     0)
#   (define-fun X_INTRODUCED_871_ () Int
#     0)
#   (define-fun X_INTRODUCED_831_ () Bool
#     false)
#   (define-fun X_INTRODUCED_877_ () Int
#     0)
#   (define-fun X_INTRODUCED_1030_ () Int
#     0)
#   (define-fun X_INTRODUCED_583_ () Bool
#     false)
#   (define-fun X_INTRODUCED_929_ () Bool
#     false)
#   (define-fun X_INTRODUCED_662_ () Int
#     0)
#   (define-fun X_INTRODUCED_443_ () Bool
#     false)
#   (define-fun X_INTRODUCED_629_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1002_ () Int
#     0)
#   (define-fun X_INTRODUCED_444_ () Int
#     0)
#   (define-fun X_INTRODUCED_300_ () Int
#     0)
#   (define-fun X_INTRODUCED_816_ () Int
#     0)
#   (define-fun X_INTRODUCED_633_ () Bool
#     false)
#   (define-fun X_INTRODUCED_291_ () Int
#     0)
#   (define-fun X_INTRODUCED_514_ () Bool
#     true)
#   (define-fun X_INTRODUCED_932_ () Bool
#     false)
#   (define-fun X_INTRODUCED_358_ () Bool
#     false)
#   (define-fun X_INTRODUCED_459_ () Bool
#     false)
#   (define-fun X_INTRODUCED_763_ () Int
#     0)
#   (define-fun X_INTRODUCED_169_ () Bool
#     true)
#   (define-fun X_INTRODUCED_32_ () Bool
#     false)
#   (define-fun X_INTRODUCED_37_ () Bool
#     false)
#   (define-fun X_INTRODUCED_105_ () Bool
#     false)
#   (define-fun X_INTRODUCED_49_ () Bool
#     false)
#   (define-fun X_INTRODUCED_736_ () Bool
#     false)
#   (define-fun X_INTRODUCED_251_ () Bool
#     false)
#   (define-fun X_INTRODUCED_245_ () Int
#     0)
#   (define-fun X_INTRODUCED_467_ () Bool
#     false)
#   (define-fun X_INTRODUCED_132_ () Bool
#     false)
#   (define-fun X_INTRODUCED_986_ () Bool
#     false)
#   (define-fun X_INTRODUCED_153_ () Bool
#     false)
#   (define-fun X_INTRODUCED_495_ () Bool
#     false)
#   (define-fun X_INTRODUCED_527_ () Int
#     0)
#   (define-fun X_INTRODUCED_196_ () Int
#     0)
#   (define-fun X_INTRODUCED_295_ () Bool
#     false)
#   (define-fun X_INTRODUCED_768_ () Bool
#     false)
#   (define-fun X_INTRODUCED_235_ () Bool
#     true)
#   (define-fun X_INTRODUCED_158_ () Bool
#     false)
#   (define-fun X_INTRODUCED_516_ () Int
#     0)
#   (define-fun X_INTRODUCED_466_ () Bool
#     true)
#   (define-fun X_INTRODUCED_858_ () Int
#     0)
#   (define-fun X_INTRODUCED_346_ () Bool
#     false)
#   (define-fun X_INTRODUCED_615_ () Bool
#     false)
#   (define-fun X_INTRODUCED_906_ () Bool
#     false)
#   (define-fun X_INTRODUCED_350_ () Int
#     0)
#   (define-fun X_INTRODUCED_725_ () Bool
#     false)
#   (define-fun X_INTRODUCED_378_ () Int
#     0)
#   (define-fun X_INTRODUCED_698_ () Bool
#     false)
#   (define-fun X_INTRODUCED_387_ () Bool
#     true)
#   (define-fun X_INTRODUCED_938_ () Int
#     0)
#   (define-fun X_INTRODUCED_75_ () Int
#     0)
#   (define-fun X_INTRODUCED_421_ () Bool
#     false)
#   (define-fun X_INTRODUCED_975_ () Int
#     0)
#   (define-fun X_INTRODUCED_797_ () Int
#     0)
#   (define-fun X_INTRODUCED_90_ () Bool
#     false)
#   (define-fun X_INTRODUCED_113_ () Bool
#     false)
#   (define-fun X_INTRODUCED_501_ () Bool
#     false)
#   (define-fun X_INTRODUCED_845_ () Bool
#     false)
#   (define-fun X_INTRODUCED_270_ () Bool
#     false)
#   (define-fun X_INTRODUCED_935_ () Bool
#     false)
#   (define-fun X_INTRODUCED_106_ () Bool
#     false)
#   (define-fun X_INTRODUCED_659_ () Int
#     0)
#   (define-fun X_INTRODUCED_655_ () Bool
#     false)
#   (define-fun X_INTRODUCED_971_ () Bool
#     false)
#   (define-fun X_INTRODUCED_683_ () Bool
#     false)
#   (define-fun X_INTRODUCED_900_ () Bool
#     false)
#   (define-fun X_INTRODUCED_834_ () Bool
#     false)
#   (define-fun X_INTRODUCED_980_ () Bool
#     false)
#   (define-fun X_INTRODUCED_107_ () Int
#     0)
#   (define-fun X_INTRODUCED_621_ () Bool
#     false)
#   (define-fun X_INTRODUCED_979_ () Int
#     0)
#   (define-fun X_INTRODUCED_1028_ () Int
#     0)
#   (define-fun X_INTRODUCED_425_ () Bool
#     false)
#   (define-fun X_INTRODUCED_619_ () Int
#     0)
#   (define-fun X_INTRODUCED_991_ () Int
#     0)
#   (define-fun X_INTRODUCED_760_ () Int
#     0)
#   (define-fun X_INTRODUCED_555_ () Bool
#     false)
#   (define-fun X_INTRODUCED_262_ () Bool
#     false)
#   (define-fun X_INTRODUCED_98_ () Bool
#     false)
#   (define-fun X_INTRODUCED_838_ () Int
#     0)
#   (define-fun X_INTRODUCED_395_ () Bool
#     false)
#   (define-fun X_INTRODUCED_933_ () Int
#     0)
#   (define-fun X_INTRODUCED_721_ () Bool
#     false)
#   (define-fun X_INTRODUCED_594_ () Bool
#     false)
#   (define-fun X_INTRODUCED_166_ () Bool
#     false)
#   (define-fun X_INTRODUCED_522_ () Bool
#     true)
#   (define-fun X_INTRODUCED_827_ () Bool
#     false)
#   (define-fun X_INTRODUCED_928_ () Int
#     0)
#   (define-fun X_INTRODUCED_803_ () Bool
#     false)
#   (define-fun X_INTRODUCED_253_ () Int
#     0)
#   (define-fun X_INTRODUCED_238_ () Bool
#     false)
#   (define-fun X_INTRODUCED_180_ () Bool
#     true)
#   (define-fun X_INTRODUCED_810_ () Bool
#     false)
#   (define-fun X_INTRODUCED_734_ () Int
#     0)
#   (define-fun X_INTRODUCED_969_ () Bool
#     false)
#   (define-fun X_INTRODUCED_589_ () Bool
#     false)
#   (define-fun X_INTRODUCED_890_ () Bool
#     false)
#   (define-fun X_INTRODUCED_170_ () Bool
#     false)
#   (define-fun X_INTRODUCED_408_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1048_ () Bool
#     true)
#   (define-fun X_INTRODUCED_863_ () Bool
#     false)
#   (define-fun X_INTRODUCED_536_ () Int
#     0)
#   (define-fun X_INTRODUCED_550_ () Int
#     0)
#   (define-fun X_INTRODUCED_907_ () Int
#     0)
#   (define-fun X_INTRODUCED_69_ () Bool
#     false)
#   (define-fun X_INTRODUCED_24_ () Bool
#     true)
#   (define-fun X_INTRODUCED_136_ () Bool
#     false)
#   (define-fun X_INTRODUCED_185_ () Bool
#     true)
#   (define-fun X_INTRODUCED_294_ () Bool
#     true)
#   (define-fun X_INTRODUCED_99_ () Int
#     0)
#   (define-fun X_INTRODUCED_676_ () Int
#     0)
#   (define-fun X_INTRODUCED_701_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1023_ () Bool
#     false)
#   (define-fun X_INTRODUCED_204_ () Int
#     0)
#   (define-fun X_INTRODUCED_0_ () Int
#     8)
#   (define-fun X_INTRODUCED_632_ () Bool
#     false)
#   (define-fun X_INTRODUCED_423_ () Int
#     0)
#   (define-fun X_INTRODUCED_160_ () Bool
#     true)
#   (define-fun X_INTRODUCED_131_ () Bool
#     true)
#   (define-fun X_INTRODUCED_661_ () Bool
#     false)
#   (define-fun X_INTRODUCED_213_ () Bool
#     true)
#   (define-fun X_INTRODUCED_742_ () Bool
#     false)
#   (define-fun X_INTRODUCED_133_ () Int
#     0)
#   (define-fun X_INTRODUCED_94_ () Bool
#     false)
#   (define-fun X_INTRODUCED_171_ () Int
#     0)
#   (define-fun X_INTRODUCED_430_ () Bool
#     false)
#   (define-fun X_INTRODUCED_565_ () Int
#     0)
#   (define-fun X_INTRODUCED_354_ () Bool
#     false)
#   (define-fun X_INTRODUCED_607_ () Int
#     0)
#   (define-fun X_INTRODUCED_333_ () Bool
#     false)
#   (define-fun X_INTRODUCED_255_ () Bool
#     false)
#   (define-fun X_INTRODUCED_884_ () Int
#     0)
#   (define-fun X_INTRODUCED_1045_ () Bool
#     true)
#   (define-fun X_INTRODUCED_885_ () Bool
#     false)
#   (define-fun X_INTRODUCED_85_ () Bool
#     true)
#   (define-fun X_INTRODUCED_302_ () Bool
#     false)
#   (define-fun X_INTRODUCED_382_ () Bool
#     true)
#   (define-fun X_INTRODUCED_420_ () Bool
#     true)
#   (define-fun X_INTRODUCED_795_ () Int
#     0)
#   (define-fun X_INTRODUCED_415_ () Int
#     0)
#   (define-fun X_INTRODUCED_694_ () Bool
#     false)
#   (define-fun X_INTRODUCED_482_ () Bool
#     false)
#   (define-fun X_INTRODUCED_195_ () Bool
#     false)
#   (define-fun X_INTRODUCED_711_ () Bool
#     false)
#   (define-fun X_INTRODUCED_562_ () Int
#     0)
#   (define-fun X_INTRODUCED_537_ () Bool
#     false)
#   (define-fun X_INTRODUCED_843_ () Bool
#     false)
#   (define-fun X_INTRODUCED_110_ () Bool
#     false)
#   (define-fun X_INTRODUCED_959_ () Bool
#     false)
#   (define-fun X_INTRODUCED_634_ () Int
#     0)
#   (define-fun X_INTRODUCED_686_ () Bool
#     false)
#   (define-fun X_INTRODUCED_232_ () Bool
#     false)
#   (define-fun X_INTRODUCED_365_ () Bool
#     false)
#   (define-fun X_INTRODUCED_252_ () Bool
#     false)
#   (define-fun X_INTRODUCED_409_ () Int
#     0)
#   (define-fun X_INTRODUCED_674_ () Int
#     0)
#   (define-fun X_INTRODUCED_881_ () Bool
#     false)
#   (define-fun X_INTRODUCED_786_ () Int
#     0)
#   (define-fun X_INTRODUCED_81_ () Int
#     0)
#   (define-fun X_INTRODUCED_518_ () Int
#     0)
#   (define-fun X_INTRODUCED_648_ () Bool
#     false)
#   (define-fun X_INTRODUCED_417_ () Bool
#     false)
#   (define-fun X_INTRODUCED_505_ () Int
#     0)
#   (define-fun X_INTRODUCED_618_ () Bool
#     false)
#   (define-fun X_INTRODUCED_645_ () Bool
#     false)
#   (define-fun X_INTRODUCED_846_ () Bool
#     false)
#   (define-fun X_INTRODUCED_233_ () Int
#     0)
#   (define-fun X_INTRODUCED_272_ () Bool
#     false)
#   (define-fun X_INTRODUCED_817_ () Bool
#     false)
#   (define-fun X_INTRODUCED_178_ () Bool
#     false)
#   (define-fun X_INTRODUCED_579_ () Bool
#     false)
#   (define-fun X_INTRODUCED_496_ () Int
#     0)
#   (define-fun X_INTRODUCED_785_ () Bool
#     false)
#   (define-fun X_INTRODUCED_651_ () Bool
#     false)
#   (define-fun X_INTRODUCED_212_ () Int
#     0)
#   (define-fun X_INTRODUCED_903_ () Int
#     0)
#   (define-fun X_INTRODUCED_611_ () Bool
#     false)
#   (define-fun X_INTRODUCED_584_ () Int
#     0)
#   (define-fun X_INTRODUCED_394_ () Bool
#     true)
#   (define-fun X_INTRODUCED_998_ () Int
#     0)
#   (define-fun X_INTRODUCED_502_ () Int
#     0)
#   (define-fun X_INTRODUCED_751_ () Int
#     0)
#   (define-fun X_INTRODUCED_297_ () Bool
#     false)
#   (define-fun X_INTRODUCED_684_ () Int
#     0)
#   (define-fun X_INTRODUCED_191_ () Bool
#     false)
#   (define-fun X_INTRODUCED_777_ () Int
#     0)
#   (define-fun X_INTRODUCED_200_ () Int
#     0)
#   (define-fun X_INTRODUCED_693_ () Int
#     0)
#   (define-fun X_INTRODUCED_393_ () Int
#     0)
#   (define-fun X_INTRODUCED_749_ () Int
#     0)
#   (define-fun X_INTRODUCED_923_ () Bool
#     false)
#   (define-fun X_INTRODUCED_957_ () Bool
#     false)
#   (define-fun X_INTRODUCED_964_ () Int
#     0)
#   (define-fun X_INTRODUCED_753_ () Bool
#     false)
#   (define-fun X_INTRODUCED_410_ () Bool
#     false)
#   (define-fun X_INTRODUCED_398_ () Bool
#     true)
#   (define-fun X_INTRODUCED_140_ () Bool
#     false)
#   (define-fun X_INTRODUCED_609_ () Bool
#     false)
#   (define-fun X_INTRODUCED_208_ () Int
#     0)
#   (define-fun X_INTRODUCED_524_ () Int
#     0)
#   (define-fun X_INTRODUCED_593_ () Int
#     0)
#   (define-fun X_INTRODUCED_20_ () Bool
#     true)
#   (define-fun X_INTRODUCED_1051_ () Bool
#     false)
#   (define-fun X_INTRODUCED_997_ () Bool
#     false)
#   (define-fun X_INTRODUCED_512_ () Int
#     0)
#   (define-fun X_INTRODUCED_914_ () Int
#     0)
#   (define-fun X_INTRODUCED_660_ () Bool
#     false)
#   (define-fun X_INTRODUCED_462_ () Int
#     0)
#   (define-fun X_INTRODUCED_377_ () Bool
#     false)
#   (define-fun X_INTRODUCED_912_ () Bool
#     true)
#   (define-fun X_INTRODUCED_33_ () Int
#     1)
#   (define-fun X_INTRODUCED_577_ () Bool
#     false)
#   (define-fun X_INTRODUCED_324_ () Bool
#     false)
#   (define-fun X_INTRODUCED_335_ () Bool
#     true)
#   (define-fun X_INTRODUCED_868_ () Int
#     0)
#   (define-fun X_INTRODUCED_847_ () Int
#     0)
#   (define-fun X_INTRODUCED_692_ () Bool
#     false)
#   (define-fun X_INTRODUCED_837_ () Bool
#     false)
#   (define-fun M () Int
#     0)
#   (define-fun X_INTRODUCED_519_ () Bool
#     true)
#   (define-fun X_INTRODUCED_617_ () Bool
#     true)
#   (define-fun X_INTRODUCED_668_ () Int
#     0)
#   (define-fun X_INTRODUCED_383_ () Bool
#     false)
#   (define-fun X_INTRODUCED_942_ () Int
#     0)
#   (define-fun X_INTRODUCED_392_ () Bool
#     false)
#   (define-fun X_INTRODUCED_321_ () Bool
#     false)
#   (define-fun X_INTRODUCED_457_ () Bool
#     true)
#   (define-fun X_INTRODUCED_825_ () Bool
#     false)
#   (define-fun X_INTRODUCED_855_ () Bool
#     false)
#   (define-fun X_INTRODUCED_8_ () Int
#     11)
#   (define-fun X_INTRODUCED_709_ () Bool
#     false)
#   (define-fun X_INTRODUCED_326_ () Int
#     0)
#   (define-fun X_INTRODUCED_580_ () Bool
#     false)
#   (define-fun X_INTRODUCED_924_ () Int
#     0)
#   (define-fun X_INTRODUCED_1000_ () Int
#     0)
#   (define-fun X_INTRODUCED_564_ () Bool
#     false)
#   (define-fun X_INTRODUCED_658_ () Bool
#     false)
#   (define-fun X_INTRODUCED_370_ () Bool
#     false)
#   (define-fun X_INTRODUCED_152_ () Bool
#     false)
#   (define-fun X_INTRODUCED_62_ () Bool
#     false)
#   (define-fun X_INTRODUCED_405_ () Bool
#     false)
#   (define-fun X_INTRODUCED_902_ () Bool
#     false)
#   (define-fun X_INTRODUCED_941_ () Bool
#     false)
#   (define-fun X_INTRODUCED_921_ () Bool
#     false)
#   (define-fun X_INTRODUCED_52_ () Bool
#     false)
#   (define-fun X_INTRODUCED_972_ () Bool
#     false)
#   (define-fun X_INTRODUCED_922_ () Int
#     0)
#   (define-fun X_INTRODUCED_477_ () Int
#     0)
#   (define-fun X_INTRODUCED_808_ () Int
#     0)
#   (define-fun X_INTRODUCED_939_ () Bool
#     false)
#   (define-fun X_INTRODUCED_733_ () Bool
#     false)
#   (define-fun X_INTRODUCED_283_ () Int
#     0)
#   (define-fun X_INTRODUCED_53_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_93_ () Bool
#     false)
#   (define-fun X_INTRODUCED_371_ () Int
#     0)
#   (define-fun X_INTRODUCED_1014_ () Int
#     1)
#   (define-fun X_INTRODUCED_46_ () Bool
#     false)
#   (define-fun X_INTRODUCED_772_ () Bool
#     false)
#   (define-fun X_INTRODUCED_478_ () Bool
#     true)
#   (define-fun X_INTRODUCED_241_ () Int
#     0)
#   (define-fun X_INTRODUCED_199_ () Bool
#     false)
#   (define-fun X_INTRODUCED_867_ () Bool
#     false)
#   (define-fun X_INTRODUCED_172_ () Bool
#     true)
#   (define-fun X_INTRODUCED_705_ () Int
#     0)
#   (define-fun X_INTRODUCED_422_ () Bool
#     false)
#   (define-fun X_INTRODUCED_771_ () Int
#     0)
#   (define-fun X_INTRODUCED_1_ () Int
#     3)
#   (define-fun X_INTRODUCED_873_ () Bool
#     false)
#   (define-fun X_INTRODUCED_984_ () Bool
#     false)
#   (define-fun X_INTRODUCED_379_ () Bool
#     true)
#   (define-fun X_INTRODUCED_592_ () Bool
#     false)
#   (define-fun X_INTRODUCED_214_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1040_ () Bool
#     true)
#   (define-fun X_INTRODUCED_582_ () Bool
#     true)
#   (define-fun X_INTRODUCED_774_ () Bool
#     false)
#   (define-fun X_INTRODUCED_123_ () Bool
#     false)
#   (define-fun X_INTRODUCED_506_ () Bool
#     false)
#   (define-fun X_INTRODUCED_73_ () Int
#     0)
#   (define-fun X_INTRODUCED_973_ () Int
#     0)
#   (define-fun X_INTRODUCED_780_ () Int
#     0)
#   (define-fun X_INTRODUCED_560_ () Bool
#     false)
#   (define-fun X_INTRODUCED_826_ () Int
#     0)
#   (define-fun X_INTRODUCED_446_ () Bool
#     false)
#   (define-fun X_INTRODUCED_120_ () Bool
#     false)
#   (define-fun X_INTRODUCED_367_ () Int
#     0)
#   (define-fun X_INTRODUCED_988_ () Bool
#     false)
#   (define-fun X_INTRODUCED_205_ () Bool
#     true)
#   (define-fun X_INTRODUCED_186_ () Bool
#     false)
#   (define-fun X_INTRODUCED_239_ () Bool
#     true)
#   (define-fun X_INTRODUCED_437_ () Bool
#     false)
#   (define-fun X_INTRODUCED_452_ () Int
#     0)
#   (define-fun X_INTRODUCED_745_ () Bool
#     false)
#   (define-fun X_INTRODUCED_314_ () Bool
#     false)
#   (define-fun X_INTRODUCED_605_ () Bool
#     true)
#   (define-fun X_INTRODUCED_118_ () Bool
#     false)
#   (define-fun X_INTRODUCED_872_ () Bool
#     false)
#   (define-fun X_INTRODUCED_480_ () Int
#     0)
#   (define-fun X_INTRODUCED_994_ () Int
#     0)
#   (define-fun X_INTRODUCED_534_ () Bool
#     true)
#   (define-fun X_INTRODUCED_802_ () Int
#     0)
#   (define-fun X_INTRODUCED_345_ () Bool
#     false)
#   (define-fun X_INTRODUCED_952_ () Int
#     0)
#   (define-fun X_INTRODUCED_1036_ () Bool
#     true)
#   (define-fun X_INTRODUCED_962_ () Int
#     0)
#   (define-fun X_INTRODUCED_905_ () Int
#     0)
#   (define-fun X_INTRODUCED_183_ () Int
#     0)
#   (define-fun X_INTRODUCED_913_ () Bool
#     false)
#   (define-fun X_INTRODUCED_888_ () Int
#     0)
#   (define-fun X_INTRODUCED_277_ () Int
#     0)
#   (define-fun X_INTRODUCED_26_ () Bool
#     true)
#   (define-fun X_INTRODUCED_949_ () Bool
#     false)
#   (define-fun X_INTRODUCED_56_ () Bool
#     false)
#   (define-fun X_INTRODUCED_821_ () Bool
#     false)
#   (define-fun X_INTRODUCED_570_ () Int
#     0)
#   (define-fun X_INTRODUCED_814_ () Int
#     0)
#   (define-fun X_INTRODUCED_469_ () Bool
#     false)
#   (define-fun X_INTRODUCED_261_ () Int
#     0)
#   (define-fun X_INTRODUCED_390_ () Bool
#     true)
#   (define-fun X_INTRODUCED_532_ () Bool
#     false)
#   (define-fun X_INTRODUCED_483_ () Bool
#     true)
#   (define-fun X_INTRODUCED_77_ () Int
#     0)
#   (define-fun X_INTRODUCED_57_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1024_ () Bool
#     true)
#   (define-fun X_INTRODUCED_531_ () Bool
#     true)
#   (define-fun X_INTRODUCED_999_ () Bool
#     false)
#   (define-fun X_INTRODUCED_547_ () Int
#     0)
#   (define-fun X_INTRODUCED_699_ () Int
#     0)
#   (define-fun X_INTRODUCED_289_ () Bool
#     false)
#   (define-fun X_INTRODUCED_828_ () Bool
#     false)
#   (define-fun X_INTRODUCED_557_ () Bool
#     false)
#   (define-fun X_INTRODUCED_165_ () Bool
#     false)
#   (define-fun X_INTRODUCED_325_ () Bool
#     false)
#   (define-fun X_INTRODUCED_606_ () Bool
#     false)
#   (define-fun X_INTRODUCED_47_ () Bool
#     false)
#   (define-fun X_INTRODUCED_318_ () Bool
#     false)
#   (define-fun X_INTRODUCED_930_ () Int
#     0)
#   (define-fun X_INTRODUCED_473_ () Bool
#     false)
#   (define-fun X_INTRODUCED_639_ () Bool
#     false)
#   (define-fun X_INTRODUCED_355_ () Bool
#     false)
#   (define-fun X_INTRODUCED_775_ () Int
#     0)
#   (define-fun X_INTRODUCED_227_ () Bool
#     true)
#   (define-fun X_INTRODUCED_916_ () Bool
#     false)
#   (define-fun X_INTRODUCED_682_ () Bool
#     false)
#   (define-fun X_INTRODUCED_201_ () Bool
#     false)
#   (define-fun X_INTRODUCED_31_ () Bool
#     false)
#   (define-fun X_INTRODUCED_485_ () Int
#     0)
#   (define-fun X_INTRODUCED_595_ () Bool
#     false)
#   (define-fun X_INTRODUCED_471_ () Int
#     0)
#   (define-fun X_INTRODUCED_54_ () Bool
#     false)
#   (define-fun X_INTRODUCED_72_ () Bool
#     false)
#   (define-fun X_INTRODUCED_121_ () Int
#     0)
#   (define-fun X_INTRODUCED_927_ () Bool
#     false)
#   (define-fun X_INTRODUCED_331_ () Bool
#     true)
#   (define-fun X_INTRODUCED_130_ () Bool
#     false)
#   (define-fun X_INTRODUCED_748_ () Bool
#     false)
#   (define-fun X_INTRODUCED_179_ () Int
#     0)
#   (define-fun X_INTRODUCED_207_ () Bool
#     false)
#   (define-fun X_INTRODUCED_526_ () Bool
#     false)
#   (define-fun X_INTRODUCED_112_ () Bool
#     true)
#   (define-fun X_INTRODUCED_189_ () Bool
#     true)
#   (define-fun X_INTRODUCED_549_ () Bool
#     false)
#   (define-fun X_INTRODUCED_125_ () Int
#     0)
#   (define-fun X_INTRODUCED_1019_ () Bool
#     false)
#   (define-fun X_INTRODUCED_144_ () Bool
#     false)
#   (define-fun X_INTRODUCED_981_ () Int
#     0)
#   (define-fun X_INTRODUCED_70_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_65_ () Int
#     1)
#   (define-fun X_INTRODUCED_60_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_55_ () Int
#     1)
#   (define-fun X_INTRODUCED_50_ () Int
#     1)
#   (define-fun X_INTRODUCED_45_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_40_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_35_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_30_ () Int
#     1)
#   (define-fun N () Int
#     1)
#   (define-fun X_INTRODUCED_1026_ () Int
#     0)
#   (define-fun X_INTRODUCED_977_ () Int
#     0)
#   (define-fun X_INTRODUCED_940_ () Int
#     0)
#   (define-fun X_INTRODUCED_901_ () Int
#     0)
#   (define-fun X_INTRODUCED_860_ () Int
#     0)
#   (define-fun X_INTRODUCED_818_ () Int
#     0)
#   (define-fun X_INTRODUCED_773_ () Int
#     0)
#   (define-fun X_INTRODUCED_726_ () Int
#     0)
#   (define-fun X_INTRODUCED_678_ () Int
#     0)
#   (define-fun X_INTRODUCED_628_ () Int
#     0)
#   (define-fun X_INTRODUCED_575_ () Int
#     0)
#   (define-fun X_INTRODUCED_521_ () Int
#     0)
#   (define-fun X_INTRODUCED_465_ () Int
#     0)
#   (define-fun X_INTRODUCED_406_ () Int
#     0)
#   (define-fun X_INTRODUCED_347_ () Int
#     0)
#   (define-fun X_INTRODUCED_286_ () Int
#     0)
#   (define-fun X_INTRODUCED_221_ () Int
#     0)
#   (define-fun X_INTRODUCED_154_ () Int
#     0)
#   (define-fun X_INTRODUCED_87_ () Int
#     0)
#   (define-fun S () Int
#     0)
#   (define-fun X_INTRODUCED_17_ () Int
#     12)
#   (define-fun X_INTRODUCED_16_ () Int
#     13)
#   (define-fun X_INTRODUCED_15_ () Int
#     16)
#   (define-fun X_INTRODUCED_14_ () Int
#     1)
#   (define-fun X_INTRODUCED_13_ () Int
#     5)
#   (define-fun X_INTRODUCED_12_ () Int
#     10)
#   (define-fun X_INTRODUCED_11_ () Int
#     18)
#   (define-fun X_INTRODUCED_10_ () Int
#     4)
#   (define-fun X_INTRODUCED_9_ () Int
#     7)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz2-noAbs/v3/R033-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 264)
# )
# (model
#   (define-fun X_INTRODUCED_36_ () Bool
#     false)
#   (define-fun X_INTRODUCED_61_ () Int
#     0)
#   (define-fun X_INTRODUCED_126_ () Int
#     3)
#   (define-fun X_INTRODUCED_79_ () Int
#     0)
#   (define-fun X_INTRODUCED_73_ () Bool
#     false)
#   (define-fun X_INTRODUCED_81_ () Bool
#     false)
#   (define-fun X_INTRODUCED_32_ () Bool
#     true)
#   (define-fun X_INTRODUCED_37_ () Int
#     0)
#   (define-fun X_INTRODUCED_49_ () Int
#     1)
#   (define-fun X_INTRODUCED_55_ () Bool
#     true)
#   (define-fun X_INTRODUCED_117_ () Bool
#     false)
#   (define-fun X_INTRODUCED_132_ () Bool
#     false)
#   (define-fun X_INTRODUCED_97_ () Int
#     0)
#   (define-fun X_INTRODUCED_120_ () Int
#     0)
#   (define-fun X_INTRODUCED_40_ () Bool
#     false)
#   (define-fun X_INTRODUCED_42_ () Bool
#     false)
#   (define-fun X_INTRODUCED_13_ () Bool
#     false)
#   (define-fun X_INTRODUCED_92_ () Bool
#     false)
#   (define-fun X_INTRODUCED_88_ () Bool
#     true)
#   (define-fun X_INTRODUCED_119_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Bool
#     false)
#   (define-fun X_INTRODUCED_102_ () Bool
#     true)
#   (define-fun X_INTRODUCED_114_ () Bool
#     false)
#   (define-fun X_INTRODUCED_44_ () Bool
#     false)
#   (define-fun X_INTRODUCED_65_ () Bool
#     false)
#   (define-fun X_INTRODUCED_27_ () Int
#     0)
#   (define-fun X_INTRODUCED_90_ () Int
#     0)
#   (define-fun X_INTRODUCED_118_ () Int
#     0)
#   (define-fun X_INTRODUCED_19_ () Bool
#     true)
#   (define-fun X_INTRODUCED_106_ () Bool
#     false)
#   (define-fun X_INTRODUCED_109_ () Int
#     0)
#   (define-fun X_INTRODUCED_41_ () Bool
#     false)
#   (define-fun X_INTRODUCED_107_ () Int
#     0)
#   (define-fun X_INTRODUCED_108_ () Bool
#     false)
#   (define-fun X_INTRODUCED_128_ () Int
#     1)
#   (define-fun X_INTRODUCED_2_ () Int
#     1)
#   (define-fun X_INTRODUCED_11_ () Bool
#     false)
#   (define-fun X_INTRODUCED_35_ () Bool
#     true)
#   (define-fun X_INTRODUCED_80_ () Bool
#     true)
#   (define-fun X_INTRODUCED_26_ () Int
#     1)
#   (define-fun X_INTRODUCED_20_ () Int
#     1)
#   (define-fun X_INTRODUCED_70_ () Bool
#     false)
#   (define-fun X_INTRODUCED_9_ () Int
#     1)
#   (define-fun X_INTRODUCED_56_ () Bool
#     false)
#   (define-fun X_INTRODUCED_89_ () Bool
#     false)
#   (define-fun X_INTRODUCED_68_ () Int
#     0)
#   (define-fun X_INTRODUCED_59_ () Bool
#     false)
#   (define-fun X_INTRODUCED_77_ () Bool
#     true)
#   (define-fun X_INTRODUCED_66_ () Int
#     0)
#   (define-fun X_INTRODUCED_43_ () Int
#     0)
#   (define-fun M () Int
#     1)
#   (define-fun X_INTRODUCED_57_ () Int
#     0)
#   (define-fun X_INTRODUCED_82_ () Int
#     0)
#   (define-fun X_INTRODUCED_69_ () Bool
#     false)
#   (define-fun X_INTRODUCED_24_ () Bool
#     false)
#   (define-fun X_INTRODUCED_16_ () Bool
#     false)
#   (define-fun X_INTRODUCED_51_ () Bool
#     false)
#   (define-fun X_INTRODUCED_99_ () Int
#     1)
#   (define-fun X_INTRODUCED_122_ () Int
#     0)
#   (define-fun X_INTRODUCED_25_ () Int
#     0)
#   (define-fun X_INTRODUCED_136_ () Int
#     0)
#   (define-fun X_INTRODUCED_8_ () Bool
#     true)
#   (define-fun X_INTRODUCED_18_ () Bool
#     true)
#   (define-fun X_INTRODUCED_103_ () Bool
#     false)
#   (define-fun X_INTRODUCED_86_ () Bool
#     true)
#   (define-fun X_INTRODUCED_60_ () Bool
#     false)
#   (define-fun X_INTRODUCED_0_ () Int
#     4)
#   (define-fun X_INTRODUCED_74_ () Int
#     0)
#   (define-fun X_INTRODUCED_63_ () Bool
#     false)
#   (define-fun X_INTRODUCED_111_ () Int
#     0)
#   (define-fun X_INTRODUCED_131_ () Bool
#     false)
#   (define-fun X_INTRODUCED_47_ () Int
#     0)
#   (define-fun X_INTRODUCED_133_ () Bool
#     false)
#   (define-fun X_INTRODUCED_14_ () Bool
#     false)
#   (define-fun X_INTRODUCED_100_ () Bool
#     false)
#   (define-fun X_INTRODUCED_94_ () Int
#     0)
#   (define-fun X_INTRODUCED_104_ () Int
#     0)
#   (define-fun X_INTRODUCED_31_ () Bool
#     true)
#   (define-fun X_INTRODUCED_23_ () Bool
#     false)
#   (define-fun X_INTRODUCED_34_ () Bool
#     false)
#   (define-fun obj () Int
#     264)
#   (define-fun X_INTRODUCED_15_ () Int
#     (- 3))
#   (define-fun X_INTRODUCED_96_ () Bool
#     false)
#   (define-fun X_INTRODUCED_54_ () Bool
#     false)
#   (define-fun X_INTRODUCED_72_ () Bool
#     false)
#   (define-fun X_INTRODUCED_78_ () Bool
#     false)
#   (define-fun X_INTRODUCED_93_ () Bool
#     false)
#   (define-fun X_INTRODUCED_85_ () Int
#     0)
#   (define-fun X_INTRODUCED_50_ () Bool
#     true)
#   (define-fun X_INTRODUCED_46_ () Bool
#     false)
#   (define-fun X_INTRODUCED_130_ () Int
#     3)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_115_ () Int
#     0)
#   (define-fun X_INTRODUCED_135_ () Int
#     0)
#   (define-fun X_INTRODUCED_112_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1_ () Int
#     6)
#   (define-fun X_INTRODUCED_45_ () Bool
#     true)
#   (define-fun X_INTRODUCED_95_ () Bool
#     false)
#   (define-fun X_INTRODUCED_22_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_17_ () Int
#     3)
#   (define-fun X_INTRODUCED_12_ () Int
#     (- 1))
#   (define-fun N () Int
#     0)
#   (define-fun X_INTRODUCED_134_ () Int
#     0)
#   (define-fun X_INTRODUCED_113_ () Int
#     0)
#   (define-fun X_INTRODUCED_101_ () Int
#     0)
#   (define-fun X_INTRODUCED_87_ () Int
#     1)
#   (define-fun X_INTRODUCED_71_ () Int
#     0)
#   (define-fun X_INTRODUCED_52_ () Int
#     0)
#   (define-fun X_INTRODUCED_33_ () Int
#     1)
#   (define-fun S () Int
#     1)
#   (define-fun X_INTRODUCED_5_ () Int
#     2)
#   (define-fun X_INTRODUCED_4_ () Int
#     3)
#   (define-fun X_INTRODUCED_3_ () Int
#     5)
# )

# %%
result = subprocess.check_output('../z3/build/z3 smt2-files/z3/Mz2-noAbs/v3/R034-dzn-fzn_v3.smt2', 
                        shell=True, universal_newlines=True)
print(result)
# Out:
# sat
# (objectives
#  (obj 1)
# )
# (model
#   (define-fun X_INTRODUCED_36_ () Bool
#     false)
#   (define-fun X_INTRODUCED_61_ () Int
#     0)
#   (define-fun X_INTRODUCED_126_ () Int
#     1)
#   (define-fun X_INTRODUCED_79_ () Int
#     0)
#   (define-fun X_INTRODUCED_73_ () Bool
#     false)
#   (define-fun X_INTRODUCED_81_ () Bool
#     false)
#   (define-fun X_INTRODUCED_32_ () Bool
#     false)
#   (define-fun X_INTRODUCED_37_ () Int
#     0)
#   (define-fun X_INTRODUCED_49_ () Int
#     0)
#   (define-fun X_INTRODUCED_55_ () Bool
#     false)
#   (define-fun X_INTRODUCED_117_ () Bool
#     false)
#   (define-fun X_INTRODUCED_132_ () Bool
#     true)
#   (define-fun X_INTRODUCED_97_ () Int
#     0)
#   (define-fun X_INTRODUCED_120_ () Int
#     0)
#   (define-fun X_INTRODUCED_40_ () Bool
#     false)
#   (define-fun X_INTRODUCED_42_ () Bool
#     false)
#   (define-fun X_INTRODUCED_13_ () Bool
#     false)
#   (define-fun X_INTRODUCED_92_ () Bool
#     false)
#   (define-fun X_INTRODUCED_88_ () Bool
#     false)
#   (define-fun X_INTRODUCED_119_ () Bool
#     false)
#   (define-fun X_INTRODUCED_7_ () Bool
#     true)
#   (define-fun X_INTRODUCED_64_ () Bool
#     false)
#   (define-fun X_INTRODUCED_102_ () Bool
#     false)
#   (define-fun X_INTRODUCED_114_ () Bool
#     false)
#   (define-fun X_INTRODUCED_44_ () Bool
#     true)
#   (define-fun X_INTRODUCED_65_ () Bool
#     false)
#   (define-fun X_INTRODUCED_27_ () Int
#     0)
#   (define-fun X_INTRODUCED_90_ () Int
#     0)
#   (define-fun X_INTRODUCED_118_ () Int
#     0)
#   (define-fun X_INTRODUCED_19_ () Bool
#     false)
#   (define-fun X_INTRODUCED_106_ () Bool
#     false)
#   (define-fun X_INTRODUCED_109_ () Int
#     0)
#   (define-fun X_INTRODUCED_107_ () Int
#     0)
#   (define-fun X_INTRODUCED_108_ () Bool
#     false)
#   (define-fun X_INTRODUCED_128_ () Int
#     1)
#   (define-fun X_INTRODUCED_2_ () Int
#     5)
#   (define-fun X_INTRODUCED_11_ () Bool
#     false)
#   (define-fun X_INTRODUCED_35_ () Bool
#     false)
#   (define-fun X_INTRODUCED_80_ () Bool
#     false)
#   (define-fun X_INTRODUCED_26_ () Int
#     0)
#   (define-fun X_INTRODUCED_20_ () Int
#     1)
#   (define-fun X_INTRODUCED_70_ () Bool
#     false)
#   (define-fun X_INTRODUCED_30_ () Bool
#     false)
#   (define-fun X_INTRODUCED_9_ () Int
#     1)
#   (define-fun X_INTRODUCED_56_ () Bool
#     false)
#   (define-fun X_INTRODUCED_89_ () Bool
#     false)
#   (define-fun X_INTRODUCED_68_ () Int
#     0)
#   (define-fun X_INTRODUCED_59_ () Bool
#     true)
#   (define-fun X_INTRODUCED_77_ () Bool
#     false)
#   (define-fun X_INTRODUCED_66_ () Int
#     0)
#   (define-fun X_INTRODUCED_43_ () Int
#     0)
#   (define-fun M () Int
#     0)
#   (define-fun X_INTRODUCED_57_ () Int
#     0)
#   (define-fun X_INTRODUCED_82_ () Int
#     0)
#   (define-fun X_INTRODUCED_69_ () Bool
#     true)
#   (define-fun X_INTRODUCED_24_ () Bool
#     false)
#   (define-fun X_INTRODUCED_16_ () Bool
#     false)
#   (define-fun X_INTRODUCED_51_ () Bool
#     false)
#   (define-fun X_INTRODUCED_99_ () Int
#     0)
#   (define-fun X_INTRODUCED_122_ () Int
#     0)
#   (define-fun X_INTRODUCED_25_ () Int
#     0)
#   (define-fun X_INTRODUCED_136_ () Int
#     0)
#   (define-fun X_INTRODUCED_8_ () Bool
#     true)
#   (define-fun X_INTRODUCED_18_ () Bool
#     false)
#   (define-fun X_INTRODUCED_103_ () Bool
#     false)
#   (define-fun X_INTRODUCED_86_ () Bool
#     false)
#   (define-fun X_INTRODUCED_60_ () Bool
#     false)
#   (define-fun X_INTRODUCED_0_ () Int
#     3)
#   (define-fun X_INTRODUCED_74_ () Int
#     0)
#   (define-fun X_INTRODUCED_63_ () Bool
#     true)
#   (define-fun X_INTRODUCED_111_ () Int
#     0)
#   (define-fun X_INTRODUCED_131_ () Bool
#     false)
#   (define-fun X_INTRODUCED_47_ () Int
#     0)
#   (define-fun X_INTRODUCED_133_ () Bool
#     false)
#   (define-fun X_INTRODUCED_14_ () Bool
#     false)
#   (define-fun X_INTRODUCED_100_ () Bool
#     false)
#   (define-fun X_INTRODUCED_94_ () Int
#     0)
#   (define-fun X_INTRODUCED_104_ () Int
#     0)
#   (define-fun X_INTRODUCED_31_ () Bool
#     true)
#   (define-fun X_INTRODUCED_23_ () Bool
#     false)
#   (define-fun X_INTRODUCED_34_ () Bool
#     true)
#   (define-fun obj () Int
#     1)
#   (define-fun X_INTRODUCED_15_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_96_ () Bool
#     false)
#   (define-fun X_INTRODUCED_93_ () Bool
#     false)
#   (define-fun X_INTRODUCED_72_ () Bool
#     true)
#   (define-fun X_INTRODUCED_78_ () Bool
#     false)
#   (define-fun X_INTRODUCED_85_ () Int
#     0)
#   (define-fun X_INTRODUCED_50_ () Bool
#     false)
#   (define-fun X_INTRODUCED_46_ () Bool
#     false)
#   (define-fun X_INTRODUCED_130_ () Int
#     1)
#   (define-fun X_INTRODUCED_21_ () Bool
#     false)
#   (define-fun X_INTRODUCED_115_ () Int
#     0)
#   (define-fun X_INTRODUCED_135_ () Int
#     1)
#   (define-fun X_INTRODUCED_112_ () Bool
#     false)
#   (define-fun X_INTRODUCED_1_ () Int
#     2)
#   (define-fun X_INTRODUCED_45_ () Bool
#     false)
#   (define-fun X_INTRODUCED_95_ () Bool
#     true)
#   (define-fun X_INTRODUCED_22_ () Int
#     (- 1))
#   (define-fun X_INTRODUCED_17_ () Int
#     1)
#   (define-fun X_INTRODUCED_12_ () Int
#     (- 1))
#   (define-fun N () Int
#     1)
#   (define-fun X_INTRODUCED_134_ () Int
#     0)
#   (define-fun X_INTRODUCED_113_ () Int
#     0)
#   (define-fun X_INTRODUCED_101_ () Int
#     0)
#   (define-fun X_INTRODUCED_87_ () Int
#     0)
#   (define-fun X_INTRODUCED_71_ () Int
#     0)
#   (define-fun X_INTRODUCED_52_ () Int
#     0)
#   (define-fun X_INTRODUCED_33_ () Int
#     0)
#   (define-fun S () Int
#     0)
#   (define-fun X_INTRODUCED_5_ () Int
#     6)
#   (define-fun X_INTRODUCED_4_ () Int
#     1)
#   (define-fun X_INTRODUCED_3_ () Int
#     4)
# )
